# %%
import sklearn_crfsuite
import pandas as pd

from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from helper.dataset_reader import read_tsv
from helper.features import *

# import warnings filter
from warnings import simplefilter

# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %%
data = read_tsv('../dataset/all-merged-data-140422.tsv')

# %%
dt, all_words, all_tags = data

# %%
# Convert to dataframe [Tweet | Tags]
df_tweet_tags = pd.DataFrame(dt, columns=['Tweets','Tags'])
# df_tweet_tags.head()

# %%
token_tag_pair = []

for index, row in df_tweet_tags.iterrows():
    pair = list(zip(row['Tweets'], row['Tags']))
    token_tag_pair.append(pair)

token_tag_pair
# Out:
# [[('Tumben', 'ID'),
#   ('xl', 'O'),
#   ('banter', 'ID'),
#   ('go', 'JV'),
#   ('download', 'EN'),
#   (',', 'O'),
#   (',', 'O'),
#   ('download', 'EN'),
#   ('video', 'ID'),
#   ('tom', 'O'),
#   ('jerry', 'O'),
#   ('ya', 'ID'),
#   ('masuk', 'ID'),
#   ('kie', 'JV'),
#   ('https://t.co/SmrXmut7wk', 'O')],
#  [('@myXL', 'O'),
#   ('@myXLCare', 'O'),
#   ('knp', 'ID'),
#   ('xl', 'O'),
#   ('skr', 'ID'),
#   ('jd', 'ID'),
#   ('susah', 'ID'),
#   ('signal', 'EN'),
#   ('ya', 'ID'),
#   (',', 'O'),
#   ('dan', 'ID'),
#   ('download', 'EN'),
#   ('paling', 'ID'),
#   ('banter', 'ID'),
#   ('70kbps', 'EN'),
#   ('.', 'O'),
#   ('Sangat', 'ID'),
#   ('disayangkan', 'ID')],
#  [('Lak', 'JV'),
#   ('download', 'EN'),
#   ('nggawe', 'JV'),
#   ('cl', 'O'),
#   ('iku', 'JV'),
#   ('subuh', 'ID'),
#   ('baru', 'ID'),
#   ('banter', 'ID'),
#   ('.', 'O'),
#   ('Lak', 'JV'),
#   ('sore-bengi', 'JV'),
#   ('lemot', 'JV'),
#   ("''", 'O'),
#   ('@kecepoood', 'O'),
#   (':', 'O'),
#   ('XL', 'O'),
#   ('labil', 'ID'),
#   ('donlod', 'EN'),
#   ('munggah', 'JV'),
#   ('mudun', 'JV'),
#   ('😩', 'O'),
#   ('"', 'O')],
#  [('xl', 'O'),
#   ('ngebut', 'ID'),
#   ('.', 'O'),
#   ('Banter', 'JV'),
#   ('banget', 'JV'),
#   ('.', 'O'),
#   ('Download', 'EN'),
#   ('0,7GB', 'O'),
#   ('hanya', 'ID'),
#   ('26', 'O'),
#   ('menit', 'ID'),
#   ('.', 'O')],
#  [('Opone', 'JV'),
#   ('banter', 'JV'),
#   ('limite', 'MIX-JV-EN'),
#   ('mek', 'JV'),
#   ('512kbps', 'EN'),
#   ('RT', 'EN'),
#   ('@aslisuroboyo:', 'O'),
#   ('Nggawe', 'JV'),
#   ('XL', 'O'),
#   ('unlimited', 'EN'),
#   ('streaming', 'EN'),
#   ('youtube', 'EN'),
#   ('karo', 'JV'),
#   ('download', 'EN'),
#   ('kenceng', 'ID'),
#   ('!', 'O'),
#   ('Info', 'ID'),
#   (':', 'O'),
#   ('http://t.co/oXbsXMkMF1', 'O')],
#  [('Lagi', 'ID'),
#   ('banter', 'ID'),
#   ('nih', 'ID'),
#   ('yank', 'ID'),
#   ('.', 'O'),
#   ('puas', 'ID'),
#   ('download', 'EN'),
#   ('nih', 'ID'),
#   ('.', 'O'),
#   ('RT', 'EN'),
#   ('@dedelchup_ah:', 'O'),
#   ('Jadi', 'ID'),
#   ('males', 'ID'),
#   ('internetan', 'ID'),
#   ('..', 'O'),
#   ('Ini', 'ID'),
#   ('xl', 'O'),
#   ('lg', 'ID'),
#   ('cupu', 'ID'),
#   ('!', 'O')],
#  [('Njir', 'ID'),
#   ('lemot', 'ID'),
#   ('banget', 'ID'),
#   ('ni', 'ID'),
#   ('XL', 'O'),
#   (',', 'O'),
#   ('td', 'ID'),
#   ('subuh', 'ID'),
#   ('buat', 'ID'),
#   ('download', 'EN'),
#   ('masih', 'ID'),
#   ('banter', 'ID'),
#   ('pdahal', 'ID'),
#   ('....', 'O')],
#  [('@Preteritoo', 'O'),
#   ('flash', 'EN'),
#   ('ambek', 'JV'),
#   ('xl', 'O'),
#   ('download', 'EN'),
#   ('stabille', 'EN'),
#   ('350kbps', 'EN'),
#   (',', 'O'),
#   ('cuman', 'ID'),
#   ('xl', 'O'),
#   ('sinyale', 'MIX-ID-JV'),
#   ('ga', 'ID'),
#   ('stabil', 'ID'),
#   (',', 'O'),
#   ('kadang', 'ID'),
#   ('banter', 'JV'),
#   (',', 'O'),
#   ('kadang', 'ID'),
#   ('ngedrop', 'MIX-ID-EN'),
#   (',', 'O'),
#   ('regane', 'JV'),
#   ('cuman', 'ID'),
#   ('bedo', 'JV'),
#   ('10ewu', 'JV'),
#   ('tok', 'JV')],
#  [('@ms_ephee', 'O'),
#   ('kamu', 'ID'),
#   ('pake', 'ID'),
#   ('apa', 'ID'),
#   ('toh', 'ID'),
#   ('?', 'O'),
#   ('Aku', 'ID'),
#   ('pake', 'ID'),
#   ('XL', 'O'),
#   ('banter', 'ID'),
#   ('lho', 'ID'),
#   ('di', 'ID'),
#   ('apartemen', 'ID'),
#   ('pun', 'ID'),
#   ('bisa', 'ID'),
#   ('download', 'EN'),
#   ('yutub', 'O')],
#  [('Weekend', 'EN'),
#   ('santai', 'ID'),
#   (',', 'O'),
#   ('mau', 'ID'),
#   ('streamingan', 'MIX-ID-EN'),
#   ('main', 'ID'),
#   ('sosmed', 'ID'),
#   ('tanpa', 'ID'),
#   ('ngelag', 'MIX-ID-EN'),
#   ('bersama', 'ID'),
#   ('jaringan', 'ID'),
#   ('IndiHome', 'O'),
#   ('@IndiHomeCare', 'O'),
#   ('#AktivitasTanpaBatas', 'O')],
#  [('convomf', 'O'),
#   ('pernah', 'ID'),
#   (',', 'O'),
#   ('karena', 'ID'),
#   ('waktu', 'ID'),
#   ('itu', 'ID'),
#   ('ada', 'ID'),
#   ('kerja', 'ID'),
#   ('kelompok', 'ID'),
#   (',', 'O'),
#   ('trs', 'ID'),
#   ('mau', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   (',', 'O'),
#   ('tapi', 'ID'),
#   ('temen', 'ID'),
#   ('cowo', 'ID'),
#   ('gue', 'ID'),
#   ('ga', 'ID'),
#   ('tau', 'ID'),
#   ('tempatnya', 'ID'),
#   ('alhasil', 'ID'),
#   ('gue', 'ID'),
#   ('yg', 'ID'),
#   ('disuruh', 'ID'),
#   ('nganterin', 'ID'),
#   ('.', 'O'),
#   ('Trs', 'ID'),
#   ('pernah', 'ID'),
#   ('dibonceng', 'ID'),
#   ('guru', 'ID'),
#   ('smp', 'ID'),
#   ('karena', 'ID'),
#   ('waktu', 'ID'),
#   ('berangkat', 'ID'),
#   ('sekolah', 'ID'),
#   ('motor', 'ID'),
#   ('ibu', 'ID'),
#   ('gue', 'ID'),
#   ('bannya', 'ID'),
#   ('bocor', 'ID'),
#   ('😭', 'O')],
#  [('@tanyakanrl', 'O'),
#   ('Yg', 'ID'),
#   ('gede', 'ID'),
#   ('?', 'O'),
#   ('A3', 'O'),
#   ('?', 'O'),
#   ('Tanya', 'ID'),
#   ('mbak', 'ID'),
#   ('bisa', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('ukuran', 'ID'),
#   ('a3', 'O'),
#   ('ga', 'ID'),
#   ('ya', 'ID'),
#   (',', 'O'),
#   ('krn', 'ID'),
#   ('bnykan', 'O'),
#   ('ga', 'ID'),
#   ('bisa', 'ID')],
#  [('Iya', 'ID'),
#   ('aku', 'ID'),
#   ('mau', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('!', 'O'),
#   ('!', 'O'),
#   ('Di', 'ID'),
#   ('unimas', 'O'),
#   ('kok', 'ID'),
#   ('gada', 'ID'),
#   ('ya', 'ID'),
#   ('?', 'O')],
#  [('jane', 'JV'),
#   ('si', 'O'),
#   ('jojo', 'O'),
#   ('ki', 'JV'),
#   ('akeh', 'JV'),
#   ('error', 'EN'),
#   ('e', 'JV'),
#   ('tp', 'ID'),
#   ('yo', 'JV'),
#   ('apik', 'JV'),
#   ('maine', 'JV'),
#   (',', 'O'),
#   ('mantap', 'ID'),
#   ('sapu', 'ID'),
#   ('bersih', 'ID'),
#   ('Indonesia', 'O'),
#   ('🇮', 'O'),
#   ('🇩', 'O')],
#  [('Ngeprint', 'MIX-ID-EN'),
#   ('laporan', 'ID'),
#   ('PKL', 'ID'),
#   ('habis', 'ID'),
#   ('400k', 'O'),
#   ('.', 'O'),
#   ('Udah', 'ID'),
#   ('bisa', 'ID'),
#   ('buat', 'ID'),
#   ('beli', 'ID'),
#   ('album', 'ID'),
#   ('itu', 'ID'),
#   ('mah', 'ID'),
#   ('🥺', 'O')],
#  [('@aeribase', 'O'),
#   ('1', 'O'),
#   ('kali', 'ID'),
#   ('print', 'EN'),
#   ('1', 'O'),
#   ('kali', 'ID'),
#   ('dapat', 'ID'),
#   ('foto', 'ID'),
#   ('bareng', 'ID'),
#   ('.', 'O'),
#   ('Ngeprint', 'MIX-ID-EN'),
#   ('banyak', 'ID'),
#   ('bisa', 'ID'),
#   ('bawa', 'ID'),
#   ('pulang', 'ID'),
#   ('orang', 'ID'),
#   ('nya', 'ID'),
#   ('🤗', 'O'),
#   ('👍', 'O')],
#  [('@aeribase', 'O'),
#   ('Yang', 'ID'),
#   ('jaga', 'ID'),
#   ('tempat', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('nya', 'ID'),
#   ('bukan', 'ID'),
#   ('kaleng', 'ID'),
#   ('kaleng', 'ID'),
#   ('😭', 'O')],
#  [('@Moo__nday', 'O'),
#   ('@convomf', 'O'),
#   ('wwkwkakakak', 'O'),
#   ('hobi', 'ID'),
#   ('bgtt', 'ID'),
#   ('neeeh', 'ID'),
#   ('adek', 'ID'),
#   ('gw', 'ID'),
#   ('tugasnya', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('muluu', 'ID'),
#   ('🤣', 'O')],
#  [('“', 'O'),
#   ('halah', 'JV'),
#   ('tinggal', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('sendiri', 'ID'),
#   ('apa', 'ID'),
#   ('bedanya', 'ID'),
#   ('”', 'O'),
#   ('🤣', 'O'),
#   ('🤣', 'O'),
#   ('🤣', 'O')],
#  [('kang', 'ID'),
#   ('fotokopi', 'ID'),
#   ('bantuin', 'ID'),
#   ('aku', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('in', 'ID'),
#   ('laprak', 'ID'),
#   ('..', 'O'),
#   ('tapi', 'ID'),
#   ('jan', 'ID'),
#   ('mahal2', 'ID'),
#   ('mau', 'ID'),
#   ('abangnya', 'ID'),
#   ('kek', 'ID'),
#   ('gini', 'ID'),
#   ('aklo', 'ID'),
#   ('mahal', 'ID'),
#   ('w', 'ID'),
#   ('ga', 'ID'),
#   ('ammapu', 'ID'),
#   ('🤕', 'O')],
#  [('@aba_eazid', 'O'),
#   ('@damunnnnn', 'O'),
#   ('@antipadan', 'O'),
#   ('anjim', 'ID'),
#   (',', 'O'),
#   ('makanya', 'ID'),
#   ('gue', 'ID'),
#   ('kalo', 'ID'),
#   ('mau', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('pasti', 'ID'),
#   ('dokumennya', 'ID'),
#   ('langsung', 'ID'),
#   ('gue', 'ID'),
#   ('apus', 'ID'),
#   ('permanen', 'ID'),
#   (',', 'O'),
#   ('email', 'ID'),
#   ('dicheck', 'MIX-ID-EN'),
#   ('berkali', 'ID'),
#   ('kali', 'ID'),
#   ('pastiin', 'ID'),
#   ('bener', 'ID'),
#   ('bener', 'ID'),
#   ('log', 'ID'),
#   ('out', 'EN')],
#  [('Aneh', 'ID'),
#   ('sih', 'ID'),
#   ('kalo', 'ID'),
#   ('dipikir', 'ID'),
#   ('pikir', 'ID'),
#   ('Ruangan', 'ID'),
#   ('gue', 'ID'),
#   ('kan', 'ID'),
#   ('dibelakang', 'ID'),
#   ('dia', 'ID'),
#   ('depan', 'ID'),
#   ('tp', 'ID'),
#   ('klo', 'ID'),
#   ('minta', 'ID'),
#   ('tolong', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('tuh', 'ID'),
#   ('ke', 'ID'),
#   ('gue', 'ID'),
#   ('gitu', 'ID'),
#   ('yang', 'ID'),
#   ('dibelakang', 'ID'),
#   ('padahal', 'ID'),
#   ('didepan', 'ID'),
#   ('juga', 'ID'),
#   ('ada', 'ID'),
#   ('komputer', 'ID'),
#   ('printer', 'EN'),
#   ('Trus', 'ID'),
#   ('ada', 'ID'),
#   ('pegawai', 'ID'),
#   ('juga', 'ID'),
#   ('Mungkin', 'ID'),
#   ('gue', 'ID'),
#   ('palinh', 'ID'),
#   ('enak', 'ID'),
#   ('buat', 'ID'),
#   ('disuruh', 'ID'),
#   ('kali', 'ID'),
#   ('ya', 'ID')],
#  [('@isaaxnewton', 'O'),
#   ('Ngeprint', 'MIX-ID-EN'),
#   ('KTP', 'ID'),
#   ('bisa', 'ID'),
#   ('di', 'ID'),
#   ('dukcapil', 'ID'),
#   ('seluruh', 'ID'),
#   ('Indonesia', 'O'),
#   ('kalo', 'ID'),
#   ('ga', 'ID'),
#   ('salah', 'ID'),
#   (',', 'O'),
#   ('kalo', 'ID'),
#   ('foto', 'ID'),
#   ('di', 'ID'),
#   ('KTP', 'ID'),
#   ('ga', 'ID'),
#   ('bisa', 'ID'),
#   ('diganti', 'ID'),
#   ('wkwk', 'O')],
#  [('@PhoenicisAlpha', 'O'),
#   ('Tp', 'ID'),
#   ('ena', 'ID'),
#   ('kalo', 'ID'),
#   ('ada', 'ID'),
#   ('keperluan', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('dadakan', 'ID'),
#   ('😂', 'O'),
#   ('😂', 'O')],
#  [('@codingfess', 'O'),
#   ('Ngeprint', 'MIX-ID-EN'),
#   ('``', 'O'),
#   ('Hello', 'EN'),
#   ('World', 'EN'),
#   ("''", 'O')],
#  [('@aeribase', 'O'),
#   ('kalo', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('gratis', 'ID'),
#   ('fotbar', 'ID'),
#   ('ga', 'ID'),
#   ('mas', 'ID')],
#  [('@missufe', 'O'),
#   ('belum', 'ID'),
#   ('makan', 'ID'),
#   ('makjii', 'O'),
#   ('aku', 'ID'),
#   ('lagi', 'ID'),
#   ('pusing', 'ID'),
#   ('bgt', 'ID'),
#   ('gaada', 'ID'),
#   ('uang', 'ID'),
#   ('buat', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('tugas', 'ID'),
#   ('aku', 'ID'),
#   ('76', 'O'),
#   ('lembar', 'ID'),
#   ('aaa', 'O'),
#   ('kalo', 'ID'),
#   ('gini', 'ID'),
#   ('cuma', 'ID'),
#   ('bisa', 'ID'),
#   ('nangis', 'ID'),
#   ('aja', 'ID'),
#   ('😔', 'O'),
#   ('😔', 'O')],
#  [('@HurryKoRn', 'O'),
#   ('Niat', 'ID'),
#   ('bener', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('sticker', 'EN'),
#   ('segede', 'ID'),
#   ('itu', 'ID'),
#   ('😁', 'O')],
#  [('Gue', 'ID'),
#   ('mau', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('tulisan', 'ID'),
#   ('MIA', 'O'),
#   ('I', 'EN'),
#   ('LOPE', 'EN'),
#   ('U', 'EN'),
#   ('baaaah', 'O'),
#   ('terguncang', 'ID'),
#   ('exoplanet', 'EN'),
#   ('🤣', 'O'),
#   ('🤣', 'O')],
#  [('@antipadan', 'O'),
#   ('Ini', 'ID'),
#   ('kalo', 'ID'),
#   ('di', 'ID'),
#   ('austria', 'O'),
#   ('ada', 'ID'),
#   ('namanya', 'ID'),
#   ('printbox', 'EN'),
#   ('.', 'O'),
#   ('Enakan', 'ID'),
#   ('pake', 'ID'),
#   ('beginian', 'ID'),
#   ('cepet', 'ID'),
#   ('ga', 'ID'),
#   ('ribet', 'ID'),
#   ('.', 'O'),
#   ('Walaupun', 'ID'),
#   ('lumayan', 'ID'),
#   ('sih', 'ID'),
#   ('0.25', 'O'),
#   ('euro', 'O'),
#   ('per', 'ID'),
#   ('print', 'EN'),
#   ('wkwkwk', 'O'),
#   ('(', 'O'),
#   ('nb', 'ID'),
#   (':', 'O'),
#   ('makin', 'ID'),
#   ('banyak', 'ID'),
#   ('makin', 'ID'),
#   ('murah', 'ID'),
#   ('.', 'O'),
#   ('Rate', 'EN'),
#   ('termurah', 'ID'),
#   ('0.09', 'O'),
#   ('tp', 'ID'),
#   ('ga', 'ID'),
#   ('worth', 'EN'),
#   ('buat', 'ID'),
#   ('yg', 'ID'),
#   ('ga', 'ID'),
#   ('tinggal', 'ID'),
#   ('lama', 'ID'),
#   ('di', 'ID'),
#   ('sini', 'ID'),
#   ('.', 'O'),
#   ('Mending', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('di', 'ID'),
#   ('kampus', 'ID'),
#   ('0.10', 'O'),
#   ('euro', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('Terus', 'ID'),
#   ('aing', 'O'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('skripsi', 'ID'),
#   ('yg', 'ID'),
#   ('sampe', 'ID'),
#   ('260an', 'ID'),
#   ('halaman', 'ID'),
#   ('itu', 'ID'),
#   (',', 'O'),
#   ('dibelakang', 'ID'),
#   ('orang', 'ID'),
#   ('ngantri', 'JV'),
#   ('wkwkwkwk', 'O')],
#  [('This', 'EN'),
#   ('!', 'O'),
#   ('!', 'O'),
#   ('!', 'O'),
#   ('!', 'O'),
#   ('!', 'O'),
#   ('!', 'O'),
#   ('!', 'O'),
#   ('Benci', 'ID'),
#   ('banget', 'ID'),
#   ('sama', 'ID'),
#   ('tukang', 'ID'),
#   ('print', 'EN'),
#   ('kayak', 'ID'),
#   ('babi', 'ID'),
#   ('.', 'O'),
#   ('Kita', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('tuh', 'ID'),
#   ('pakai', 'ID'),
#   ('duit', 'ID'),
#   ('.', 'O'),
#   ('Makan', 'ID'),
#   ('dah', 'ID'),
#   ('tuh', 'ID'),
#   ('orderan', 'ID'),
#   ('lu', 'ID'),
#   ('sepi', 'ID'),
#   ('kalau', 'ID'),
#   ('makin', 'ID'),
#   ('banyak', 'ID'),
#   ('mesin', 'ID'),
#   ('cetak', 'ID'),
#   ('mandiri', 'ID'),
#   ('gini', 'ID')],
#  [('Yaelah', 'ID'),
#   (',', 'O'),
#   ('kalo', 'ID'),
#   ('yg', 'ID'),
#   ('jaga', 'ID'),
#   ('print-print', 'MIX-ID-EN'),
#   ('an', 'ID'),
#   ('kayak', 'ID'),
#   ('gini', 'ID'),
#   ('mah', 'ID'),
#   (',', 'O'),
#   ('mau', 'ID'),
#   ('tiap', 'ID'),
#   ('hari', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('🤣', 'O'),
#   ('✨', 'O'),
#   ('https://t.co/kCGHsugwCA', 'O')],
#  [('@WAHYUYK_', 'O'),
#   ('@titiswell', 'O'),
#   ('bismillah', 'ID'),
#   ('kalo', 'ID'),
#   ('rejeki', 'ID'),
#   ('mau', 'ID'),
#   ('buat', 'ID'),
#   ('beli', 'ID'),
#   ('kertas', 'ID'),
#   ('print', 'EN'),
#   ('kak', 'ID'),
#   (',', 'O'),
#   ('buat', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('skripsi', 'ID'),
#   ('wkwk', 'O')],
#  [('Baru', 'ID'),
#   ('sadar', 'ID'),
#   ('lupa', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('yg', 'ID'),
#   ('donghae', 'O'),
#   ('😭', 'O')],
#  [('@collegemenfess', 'O'),
#   ('Buat', 'ID'),
#   ('banner', 'EN'),
#   (',', 'O'),
#   ('ngedit', 'ID'),
#   ('postingan', 'MIX-ID-EN'),
#   (',', 'O'),
#   ('ngevideoin', 'ID'),
#   ('acara', 'ID'),
#   (',', 'O'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ("''", 'O'),
#   (',', 'O'),
#   ('buat', 'ID'),
#   ('id', 'EN'),
#   ('card', 'EN'),
#   ('keanggotaan', 'ID'),
#   (',', 'O'),
#   ('ngedit', 'ID'),
#   ('sertifikat', 'ID'),
#   ('acara', 'ID')],
#  [('PENGEN', 'ID'),
#   ('NGEPRINT', 'MIX-ID-EN'),
#   ('JADI', 'ID'),
#   ('PC', 'EN'),
#   ('😆', 'O')],
#  [('Iseng', 'ID'),
#   ('coba', 'ID'),
#   ('coba', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('PC', 'EN'),
#   ('https://t.co/fd6gsPciCu', 'O')],
#  [('ta-tapi', 'ID'),
#   ('kl', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('dkt', 'ID'),
#   ('kampus', 'ID'),
#   ('juga', 'ID'),
#   ('udh', 'ID'),
#   ('self', 'EN'),
#   ('service', 'EN'),
#   ('tidak', 'ID'),
#   ('ada', 'ID'),
#   ('beda', 'ID'),
#   (':")', 'O')],
#  [('di', 'ID'),
#   ('Bandara', 'O'),
#   ('Jogja', 'O'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('surat', 'ID'),
#   ('antigen', 'ID'),
#   ('5k', 'O'),
#   ('lalu', 'ID'),
#   ('di', 'ID'),
#   ('Bandara', 'O'),
#   ('Balikpapan', 'O'),
#   ('beli', 'ID'),
#   ('makanan', 'ID'),
#   ('ini', 'ID'),
#   ('totalnya', 'ID'),
#   ('66k', 'O'),
#   ('.', 'O'),
#   ('shock', 'EN'),
#   ('harga', 'ID'),
#   ('onigiri', 'O'),
#   ('mahal', 'ID'),
#   ('di', 'ID'),
#   ('Balikpapan', 'O'),
#   ('https://t.co/WXb29MkYDz', 'O')],
#  [('@bedarmanto', 'O'),
#   ('Mereka', 'ID'),
#   ('pro', 'ID'),
#   ('lah', 'ID'),
#   ('.', 'O'),
#   ('Cm', 'ID'),
#   ('kurang', 'ID'),
#   ('belajar', 'ID'),
#   ('teknologi', 'ID'),
#   ('aja', 'ID'),
#   ('.', 'O'),
#   ('Mereka', 'ID'),
#   ('masi', 'ID'),
#   ('pake', 'ID'),
#   ('mesin', 'ID'),
#   ('tik', 'ID'),
#   ('.', 'O'),
#   ('Ga', 'ID'),
#   ('bisa', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('pake', 'ID'),
#   ('komputer', 'ID'),
#   (',', 'O'),
#   ('kalo', 'ID'),
#   ('bisa', 'ID'),
#   ('pake', 'ID'),
#   ('komputer', 'ID'),
#   ('kan', 'ID'),
#   ('mestinya', 'ID'),
#   ('tau', 'ID'),
#   ('cukup', 'ID'),
#   ('GOOGLE', 'O'),
#   ('aja', 'ID'),
#   ('selesai', 'ID'),
#   ('ga', 'ID'),
#   ('usah', 'ID'),
#   ('jauh2', 'ID'),
#   ('ke', 'ID'),
#   ('Diriyah', 'O'),
#   ('.', 'O'),
#   ('HP', 'EN'),
#   ('nya', 'ID'),
#   ('jg', 'ID'),
#   ('pasti', 'ID'),
#   ('nokia', 'O'),
#   ('jadul', 'ID'),
#   (',', 'O'),
#   ('bukan', 'ID'),
#   ('android', 'O'),
#   ('yg', 'ID'),
#   ('ada', 'ID'),
#   ('GOOGLE', 'O'),
#   ('nya', 'ID'),
#   ('😂', 'O')],
#  [('Ngestan', 'MIX-ID-EN'),
#   ('exo', 'O'),
#   ('dari', 'ID'),
#   ('era', 'ID'),
#   ('growl', 'EN'),
#   ('2013', 'O'),
#   (',', 'O'),
#   ('dari', 'ID'),
#   ('jamannya', 'ID'),
#   ('cuma', 'ID'),
#   ('bisa', 'ID'),
#   ('liat', 'ID'),
#   ('dari', 'ID'),
#   ('hape', 'EN'),
#   (',', 'O'),
#   ('nontonin', 'ID'),
#   ('mv', 'EN'),
#   ('vs', 'EN'),
#   ('drakor', 'ID'),
#   ('downloadin', 'MIX-ID-EN'),
#   ('mv', 'EN'),
#   ('lagu', 'ID'),
#   ('mereka', 'ID'),
#   (',', 'O'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('foto', 'ID'),
#   ('pake', 'ID'),
#   ('hvs', 'O'),
#   ('😂', 'O'),
#   (',', 'O'),
#   ('mau', 'ID'),
#   ('beli', 'ID'),
#   ('album', 'ID'),
#   ('gak', 'ID'),
#   ('ada', 'ID'),
#   ('uang', 'ID'),
#   ('lebih', 'ID'),
#   (',', 'O'),
#   ('dan', 'ID'),
#   ('baru', 'ID'),
#   ('bisa', 'ID'),
#   ('kebeli', 'ID'),
#   ('album', 'ID'),
#   ('2017', 'O'),
#   (',', 'O'),
#   ('semoga', 'ID'),
#   ('2022', 'O'),
#   ('5pc', 'EN'),
#   ('lagi', 'ID'),
#   ('sebelum', 'ID'),
#   ('cy', 'O'),
#   ('balik', 'ID'),
#   ('kekumpul', 'ID'),
#   ('semua', 'ID'),
#   ('Exol', 'O'),
#   ('😍', 'O'),
#   ('https://t.co/WLnx5qOO0O', 'O')],
#  [('Kalo', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('pke', 'ID'),
#   ('itu', 'ID'),
#   ('lebih', 'ID'),
#   ('enak', 'ID'),
#   ('dan', 'ID'),
#   ('ga', 'ID'),
#   ('ribet', 'ID'),
#   ('keknya', 'ID'),
#   ('jadi', 'ID'),
#   ('gausa', 'ID'),
#   ('lagi', 'ID'),
#   ('bawa', 'ID'),
#   ('bawa', 'ID'),
#   ('fd', 'EN'),
#   ('ke', 'ID'),
#   ('warnet', 'ID'),
#   ('buat', 'ID'),
#   ('print', 'EN'),
#   (',', 'O'),
#   ('kdng', 'ID'),
#   ('tukang', 'ID'),
#   ('print', 'EN'),
#   ('gamau', 'ID'),
#   ('print', 'EN'),
#   ('kan', 'ID'),
#   ('malah', 'ID'),
#   ('nyuruh', 'ID'),
#   ('ktaa', 'ID'),
#   (':((', 'O'),
#   ('soalnya', 'ID'),
#   ('kalo', 'ID'),
#   ('print', 'EN'),
#   ('sndri', 'ID'),
#   ('tuh', 'ID'),
#   ('ga', 'ID'),
#   ('enak', 'ID'),
#   ('bgt', 'ID'),
#   ('kdng', 'ID'),
#   ('ga', 'ID'),
#   ('sesuai', 'ID'),
#   ('sm', 'ID'),
#   ('yg', 'ID'),
#   ('kta', 'ID'),
#   ('mau', 'ID'),
#   ('gtu', 'ID'),
#   ('pas', 'ID'),
#   ('hasilnya', 'ID'),
#   ('kluar', 'ID')],
#  [('@BaseAnakFK', 'O'),
#   ('tergantung', 'ID'),
#   (',', 'O'),
#   ('tapi', 'ID'),
#   ('harusnya', 'ID'),
#   ('se', 'ID'),
#   ('hari', 'ID'),
#   ('30rb', 'ID'),
#   ('makan', 'ID'),
#   ('pagi', 'ID'),
#   ('smp', 'ID'),
#   ('mlm', 'ID'),
#   ('yhaa', 'ID'),
#   ('.', 'O'),
#   ('tapi', 'ID'),
#   ('kalo', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   (',', 'O'),
#   ('uang', 'ID'),
#   ('jilid', 'ID'),
#   (',', 'O'),
#   ('fotkop', 'ID'),
#   ('bedalagi', 'ID'),
#   ('🙏', 'O')],
#  [('@thyannosaurus', 'O'),
#   ('Mas', 'O'),
#   ('ono', 'O'),
#   ('dan', 'ID'),
#   ('jasa', 'ID'),
#   ('print', 'EN'),
#   ('selalu', 'ID'),
#   ('di', 'ID'),
#   ('hati', 'ID'),
#   ('pokoknya', 'ID'),
#   ('.', 'O'),
#   ('Ngeprint', 'MIX-ID-EN'),
#   ('bonus', 'ID'),
#   ('koreksi', 'ID'),
#   ('penulisan', 'ID'),
#   ('wkwkwk', 'O')],
#  [('@angelicnesya', 'O'),
#   ('Hai', 'ID'),
#   (',', 'O'),
#   ('Kak', 'O'),
#   ('Angel', 'O'),
#   ('.', 'O'),
#   ('Jika', 'ID'),
#   ('menglamai', 'ID'),
#   ('kendalda', 'ID'),
#   ('pada', 'ID'),
#   ('koneksi', 'ID'),
#   ('IndiHome-nya', 'ID'),
#   (',', 'O'),
#   ('Sebagai', 'ID'),
#   ('langkah', 'ID'),
#   ('awal', 'ID'),
#   (',', 'O'),
#   ('silakan', 'ID'),
#   ('restart', 'EN'),
#   ('modemnya', 'ID'),
#   ('selama', 'ID'),
#   ('3-5', 'O'),
#   ('menit', 'ID'),
#   ('.', 'O'),
#   ('Jika', 'ID'),
#   ('masih', 'ID'),
#   ('bermasalah', 'ID'),
#   ('segera', 'ID'),
#   ('informasikan', 'ID'),
#   ('kembali', 'ID'),
#   ('via', 'ID'),
#   ('DM', 'EN'),
#   ('guna', 'ID'),
#   ('proses', 'ID'),
#   ('lebih', 'ID'),
#   ('lanjut', 'ID'),
#   (',', 'O'),
#   ('sertakan', 'ID'),
#   ('juga', 'ID'),
#   ('nomor', 'ID'),
#   ('internet', 'ID'),
#   ('dan', 'ID'),
#   ('nomor', 'ID'),
#   ('(1/2)', 'O')],
#  [('@AngeL_jLo', 'O'),
#   ('Iya', 'ID'),
#   ('kak', 'ID'),
#   (',', 'O'),
#   ('dikarekan', 'ID'),
#   ('setiap', 'ID'),
#   ('jalur', 'ID'),
#   ('odp-nya', 'ID'),
#   ('berbeda', 'ID'),
#   ('beda', 'ID'),
#   ('maka', 'ID'),
#   ('gangguan', 'ID'),
#   ('yg', 'ID'),
#   ('dialaminya', 'ID'),
#   ('pun', 'ID'),
#   ('tdk', 'ID'),
#   ('merata', 'ID'),
#   (',', 'O'),
#   ('kami', 'ID'),
#   ('cek', 'ID'),
#   ('saat', 'ID'),
#   ('ini', 'ID'),
#   ('msh', 'ID'),
#   ('dlm', 'ID'),
#   ('pengecekan', 'ID'),
#   ('dan', 'ID'),
#   ('koordinasi', 'ID'),
#   ('petugas', 'ID'),
#   ('teknisi', 'ID'),
#   ('kami', 'ID'),
#   (',', 'O'),
#   ('secepatnya', 'ID'),
#   ('agar', 'ID'),
#   ('koneksi', 'ID'),
#   ('inetnya', 'ID'),
#   ('dpt', 'ID'),
#   ('kembali', 'ID'),
#   ('normal', 'ID'),
#   (',', 'O'),
#   ('info', 'ID'),
#   ('update-nya', 'MIX-ID-EN'),
#   ('kami', 'ID'),
#   ('arahkan', 'ID'),
#   ('via', 'ID'),
#   ('dm', 'EN'),
#   ('(1/2)', 'O')],
#  [('@dw_whyn', 'O'),
#   ('Baik', 'ID'),
#   (',', 'O'),
#   ('Kak', 'ID'),
#   ('.', 'O'),
#   ('Maaf', 'ID'),
#   ('banget', 'ID'),
#   ('ya', 'ID'),
#   ('jadi', 'ID'),
#   ('ga', 'ID'),
#   ('nyaman', 'ID'),
#   ('.', 'O'),
#   ('Jika', 'ID'),
#   ('Kakak', 'ID'),
#   ('berkendala', 'ID'),
#   ('pada', 'ID'),
#   ('koneksi', 'ID'),
#   ('WiFi', 'EN'),
#   ('Indihome', 'O'),
#   (',', 'O'),
#   ('silakan', 'ID'),
#   ('untuk', 'ID'),
#   ('menghubungi', 'ID'),
#   ('rekan', 'ID'),
#   ('mimin', 'ID'),
#   ('di', 'ID'),
#   ('@indihome', 'O'),
#   ('biar', 'ID'),
#   ('dibantu', 'ID'),
#   ('proses', 'ID'),
#   ('selanjutnya', 'ID'),
#   ('ya', 'ID'),
#   (',', 'O'),
#   ('Kak', 'ID'),
#   ('.', 'O'),
#   ('Makasih', 'ID'),
#   (':)', 'O'),
#   ('-', 'O'),
#   ('Angel', 'O')],
#  [('@ManUtd', 'O'),
#   ('Kalah', 'ID'),
#   ('gausa', 'ID'),
#   ('update', 'EN'),
#   (',', 'O'),
#   ('sedih', 'ID'),
#   ('ngene', 'JV'),
#   ('delok', 'JV'),
#   ('mainmu', 'JV'),
#   ('.', 'O'),
#   ('De', 'O'),
#   ('gea', 'O'),
#   (',', 'O'),
#   ('Maguire', 'O'),
#   ('blunder', 'EN'),
#   ('terosssss', 'JV'),
#   ('#MUFC', 'O'),
#   ('#brunofernandes', 'O')],
#  [('Baru', 'ID'),
#   ('update', 'EN'),
#   ('semalem', 'ID'),
#   ('ketiduran', 'ID'),
#   ('soalnya', 'ID'),
#   ('hehe', 'O'),
#   ('.', 'O'),
#   ('Selamat', 'ID'),
#   ('pagi', 'ID'),
#   (',', 'O'),
#   ('pagi', 'ID'),
#   ('disana', 'ID'),
#   ('hujan', 'ID'),
#   ('ngga', 'ID'),
#   ('?', 'O'),
#   ('Oh', 'ID'),
#   ('iya', 'ID'),
#   ('ada', 'ID'),
#   ('beberapa', 'ID'),
#   ('daerah', 'ID'),
#   ('yg', 'ID'),
#   ('kena', 'ID'),
#   ('banjir', 'ID'),
#   ('hati-hati', 'ID'),
#   ('ya', 'ID'),
#   ('stay', 'EN'),
#   ('safe', 'EN'),
#   (':(', 'O')],
#  [('@euisbeling13', 'O'),
#   ('Hati', 'ID'),
#   ('hati', 'ID'),
#   ('nyai', 'ID'),
#   ('.', 'O'),
#   ('Suskes', 'ID'),
#   ('buat', 'ID'),
#   ('projectnya', 'MIX-ID-EN'),
#   ('ya', 'ID'),
#   ('.', 'O'),
#   ('Stay', 'EN'),
#   ('safe', 'EN'),
#   ('plis', 'EN'),
#   ('❤', 'O'),
#   ('️', 'O')],
#  [('Cashbacers', 'O'),
#   ('yang', 'ID'),
#   ('di', 'ID'),
#   ('Jakarta', 'O'),
#   ('dan', 'ID'),
#   ('terdampak', 'ID'),
#   ('banjir', 'ID'),
#   (',', 'O'),
#   ('tetap', 'ID'),
#   ('hati', 'ID'),
#   ('hati', 'ID'),
#   ('ya', 'ID'),
#   (',', 'O'),
#   ('stay', 'EN'),
#   ('safe', 'EN'),
#   ('!', 'O'),
#   ('🥺', 'O')],
#  [('@bigwintha', 'O'),
#   ('Ngeri', 'ID'),
#   ('Ihhh', 'ID'),
#   (',', 'O'),
#   ('hati', 'ID'),
#   ('hati', 'ID'),
#   ('ya', 'ID'),
#   ('paw', 'O'),
#   (',', 'O'),
#   ('Stay', 'EN'),
#   ('safe', 'EN'),
#   ('Pokoknya', 'ID'),
#   (',', 'O'),
#   ('tp', 'ID'),
#   ('km', 'ID'),
#   ('gapapa', 'ID'),
#   ('kan', 'ID'),
#   ('?', 'O'),
#   ('Hati', 'ID'),
#   ('hati', 'ID'),
#   ('pokoknya', 'ID'),
#   (',', 'O'),
#   ('Mungkin', 'ID'),
#   ('lain', 'ID'),
#   ('kali', 'ID'),
#   ('lewat', 'ID'),
#   ('jalan', 'ID'),
#   ('yang', 'ID'),
#   ('ramai', 'ID'),
#   ('dan', 'ID'),
#   ('jgn', 'ID'),
#   ('lupa', 'ID'),
#   ('berdoa', 'ID'),
#   ('..', 'O')],
#  [('Buat', 'ID'),
#   ('temen-temen', 'ID'),
#   ('kalau', 'ID'),
#   ('berkendara', 'ID'),
#   ('hati-hati', 'ID'),
#   ('apalagi', 'ID'),
#   ('di', 'ID'),
#   ('saat', 'ID'),
#   ('musim', 'ID'),
#   ('hujan', 'ID'),
#   ('seperti', 'ID'),
#   ('sekarang', 'ID'),
#   ('.', 'O'),
#   ('Hari', 'ID'),
#   ('ini', 'ID'),
#   ('di', 'ID'),
#   ('jakal', 'ID'),
#   ('atas', 'ID'),
#   ('gw', 'ID'),
#   ('ngeliat', 'ID'),
#   ('2', 'O'),
#   ('kecelakaan', 'ID'),
#   ('yang', 'ID'),
#   ('lumayan', 'ID'),
#   ('parah', 'ID'),
#   (',', 'O'),
#   ('so', 'EN'),
#   ('stay', 'EN'),
#   ('safe', 'EN'),
#   ('dan', 'ID'),
#   ('selalu', 'ID'),
#   ('berhati-hati', 'ID'),
#   ('ya', 'ID'),
#   ('gaes', 'EN'),
#   ('.', 'O'),
#   ('Semoga', 'ID'),
#   ('kita', 'ID'),
#   ('selalu', 'ID'),
#   ('dilindungi', 'ID'),
#   ('dan', 'ID'),
#   ('terhindar', 'ID'),
#   ('dari', 'ID'),
#   ('musibah', 'ID'),
#   (',', 'O'),
#   ('aamiin', 'ID')],
#  [('Udah', 'ID'),
#   ('pamit', 'ID'),
#   ('pulang', 'ID'),
#   ('jam', 'ID'),
#   ('9', 'O'),
#   ('tapi', 'ID'),
#   ('laptop', 'ID'),
#   ('ngehang', 'MIX-ID-EN'),
#   ('gabisa', 'ID'),
#   ('dimatiin', 'ID'),
#   ('udah', 'ID'),
#   ('gitu', 'ID'),
#   ('perlu', 'ID'),
#   ('update', 'EN'),
#   ('Ya', 'ID'),
#   ('Allah', 'O'),
#   ('alamat', 'ID'),
#   ('dimarahin', 'ID'),
#   ('bapack', 'ID'),
#   ('ini', 'ID'),
#   ('mah', 'ID')],
#  [('KIM', 'O'),
#   ('HONGJOONG', 'O'),
#   (',', 'O'),
#   ('menerima', 'ID'),
#   ('segala', 'ID'),
#   ('jenis', 'ID'),
#   ('revisi', 'ID'),
#   ('.', 'O'),
#   ('Pas', 'ID'),
#   ('udah', 'ID'),
#   ('dikejar', 'ID'),
#   ('deadline', 'EN'),
#   (',', 'O'),
#   ('laptop', 'ID'),
#   ('tiba-tiba', 'ID'),
#   ('ngehang', 'MIX-ID-EN'),
#   ('terus', 'ID'),
#   ('mesti', 'ID'),
#   ('di', 'ID'),
#   ('ketok-ketok', 'ID'),
#   ('dulu', 'ID'),
#   ('baru', 'ID'),
#   ('bener', 'ID'),
#   ('.', 'O'),
#   ('https://t.co/bNv9VQYVDD', 'O')],
#  [('Laptop', 'ID'),
#   ('gua', 'ID'),
#   ('ngehang', 'MIX-ID-EN'),
#   ('bangsatttt', 'ID'),
#   ('https://t.co/KRi8JifvMy', 'O')],
#  [('Laptop', 'ID'),
#   ('cuman', 'ID'),
#   ('dipake', 'ID'),
#   ('ngedit', 'ID'),
#   ('cv', 'EN'),
#   ('ama', 'ID'),
#   ('excel', 'O'),
#   ('ngitungin', 'ID'),
#   ('utang', 'ID'),
#   ('priwil', 'O'),
#   ('aja', 'ID'),
#   ('ngehang', 'MIX-ID-EN'),
#   ('.', 'O'),
#   ('Bajigur2', 'JV')],
#  [('Lagi', 'ID'),
#   ('ngerjain', 'ID'),
#   ('ppt', 'EN'),
#   (',', 'O'),
#   ('laptop', 'ID'),
#   ('w', 'ID'),
#   ('tiba2', 'ID'),
#   ('ngehang', 'MIX-ID-EN'),
#   (',', 'O'),
#   ('g', 'ID'),
#   ('mau', 'ID'),
#   ('diketik', 'ID'),
#   ('apapun', 'ID'),
#   ('.', 'O'),
#   ('And', 'EN'),
#   ('then', 'EN'),
#   ('mati', 'ID'),
#   ('👍', 'O')],
#  [('zumpah', 'ID'),
#   ('w', 'ID'),
#   ('udh', 'ID'),
#   ('ngerjain', 'ID'),
#   ('excel', 'O'),
#   ('smpe', 'ID'),
#   ('selesai', 'ID'),
#   (',', 'O'),
#   ('then', 'EN'),
#   ('laptop', 'ID'),
#   ('e', 'JV'),
#   ('ngehang', 'MIX-ID-EN'),
#   ('blm', 'ID'),
#   ('w', 'ID'),
#   ('save', 'EN'),
#   ('.', 'O'),
#   ('nangis', 'ID'),
#   ('bgt', 'ID')],
#  [('Udah', 'ID'),
#   ('lama', 'ID'),
#   ('ga', 'ID'),
#   ('ngehang', 'MIX-ID-EN'),
#   ('trs', 'ID'),
#   ('barusan', 'ID'),
#   ('ngehang', 'MIX-ID-EN'),
#   ('lagi', 'ID'),
#   ('laptop', 'ID'),
#   ('gila', 'ID')],
#  [('Berjam', 'ID'),
#   ('jam', 'ID'),
#   ('buka', 'ID'),
#   ('laptop', 'ID'),
#   ('niatnya', 'ID'),
#   ('mau', 'ID'),
#   ('bikin', 'ID'),
#   ('cover', 'EN'),
#   ('letter', 'EN'),
#   ('dan', 'ID'),
#   ('persiapan', 'ID'),
#   ('nyebar', 'JV'),
#   ('lamaran', 'ID'),
#   ('.', 'O'),
#   ('Fact', 'EN'),
#   (':', 'O'),
#   ('laptop', 'ID'),
#   ('ngehang', 'MIX-ID-EN'),
#   ('mulu', 'ID'),
#   ('Akhirnya', 'ID'),
#   ('yak', 'ID'),
#   ('ga', 'ID'),
#   ('jadi', 'ID'),
#   ('jadi', 'ID'),
#   (':")', 'O')],
#  [('Wis', 'JV'),
#   ('lah', 'ID'),
#   ('...', 'O'),
#   ('tidur', 'ID'),
#   ('lg', 'ID'),
#   ('ajahh', 'ID'),
#   ('..', 'O'),
#   ('Hawane', 'JV'),
#   ('cocok', 'ID'),
#   ('e', 'JV'),
#   ('go', 'JV'),
#   ('turuuu', 'JV')],
#  [('Mumet', 'JV'),
#   ('mikir', 'JV'),
#   ('konsep', 'ID'),
#   ('vlog', 'EN'),
#   (',', 'O'),
#   ('ketambah', 'JV'),
#   ('mumet', 'JV'),
#   ('nyawang', 'JV'),
#   ('maine', 'JV'),
#   ('MU', 'O'),
#   ('.', 'O'),
#   ('Main', 'JV'),
#   ('koyok', 'JV'),
#   ('tim', 'ID'),
#   ('Liga', 'O'),
#   ('3', 'O'),
#   ('Indonesia', 'O'),
#   ('cok', 'JV'),
#   ('.', 'O'),
#   ('Passing', 'EN'),
#   ('ra', 'JV'),
#   ('nggenah', 'JV'),
#   ('.', 'O'),
#   ('Apik', 'JV'),
#   ('lawan', 'JV'),
#   ('big', 'EN'),
#   ('six', 'EN'),
#   (',', 'O'),
#   ('lawan', 'JV'),
#   ('tim', 'ID'),
#   ('laine', 'MIX-ID-JV'),
#   ('bapuk', 'JV'),
#   (',', 'O'),
#   ('bosokkkk', 'JV'),
#   ('.', 'O'),
#   ('Cc', 'EN'),
#   (':', 'O'),
#   ('@ManUtd', 'O'),
#   ('@ManUtd_ID', 'O')],
#  [('Rumangsane', 'JV'),
#   ('Indonesia', 'O'),
#   ('kalah', 'JV'),
#   ('3-0', 'O'),
#   ('mergo', 'JV'),
#   ('Vietnam', 'O'),
#   ('maine', 'JV'),
#   ('apik', 'JV'),
#   ('?', 'O'),
#   ('Yo', 'JV'),
#   ('ora', 'JV'),
#   ('lah', 'JV'),
#   (',', 'O'),
#   ('pancen', 'JV'),
#   ('niat', 'JV'),
#   ('ngeprank', 'MIX-JV-EN'),
#   ('kok', 'JV'),
#   ('.', 'O'),
#   ('Edan', 'JV'),
#   ('po', 'JV'),
#   ('😜', 'O'),
#   ('🇲', 'O'),
#   ('🇨', 'O'),
#   ('🇲', 'O'),
#   ('🇨', 'O'),
#   ('🇲', 'O'),
#   ('🇨', 'O')],
#  [('Indonesia', 'O'),
#   ('maine', 'JV'),
#   ('apik', 'JV'),
#   ('tapi', 'JV'),
#   ('end', 'EN'),
#   ('passing', 'EN'),
#   ('karo', 'JV'),
#   ('finishing', 'EN'),
#   ('e', 'JV'),
#   ('remuk', 'ID'),
#   ('sekali', 'ID')],
#  [('Maine', 'JV'),
#   ('timnas', 'ID'),
#   ('Indonesia', 'O'),
#   ('luwih', 'JV'),
#   ('apik', 'JV'),
#   ('timbang', 'JV'),
#   ('AS', 'O'),
#   ('Roma', 'O'),
#   ('.', 'O'),
#   ('Jujur', 'ID'),
#   ('.', 'O')],
#  [('Maine', 'JV'),
#   ('wes', 'JV'),
#   ('apik', 'JV'),
#   ('min', 'ID'),
#   (',', 'O'),
#   ('Indonesia', 'O'),
#   ('Asli', 'JV'),
#   ('iki', 'JV'),
#   ('mau', 'JV'),
#   ('....', 'O'),
#   ('😂', 'O'),
#   ('leg', 'EN'),
#   ('2', 'O'),
#   ('metu', 'JV'),
#   ('Indonesia', 'O'),
#   ('sing', 'JV'),
#   ('ngeropa', 'JV'),
#   ('🤣', 'O'),
#   ('🤣', 'O')],
#  [('Iki', 'JV'),
#   ('indonesia', 'O'),
#   ('opo', 'JV'),
#   ('mancity', 'O'),
#   ('?', 'O'),
#   ('Maine', 'JV'),
#   ('apik', 'JV'),
#   ('men', 'JV'),
#   ('#TimnasDay', 'O')],
#  [('@diijeeh', 'O'),
#   ('@MediaRakyat_', 'O'),
#   ('Bener', 'ID'),
#   ('itu', 'ID'),
#   ('mbak', 'ID'),
#   ('.', 'O'),
#   ('Masuk', 'ID'),
#   ('got', 'ID'),
#   ('aja', 'ID'),
#   ('yg', 'ID'),
#   ('perlu', 'ID'),
#   ('bawa²', 'ID'),
#   ('camera', 'EN'),
#   ('.', 'O')],
#  [('tiba', 'ID'),
#   ('tiba', 'ID'),
#   ('masuk', 'ID'),
#   ('nominasi', 'ID'),
#   ('aja', 'ID'),
#   ('gitu', 'ID'),
#   ('.', 'O'),
#   ('(', 'O'),
#   ('I', 'EN'),
#   ('really', 'EN'),
#   ('dont', 'EN'),
#   ('know', 'EN'),
#   ('what', 'EN'),
#   ('i', 'EN'),
#   ('talked', 'EN'),
#   ('about', 'EN'),
#   ('here', 'EN'),
#   ('since', 'EN'),
#   ('i', 'EN'),
#   ('never', 'EN'),
#   ('got', 'ID'),
#   ('nominated', 'EN'),
#   ('for', 'EN'),
#   ('anything', 'EN'),
#   ('?', 'O'),
#   (')', 'O'),
#   ('Dan', 'ID'),
#   ('disitu', 'ID'),
#   ('aku', 'ID'),
#   ('mikirnya', 'ID'),
#   ('antara', 'ID'),
#   ('pak', 'ID'),
#   ('bos', 'ID'),
#   ('pengen', 'ID'),
#   ('anak', 'ID'),
#   ('buahnya', 'ID'),
#   ('masuk', 'ID'),
#   ('nominasi', 'ID'),
#   ('juga', 'ID'),
#   ('atau', 'ID'),
#   ('bikin', 'ID'),
#   ('nominasi', 'ID'),
#   ('sendiri', 'ID'),
#   ('wkwkw', 'O'),
#   ('aneh', 'ID'),
#   ('emang', 'ID')],
#  [('mikir', 'ID'),
#   ('mau', 'ID'),
#   ('masuk', 'ID'),
#   ('jurusan', 'ID'),
#   ('apa', 'ID'),
#   ('tpi', 'ID'),
#   ('mikir', 'ID'),
#   ('masuk', 'ID'),
#   ('ipa', 'ID'),
#   ('/', 'O'),
#   ('ips', 'ID'),
#   ('aja', 'ID'),
#   ('belom', 'ID'),
#   ('😭', 'O')],
#  [('@dayeniii', 'O'),
#   ('Gw', 'ID'),
#   ('aja', 'ID'),
#   ('sampai', 'ID'),
#   ('keleyengan', 'ID'),
#   ('ampir', 'ID'),
#   ('masuk', 'ID'),
#   ('got', 'ID'),
#   ('dulu', 'ID')],
#  [('tapi', 'ID'),
#   ('emg', 'ID'),
#   ('lu', 'ID'),
#   ('ganteng', 'ID'),
#   ('bgt', 'ID'),
#   (',', 'O'),
#   ('sering2', 'ID'),
#   ('berulah', 'ID'),
#   ('aja', 'ID'),
#   ('biar', 'ID'),
#   ('foto', 'ID'),
#   ('lu', 'ID'),
#   ('bisa', 'ID'),
#   ('masuk', 'ID'),
#   ('galeri', 'ID'),
#   ('gue', 'ID'),
#   ('🤩', 'O')],
#  [('Sebagai', 'ID'),
#   ('dinonara', 'O'),
#   ('akut', 'ID'),
#   (',', 'O'),
#   ('seneng', 'ID'),
#   ('bgt', 'ID'),
#   ('Dino', 'O'),
#   ('finally', 'EN'),
#   ('got', 'ID'),
#   ('the', 'EN'),
#   ('recognition', 'EN'),
#   ('he', 'EN'),
#   ('deserves', 'EN'),
#   ('.', 'O'),
#   ('Sekarang', 'ID'),
#   ('sering', 'ID'),
#   ('trending', 'EN'),
#   (',', 'O'),
#   ('brand', 'EN'),
#   ('reputation', 'EN'),
#   ('juga', 'ID'),
#   ('udah', 'ID'),
#   ('masuk', 'ID'),
#   ('top', 'ID'),
#   ('20', 'O'),
#   (',', 'O'),
#   ('sering', 'ID'),
#   ('dapet', 'ID'),
#   ('komen', 'ID'),
#   ('di', 'ID'),
#   ('youtube', 'EN'),
#   ('ttg', 'ID'),
#   ('dia', 'ID'),
#   ('.', 'O'),
#   ('Seseneng', 'ID'),
#   ('itu', 'ID'),
#   ('.', 'O'),
#   ('Krn', 'ID'),
#   ('dulu', 'ID'),
#   ('jangankan', 'ID'),
#   ('trending', 'EN'),
#   (',', 'O'),
#   ('diwaro', 'O'),
#   ('aja', 'ID'),
#   ('engga', 'ID'),
#   ('.', 'O'),
#   ('So', 'EN'),
#   ('happy', 'EN'),
#   ('🥺', 'O'),
#   ('❤', 'O'),
#   ('️', 'O'),
#   ('https://t.co/1V4phtNXOB', 'O')],
#  [('@joyfulnim', 'O'),
#   ('Kalau', 'ID'),
#   ('gitu', 'ID'),
#   ('mari', 'ID'),
#   ('menunggu', 'ID'),
#   (',', 'O'),
#   ('wendy', 'EN'),
#   ('kan', 'ID'),
#   ('anaknya', 'ID'),
#   ('suka', 'ID'),
#   ('ngasih', 'ID'),
#   ('surprise', 'EN'),
#   (',', 'O'),
#   ('pas', 'ID'),
#   ('harintu', 'ID'),
#   ('aja', 'ID'),
#   ('bilangnya', 'ID'),
#   ('lagi', 'ID'),
#   ('bersih-bersih', 'ID'),
#   ('rumah', 'ID'),
#   (',', 'O'),
#   ('tapi', 'ID'),
#   ('tau-tau', 'ID'),
#   ('masuk', 'ID'),
#   ('ke', 'ID'),
#   ('line', 'EN'),
#   ('up', 'EN'),
#   ('GOT', 'O'),
#   ('🙃', 'O')],
#  [('@ntsani__', 'O'),
#   ('@kokooamilo_', 'O'),
#   ('@adulkittipOorn', 'O'),
#   ('@moviemenfes', 'O'),
#   ('TAPI', 'ID'),
#   ('NGELIAT', 'ID'),
#   ('WAJAHNYA', 'ID'),
#   ('AJA', 'ID'),
#   ('BIKIN', 'ID'),
#   ('KETAWA', 'ID'),
#   (',', 'O'),
#   ('mana', 'ID'),
#   ('pas', 'ID'),
#   ('jatoh', 'ID'),
#   ('ke', 'ID'),
#   ('got', 'ID'),
#   ('sampe', 'ID'),
#   ('masuk', 'ID'),
#   ('berita', 'ID'),
#   ('kayak', 'ID'),
#   ('udah', 'ID'),
#   ('terima', 'ID'),
#   ('nasib', 'ID'),
#   ('😭', 'O'),
#   ('😭', 'O'),
#   ('😭', 'O')],
#  [('Gilakk', 'ID'),
#   ('mau', 'ID'),
#   ('masuk', 'ID'),
#   ('paypal', 'O'),
#   ('aja', 'ID'),
#   ('2', 'O'),
#   ('menit', 'ID'),
#   ('😨', 'O'),
#   ('😨', 'O'),
#   ('😨', 'O'),
#   ('got', 'EN'),
#   ('mood', 'EN'),
#   ('lamp', 'EN'),
#   ('at', 'EN'),
#   ('least', 'EN'),
#   ('\U0001f972', 'O'),
#   ('✊', 'O'),
#   ('🏻', 'O')],
#  [('-', 'O'),
#   ('close', 'EN'),
#   ('sorry', 'EN'),
#   ('ya', 'ID'),
#   ('tiba', 'ID'),
#   ('tiba', 'ID'),
#   (',', 'O'),
#   ('sebelumnya', 'ID'),
#   ('gue', 'ID'),
#   ('terimakasih', 'ID'),
#   ('buat', 'ID'),
#   ('kalian', 'ID'),
#   ('karna', 'ID'),
#   ('udh', 'ID'),
#   ('selalu', 'ID'),
#   ('ada', 'ID'),
#   ('buat', 'ID'),
#   ('gue', 'ID'),
#   (',', 'O'),
#   ('udh', 'ID'),
#   ('mau', 'ID'),
#   ('jadi', 'ID'),
#   ('tmn', 'ID'),
#   ('baik', 'ID'),
#   ('gue', 'ID'),
#   (',', 'O'),
#   ('and', 'EN'),
#   ('sorry', 'EN'),
#   ('kalo', 'ID'),
#   ('gue', 'ID'),
#   ('mungkin', 'ID'),
#   ('pernah', 'ID'),
#   ('bikin', 'ID'),
#   ('kalian', 'ID'),
#   ('semua', 'ID'),
#   ('sakit', 'ID'),
#   ('hati', 'ID'),
#   ('sama', 'ID'),
#   ('ucapan', 'ID'),
#   ('gue', 'ID'),
#   ('..', 'O'),
#   ('stay', 'EN'),
#   ('safe', 'EN'),
#   ('and', 'EN'),
#   ('be', 'EN'),
#   ('happy', 'EN'),
#   ('moots', 'EN')],
#  [('@tranexamicc', 'O'),
#   ('Adist', 'O'),
#   ('hati-hati', 'ID'),
#   ('ya', 'ID'),
#   ('sm', 'ID'),
#   ('ibunya', 'ID'),
#   ('...', 'O'),
#   ('Stay', 'EN'),
#   ('safe', 'EN'),
#   ('.', 'O'),
#   ('Please', 'EN'),
#   ('kl', 'ID'),
#   ('ada', 'ID'),
#   ('apa-apa', 'ID'),
#   ('siapin', 'ID'),
#   ('kontak', 'ID'),
#   ('darurat', 'ID'),
#   ('ke', 'ID'),
#   ('sodara', 'ID'),
#   ('/', 'O'),
#   ('temen', 'ID'),
#   ('deket', 'ID'),
#   ('....', 'O'),
#   ('Cari', 'ID'),
#   ('alamat', 'ID'),
#   ('polisi', 'ID'),
#   ('terdekat', 'ID'),
#   ('jg', 'ID'),
#   ('semisal', 'ID'),
#   ('ada', 'ID'),
#   ('knp2', 'ID'),
#   ('lagii', 'ID')],
#  [('@oneechannnn_0', 'O'),
#   ('Hi', 'EN'),
#   ('kak', 'ID'),
#   ('semangat', 'ID'),
#   ('terus', 'ID'),
#   ('yahh', 'ID'),
#   ('moga', 'ID'),
#   ('dikesempatan', 'ID'),
#   ('berikutnya', 'ID'),
#   ('kaka', 'EN'),
#   ('bisa', 'ID'),
#   ('menang', 'ID'),
#   ('.', 'O'),
#   ('yuk', 'ID'),
#   ('cek', 'ID'),
#   ('postingan', 'MIX-ID-EN'),
#   ('terbaru', 'ID'),
#   ('mimin', 'ID'),
#   ('biar', 'ID'),
#   ('ga', 'ID'),
#   ('ketinggalan', 'ID'),
#   ('info', 'ID'),
#   ('menarik', 'ID'),
#   ('lainnya', 'ID'),
#   ('have', 'EN'),
#   ('a', 'EN'),
#   ('good', 'EN'),
#   ('day', 'EN'),
#   ('.', 'O'),
#   ('😊', 'O'),
#   ('^RB', 'O')],
#  [('@MarsellaDwi8', 'O'),
#   ('Bismillah', 'ID'),
#   ('dan', 'ID'),
#   ('semangat', 'ID'),
#   ('terus', 'ID'),
#   ('yaah', 'ID'),
#   ('kak', 'ID'),
#   (',', 'O'),
#   ('mimin', 'ID'),
#   ('support', 'EN'),
#   ('kamu', 'ID'),
#   ('semoga', 'ID'),
#   ('menang', 'ID'),
#   ('ya', 'ID'),
#   ('kak', 'ID'),
#   ('.', 'O'),
#   ('Good', 'EN'),
#   ('luck', 'EN'),
#   ('kak', 'ID'),
#   (':)', 'O'),
#   ('^TN', 'O')],
#  [('Bagus', 'ID'),
#   ('!', 'O'),
#   ('gue', 'ID'),
#   ('lomba', 'ID'),
#   ('juara', 'ID'),
#   ('satu', 'ID'),
#   ('kemaren', 'ID'),
#   (',', 'O'),
#   ('terus', 'ID'),
#   ('waktu', 'ID'),
#   ('itu', 'ID'),
#   ('menang', 'ID'),
#   ('lagi', 'ID'),
#   ('juara', 'ID'),
#   ('dua', 'ID'),
#   ('.', 'O'),
#   ("i'm", 'EN'),
#   ('good', 'EN'),
#   ('at', 'EN'),
#   ('talking', 'EN'),
#   ('in', 'EN'),
#   ('public', 'EN'),
#   (',', 'O'),
#   ('karna', 'ID'),
#   ('extrovert', 'EN'),
#   ('juga', 'ID'),
#   ('jadi', 'ID'),
#   ('ngebantu', 'ID'),
#   ('hehe', 'O')],
#  [('Kalo', 'ID'),
#   ('disakiti', 'ID'),
#   ('dan', 'ID'),
#   ('kita', 'ID'),
#   ('balas', 'ID'),
#   ('menyakiti', 'ID'),
#   ('itu', 'ID'),
#   ('boleh', 'ID'),
#   ('itu', 'ID'),
#   ('adil', 'ID'),
#   ('itu', 'ID'),
#   ('sah', 'ID'),
#   ('impas', 'ID'),
#   ('tapi', 'ID'),
#   ('nilainya', 'ID'),
#   ('0', 'O'),
#   (',', 'O'),
#   ('kalo', 'ID'),
#   ('dalam', 'ID'),
#   ('sepak', 'ID'),
#   ('bola', 'ID'),
#   ('seri', 'ID'),
#   ('.', 'O'),
#   ('Tidak', 'ID'),
#   ('ada', 'ID'),
#   ('yang', 'ID'),
#   ('menang', 'ID'),
#   ('tidak', 'ID'),
#   ('ada', 'ID'),
#   ('yang', 'ID'),
#   ('kalah', 'ID'),
#   ('dan', 'ID'),
#   ('derajatnya', 'ID'),
#   ('sama', 'ID'),
#   (',', 'O'),
#   ('kita', 'ID'),
#   ('tak', 'ID'),
#   ('lebih', 'ID'),
#   ('baik', 'ID'),
#   ('dari', 'ID'),
#   ('yang', 'ID'),
#   ('menyakiti', 'ID'),
#   ('kita', 'ID'),
#   (',', 'O'),
#   ('sama', 'ID'),
#   ('aja', 'ID'),
#   ('podo', 'JV'),
#   ('wae', 'JV'),
#   ('.', 'O')],
#  [('@RioAndr88', 'O'),
#   ('@Nataclan', 'O'),
#   ('@aardwi15', 'O'),
#   ('@rizkyyyfaisal', 'O'),
#   ('@Sport77Official', 'O'),
#   ('Kalau', 'ID'),
#   ('misal', 'ID'),
#   ('kuat', 'ID'),
#   ('full', 'EN'),
#   ('90', 'O'),
#   ('menit', 'ID'),
#   (',', 'O'),
#   ('tp', 'ID'),
#   ('sering', 'ID'),
#   ('hilang', 'ID'),
#   ('bola', 'ID'),
#   ('dan', 'ID'),
#   ('sering', 'ID'),
#   ('kalah', 'ID'),
#   ('duel', 'ID'),
#   ('gmn', 'ID'),
#   ('??', 'O'),
#   ('Kalau', 'ID'),
#   ('Spaso', 'O'),
#   ('justru', 'ID'),
#   ('punya', 'ID'),
#   ('kelebihan', 'ID'),
#   ('kalau', 'ID'),
#   ('dapet', 'ID'),
#   ('bola²', 'ID'),
#   ('mati', 'ID'),
#   ('.', 'O'),
#   ('Toh', 'ID'),
#   ('STY', 'O'),
#   ('jg', 'ID'),
#   ('sering', 'ID'),
#   ('kok', 'ID'),
#   ('rotasi', 'ID'),
#   ('striker', 'ID'),
#   (',', 'O'),
#   ('menurutku', 'ID'),
#   ('sih', 'ID'),
#   ('opsi', 'ID'),
#   ('ya', 'ID'),
#   ('kalau', 'ID'),
#   ('Spaso', 'O'),
#   ('.', 'O')],
#  [('@northerncsl', 'O'),
#   ('Model2', 'JV'),
#   ('ngene', 'JV'),
#   ('kalah', 'JV'),
#   ('ngolek', 'JV'),
#   ('salah', 'JV'),
#   ('e', 'JV'),
#   ('siji', 'JV'),
#   ('loro', 'JV'),
#   ('pemain', 'JV'),
#   ('.', 'O'),
#   ('Menang', 'JV'),
#   ('horeee', 'ID'),
#   ('...', 'O'),
#   ('Pemain', 'JV'),
#   ('arep', 'JV'),
#   ('main', 'JV'),
#   ('neng', 'JV'),
#   ('sleman', 'O'),
#   ('wegah', 'JV'),
#   ('di', 'JV'),
#   ('paido', 'JV'),
#   ('wae', 'JV'),
#   ('...', 'O'),
#   ('dari', 'ID'),
#   ('video', 'ID'),
#   ('lawan', 'ID'),
#   ('persiraja', 'O'),
#   ('kelihatan', 'ID'),
#   ('aliran', 'ID'),
#   ('bola', 'ID'),
#   ('lambat', 'ID'),
#   ('lawan', 'ID'),
#   ('.', 'O'),
#   ('presing', 'EN'),
#   ('ketat', 'ID'),
#   ('mesti', 'ID'),
#   ('kedodoran', 'ID'),
#   ('wong', 'JV'),
#   ('belum', 'ID'),
#   ('nyetel', 'ID')],
#  [('@xylemfloemm', 'O'),
#   ('Aku', 'ID'),
#   ('selalu', 'ID'),
#   ('membuat', 'ID'),
#   ('kesalahan', 'ID'),
#   ('kalau', 'ID'),
#   ('nonton', 'ID'),
#   ('bola', 'ID'),
#   ('sama', 'ID'),
#   ('badminton', 'ID'),
#   (',', 'O'),
#   ('udh', 'ID'),
#   ('tau', 'ID'),
#   ('lawan', 'ID'),
#   ('nya', 'ID'),
#   ('bagus', 'ID'),
#   (',', 'O'),
#   ('ngarep', 'JV'),
#   ('menang', 'ID'),
#   ('tp', 'ID'),
#   ('pd', 'ID'),
#   ('akhirnya', 'ID'),
#   ('kalah', 'ID'),
#   ('.', 'O'),
#   ('Dan', 'ID'),
#   ('kalau', 'ID'),
#   ('mereka', 'ID'),
#   ('main', 'ID'),
#   ('lagi', 'ID'),
#   ('aku', 'JV'),
#   ('tetep', 'JV'),
#   ('wae', 'JV'),
#   ('ngono', 'JV'),
#   ('👀', 'O')],
#  [('Seko', 'JV'),
#   ('kontrol', 'ID'),
#   ('bola', 'ID'),
#   ('ne', 'JV'),
#   ('wae', 'JV'),
#   ('wes', 'JV'),
#   ('ketok', 'JV'),
#   ('kalah', 'JV'),
#   ('kelas', 'JV'),
#   ('lho', 'JV'),
#   ('...', 'O')],
#  [('Timnas', 'ID'),
#   ('bola', 'ID'),
#   ('kita', 'ID'),
#   ('sudah', 'ID'),
#   ('biasa', 'ID'),
#   ('kalah', 'ID'),
#   (',', 'O'),
#   (',', 'O'),
#   (',', 'O'),
#   ('jadi', 'ID'),
#   ('biasa', 'JV'),
#   ('wae', 'JV'),
#   ('...', 'O')],
#  [('@MafiaWasit', 'O'),
#   ('Yo', 'JV'),
#   ('pie', 'JV'),
#   ('mbah', 'JV'),
#   ('kene', 'JV'),
#   ('level', 'ID'),
#   ('e', 'JV'),
#   ('ijih', 'JV'),
#   ('mlebu', 'JV'),
#   ('kamar', 'ID'),
#   ('ganti', 'ID'),
#   ('timnas', 'ID'),
#   ('dinggo', 'JV'),
#   ('konten', 'ID'),
#   ('og', 'JV'),
#   (',', 'O'),
#   ('bola', 'ID'),
#   ('dinggo', 'JV'),
#   ('alat', 'ID'),
#   ('politik', 'ID'),
#   ('eh', 'ID'),
#   ('ternyata', 'ID'),
#   ('kalah', 'JV'),
#   ('pas', 'JV'),
#   ('pilihan', 'JV'),
#   ('njuk', 'JV'),
#   ('klub', 'ID'),
#   ('e', 'JV'),
#   ('ditinggal', 'JV'),
#   ('ngono', 'JV'),
#   ('wae', 'JV'),
#   (',', 'O'),
#   ('karo', 'JV'),
#   ('isih', 'JV'),
#   ('konsisten', 'ID'),
#   ('terhadap', 'ID'),
#   ('inkonsistensi', 'ID'),
#   ('hukuman', 'ID'),
#   ('yang', 'ID'),
#   ('timpang', 'ID'),
#   ('untuk', 'ID'),
#   ('pemain', 'ID'),
#   ('dilapangan', 'ID')],
#  [('menang', 'ID'),
#   ('ngebully', 'MIX-ID-EN'),
#   ('kalah', 'JV'),
#   ('ora', 'JV'),
#   ('trimo', 'JV'),
#   (',', 'O'),
#   ('kabeh', 'JV'),
#   ('kabeh', 'JV'),
#   ('disalahke', 'JV'),
#   ('.', 'O'),
#   ('yen', 'JV'),
#   ('tim', 'ID'),
#   ('e', 'JV'),
#   ('kesayangane', 'MIX-ID-JV'),
#   ('kalah', 'ID'),
#   (',', 'O'),
#   ('dibully', 'MIX-JV-EN'),
#   ('genti', 'JV'),
#   ('alesanne', 'JV'),
#   ('ono', 'JV'),
#   ('wae', 'JV'),
#   ('persepsine', 'MIX-ID-JV'),
#   ('.', 'O'),
#   ('fans', 'EN'),
#   ('fanatik', 'ID'),
#   ('sepak', 'ID'),
#   ('bola', 'ID'),
#   ('be', 'EN'),
#   ('like', 'EN'),
#   (':', 'O'),
#   ('https://t.co/IV5H7JTBea', 'O')],
#  [('Indonesia', 'O'),
#   ('sing', 'JV'),
#   ('seneng', 'JV'),
#   ('ngefans', 'MIX-ID-EN'),
#   ('bola', 'ID'),
#   ('paling', 'JV'),
#   ('akeh', 'JV'),
#   ('tapi', 'JV'),
#   ('lali', 'JV'),
#   ('bakat', 'JV'),
#   ('e', 'JV'),
#   ('nonton', 'JV'),
#   ('tok', 'ID'),
#   ('ora', 'JV'),
#   ('bakat', 'JV'),
#   ('main', 'JV'),
#   ('bal', 'JV'),
#   ('wkwk', 'O'),
#   ('...', 'O'),
#   ('mbok', 'JV'),
#   ('wes', 'JV'),
#   ('trimo', 'JV'),
#   ('wae', 'JV'),
#   ('nek', 'JV'),
#   ('kalah', 'JV'),
#   ('neh', 'JV'),
#   ('...', 'O')],
#  [('Wess', 'JV'),
#   ('ngene', 'JV'),
#   ('wae', 'JV'),
#   ('skenario', 'ID'),
#   ('ne', 'JV'),
#   ('prennn', 'EN'),
#   ('...', 'O'),
#   ('Pokoke', 'JV'),
#   ('para', 'ID'),
#   ('pejuang', 'ID'),
#   ('slot', 'EN'),
#   ('bola', 'ID'),
#   ('kudu', 'JV'),
#   ('bersatu', 'ID'),
#   ('...', 'O'),
#   ('Carane', 'JV'),
#   ('Kabeh', 'JV'),
#   ('pasang', 'JV'),
#   ('gawe', 'JV'),
#   ('Thailand', 'O'),
#   (',', 'O'),
#   ('gawe', 'JV'),
#   ('bandar', 'JV'),
#   ('bingung', 'JV'),
#   ('.', 'O'),
#   ('Njuk', 'JV'),
#   ('berusaha', 'ID'),
#   ('piye', 'JV'),
#   ('carane', 'JV'),
#   ('Ben', 'JV'),
#   ('bandar', 'JV'),
#   ('ora', 'JV'),
#   ('rugi', 'JV'),
#   ('...', 'O'),
#   ('Mesti', 'JV'),
#   ('bandar', 'JV'),
#   ('golek', 'JV'),
#   ('cara', 'ID'),
#   ('untuk', 'ID'),
#   ('memenangkan', 'ID'),
#   ('Indonesia', 'O'),
#   ('.', 'O'),
#   ('Umpomo', 'JV'),
#   ('ttp', 'JV'),
#   ('kalah', 'JV'),
#   (',', 'O'),
#   ('awak', 'JV'),
#   ('Dewe', 'JV'),
#   ('tetep', 'JV'),
#   ('JP', 'O'),
#   ('.', 'O')],
#  [('@sertralineyunki', 'O'),
#   ('At', 'EN'),
#   ('this', 'EN'),
#   ('point', 'EN'),
#   ('kayak', 'ID'),
#   ('maksa', 'ID'),
#   ('banget', 'ID'),
#   ('ga', 'ID'),
#   ('sih', 'ID'),
#   ('doi', 'ID'),
#   ('😭', 'O'),
#   ('😭', 'O'),
#   ('😭', 'O')],
#  [('happy', 'EN'),
#   ('ending', 'EN'),
#   ('kui', 'JV'),
#   ('mitos', 'ID'),
#   ('nyatane', 'JV'),
#   (',', 'O'),
#   ('opo', 'JV'),
#   ('*', 'O'),
#   ('kudu', 'JV'),
#   ('berjuangan', 'ID'),
#   ('tekane', 'JV'),
#   ('mati', 'JV'),
#   ('bahagia', 'ID'),
#   ('wae', 'JV'),
#   ('selagi', 'ID'),
#   ('iso', 'JV'),
#   ('penting', 'JV'),
#   ('ora', 'JV'),
#   ('merugikan', 'ID'),
#   ('wonglio', 'JV'),
#   ('😎', 'O')],
#  [('ud', 'ID'),
#   ('ngedonlot', 'MIX-ID-EN'),
#   ('film', 'ID'),
#   ('..', 'O'),
#   ('mlm', 'JV'),
#   ('ini', 'ID'),
#   ('mau', 'ID'),
#   ('nont', 'ID'),
#   ('aja', 'ID'),
#   ('dirmh', 'ID'),
#   ('😍', 'O'),
#   ('yg', 'ID'),
#   ('mau', 'ID'),
#   ('kirim', 'ID'),
#   ('cemilan', 'ID'),
#   ('ditunggu', 'ID'),
#   ('ya', 'ID'),
#   ('🥯', 'O'),
#   ('🥮', 'O'),
#   ('🍜', 'O'),
#   ('🍝', 'O'),
#   ('🍛', 'O'),
#   ('🎂', 'O'),
#   ('🍰', 'O'),
#   ('🍮', 'O'),
#   ('🧁', 'O'),
#   ('🍦', 'O'),
#   ('🍩', 'O'),
#   ('☕', 'O'),
#   ('🧃', 'O'),
#   ('🍿', 'O'),
#   ('🍿', 'O')],
#  [('Banyak', 'ID'),
#   ('ngehapus', 'ID'),
#   ('foto', 'ID'),
#   ('digaleri', 'ID'),
#   ('gara2', 'ID'),
#   ('ngedonlot', 'MIX-ID-EN'),
#   ('film', 'ID'),
#   ('😌', 'O')],
#  [('@sbmptnfess', 'O'),
#   ('Udh', 'ID'),
#   ('sekian', 'ID'),
#   ('purnama', 'ID'),
#   ('aku', 'ID'),
#   ('nahan', 'JV'),
#   ('nonton', 'ID'),
#   ('film', 'ID'),
#   (',', 'O'),
#   ('mau', 'ID'),
#   ('ngedonlot', 'MIX-ID-EN'),
#   ('film2', 'ID'),
#   ('trs', 'ID'),
#   ('nonton', 'ID'),
#   ('bareng', 'ID'),
#   ('adek', 'ID'),
#   (',', 'O'),
#   ('olahraga', 'ID'),
#   ('rutin', 'ID'),
#   (',', 'O'),
#   ('ngerapiin', 'ID'),
#   ('kamar', 'ID'),
#   ('sambil', 'ID'),
#   ('dikit2', 'ID'),
#   ('siap2', 'ID'),
#   ('buat', 'ID'),
#   ('mandiri', 'ID')],
#  [('Baru', 'ID'),
#   ('tauuu', 'ID'),
#   ('kalo', 'ID'),
#   ('nonton', 'ID'),
#   ('film', 'ID'),
#   ('di', 'ID'),
#   ('tele', 'O'),
#   ('itu', 'ID'),
#   ('ngedonlot', 'MIX-ID-EN'),
#   ('kirain', 'ID'),
#   ('cuma', 'ID'),
#   ('nonton', 'ID'),
#   ('online', 'EN'),
#   ('pantesan', 'ID'),
#   ('RAM', 'EN'),
#   ('gue', 'ID'),
#   ('cepet', 'ID'),
#   ('penuh', 'ID'),
#   ('sejak', 'ID'),
#   ('instal', 'ID'),
#   ('tele', 'O'),
#   (',', 'O'),
#   ('setelah', 'ID'),
#   ('ratusan', 'ID'),
#   ('film', 'ID'),
#   ('akhirnya', 'ID'),
#   ('gue', 'ID'),
#   ('hapus', 'ID'),
#   ('semua', 'ID'),
#   ('langsung', 'ID'),
#   ('free', 'EN'),
#   ('22GB', 'EN'),
#   ('🙂', 'O'),
#   ('🙂', 'O')],
#  [('Knp', 'ID'),
#   ('ya', 'ID'),
#   ('ngedonlot', 'MIX-ID-EN'),
#   ('film', 'ID'),
#   ('pake', 'ID'),
#   ('kuota', 'ID'),
#   ('sendiri', 'ID'),
#   ('tu', 'ID'),
#   ('berasa', 'ID'),
#   ('rugi', 'ID'),
#   ('bgt', 'ID'),
#   (',', 'O'),
#   ('padahal', 'ID'),
#   ('cuma', 'ID'),
#   ('500mb', 'O'),
#   ('..', 'O')],
#  [('udah', 'ID'),
#   ('make', 'ID'),
#   ('sampe', 'ID'),
#   ('7gb', 'EN'),
#   (',', 'O'),
#   ('gumoohhh', 'ID'),
#   ('ngedonlot', 'MIX-ID-EN'),
#   ('drama', 'ID'),
#   ('sama', 'ID'),
#   ('film', 'ID')],
#  [('@nasssbll', 'O'),
#   ('ini', 'ID'),
#   ('lagii', 'ID'),
#   ('mau', 'ID'),
#   ('ngedonlot', 'MIX-ID-EN'),
#   ('film', 'ID'),
#   ('baruu', 'ID')],
#  [('@vhyrieart', 'O'),
#   ('Ngedonlot', 'MIX-ID-EN'),
#   ('film', 'ID'),
#   ('sama', 'ID'),
#   ('series', 'EN'),
#   ('banyak', 'ID'),
#   ('sampe', 'ID'),
#   ('puas', 'ID')],
#  [('pegawai', 'ID'),
#   ('nasa', 'EN'),
#   ('ngedonlot', 'MIX-ID-EN'),
#   ('film', 'ID'),
#   (':', 'O')],
#  [('@txtdarionlshop', 'O'),
#   ('Selalu', 'ID'),
#   ('pake', 'ID'),
#   ('tokped', 'O'),
#   ('saat', 'ID'),
#   ('butuh', 'ID'),
#   ('barang', 'ID'),
#   ('cepet', 'ID'),
#   ('saat', 'ID'),
#   ('itu', 'ID'),
#   ('juga', 'ID'),
#   ('dan', 'ID'),
#   ('gak', 'ID'),
#   ('bisa', 'ID'),
#   ('ninggalin', 'ID'),
#   ('rumah', 'ID'),
#   ('.', 'O'),
#   ('30', 'O'),
#   ('menit', 'ID'),
#   ('hbs', 'ID'),
#   ('check', 'EN'),
#   ('out', 'EN'),
#   (',', 'O'),
#   ('lgsg', 'ID'),
#   ('nyampe', 'ID'),
#   ('barangnya', 'ID'),
#   (',', 'O'),
#   ('free', 'EN'),
#   ('ongkir', 'ID'),
#   ('lagi', 'ID'),
#   ('.', 'O'),
#   ('Mantap', 'ID'),
#   ('bgt', 'ID'),
#   ('.', 'O')],
#  [('@aniyfans', 'O'),
#   ('fix', 'EN'),
#   ('kita', 'ID'),
#   ('nunggu', 'ID'),
#   ('order', 'ID'),
#   ('via', 'ID'),
#   ('tokped', 'O'),
#   ('aja', 'ID'),
#   ('bun', 'ID'),
#   ('awokwokwkwk', 'O'),
#   ('walaupun', 'ID'),
#   ('suwe', 'JV')],
#  [('@TokopediaCare', 'O'),
#   ('min', 'ID'),
#   ('tokped', 'O'),
#   ('lg', 'ID'),
#   ('lelet', 'ID'),
#   ('apa', 'ID'),
#   ('ya', 'ID'),
#   ('🤔', 'O'),
#   (',', 'O'),
#   ('status', 'ID'),
#   ('paket', 'ID'),
#   ('3', 'O'),
#   ('biji', 'ID'),
#   ('masih', 'ID'),
#   ('stuck', 'EN'),
#   ('aja', 'ID'),
#   ('ekspedisi', 'ID'),
#   ('anter', 'O'),
#   ('aja', 'O'),
#   ('satria', 'ID'),
#   ('tuh', 'ID'),
#   ('🤦', 'O'),
#   ('🏻', 'O'),
#   ('\u200d', 'O'),
#   ('♀', 'O'),
#   ('️', 'O'),
#   ('.', 'O'),
#   ('Tp', 'ID'),
#   ('di', 'ID'),
#   ('e-commerce', 'EN'),
#   ('lain', 'ID'),
#   ('ngga', 'ID'),
#   ('maintenance', 'EN'),
#   ('ekspedisi', 'ID'),
#   ('yg', 'ID'),
#   ('sm', 'ID'),
#   ('tuh', 'ID'),
#   ('min', 'ID'),
#   ('?', 'O')],
#  [('@rsythr_', 'O'),
#   ('Dasar', 'ID'),
#   ('server', 'EN'),
#   ('bli2nya', 'ID'),
#   ('agak', 'ID'),
#   ('lelet', 'ID'),
#   ('ci', 'O'),
#   ('ai', 'O'),
#   ('...', 'O'),
#   ('Kalau', 'ID'),
#   ('kaya', 'ID'),
#   ('tokped', 'O'),
#   ('lwn', 'ID'),
#   ('Shopee', 'O'),
#   ('nyata', 'ID'),
#   ('dapat', 'ID'),
#   ('dah', 'ID'),
#   ('tu', 'ID')],
#  [('gw', 'ID'),
#   ('males', 'ID'),
#   ('sebenernya', 'ID'),
#   ('pake', 'ID'),
#   ('ekspedisi', 'ID'),
#   ('anteraja', 'O'),
#   ('.', 'O'),
#   ('lama', 'ID'),
#   ('bgtttt', 'ID'),
#   ('.', 'O'),
#   ('tapi', 'ID'),
#   ('di', 'ID'),
#   ('tokped', 'O'),
#   ('adanya', 'ID'),
#   ('itu', 'ID'),
#   ('doang', 'ID'),
#   ('yg', 'ID'),
#   ('bisa', 'ID'),
#   ('freeongkir', 'MIX-ID-EN'),
#   ('-_-', 'O')],
#  [('@aldydas04', 'O'),
#   ('@GrabKiosID', 'O'),
#   ('Cek', 'ID'),
#   ('email', 'EN'),
#   ('bang', 'ID'),
#   ('.', 'O'),
#   ('Males', 'ID'),
#   ('bet', 'ID'),
#   ('beli', 'ID'),
#   ('di', 'ID'),
#   ('GK', 'O'),
#   ('emank', 'ID'),
#   (',', 'O'),
#   ('enak', 'ID'),
#   ('dulu', 'ID'),
#   ('di', 'ID'),
#   ('tokped', 'O'),
#   ('vouchernya', 'MIX-ID-EN'),
#   ('langsung', 'ID'),
#   ('muncul', 'ID'),
#   (',', 'O'),
#   ('pembayaranya', 'ID'),
#   ('bisa', 'ID'),
#   ('tranfer', 'ID'),
#   ('lewat', 'ID'),
#   ('bank', 'ID'),
#   ('.', 'O'),
#   ('sat', 'O'),
#   ('set', 'O'),
#   ('sat', 'O'),
#   ('set', 'O'),
#   ('.', 'O'),
#   ('Ada', 'ID'),
#   ('promonya', 'ID'),
#   ('lagi', 'ID'),
#   ('.', 'O'),
#   ('GK', 'O'),
#   ('udah', 'ID'),
#   ('pelit', 'ID'),
#   (',', 'O'),
#   ('ribet', 'ID'),
#   (',', 'O'),
#   ('lemot', 'ID'),
#   ('lagi', 'ID'),
#   ('.', 'O')],
#  [('Beli', 'ID'),
#   ('spotify', 'O'),
#   ('ora', 'O'),
#   ('danta', 'O'),
#   ('Beli', 'ID'),
#   ('Netflix', 'O'),
#   ('ora', 'O'),
#   ('danta', 'O'),
#   ('Belanja', 'ID'),
#   ('di', 'ID'),
#   ('tokped', 'O'),
#   ('ora', 'O'),
#   ('danta', 'O'),
#   ('Emang', 'ID'),
#   ('lagi', 'ID'),
#   ('ga', 'ID'),
#   ('di', 'ID'),
#   ('bolehin', 'ID'),
#   ('bebelian', 'ID'),
#   ('sama', 'ID'),
#   ('allah', 'O'),
#   ('#mereun', 'O')],
#  [('@jogjamnfs', 'O'),
#   ('Niat', 'JV'),
#   ('nambah', 'JV'),
#   ('konco', 'JV'),
# ...
#   ('di', 'ID'),
#   ('1', 'O'),
#   ('jenis', 'ID'),
#   ('genre', 'ID'),
#   ('tok', 'JV'),
#   ('cuma', 'ID'),
#   ('yo', 'JV'),
#   ('ngunu', 'JV'),
#   ('iku', 'JV'),
#   ('alur', 'ID'),
#   ('+', 'O'),
#   ('percakapane', 'MIX-ID-JV'),
#   ('ilo', 'O'),
#   ('😭', 'O')],
#  [('@rdian2408', 'O'),
#   ('@mykingdomrandom', 'O'),
#   ('@AminMualim', 'O'),
#   ('@fuego97XX', 'O'),
#   ('@jowoshitpost', 'O'),
#   ('Lagi', 'JV'),
#   ('gering', 'JV'),
#   (',,', 'O'),
#   ('moco', 'JV'),
#   ('percakapane', 'MIX-ID-JV'),
#   ('samean', 'JV'),
#   ('samean', 'JV'),
#   ('marai', 'JV'),
#   ('rodo', 'JV'),
#   ('lali', 'JV'),
#   ('le', 'JV'),
#   ('gering', 'JV'),
#   ('..', 'O'),
#   ('😂', 'O'),
#   ('😂', 'O')],
#  [('-', 'O'),
#   ('rek', 'JV'),
#   ('kon', 'JV'),
#   ('wedok', 'JV'),
#   ('yaopo', 'JV'),
#   ('perasaanmu', 'ID'),
#   ('pas', 'JV'),
#   ('ngancani', 'JV'),
#   ('pacarmu', 'JV'),
#   ('ketemuan', 'ID'),
#   ('karo', 'JV'),
#   ('pacare', 'JV'),
#   ('konco', 'JV'),
#   ('e', 'JV'),
#   ('dee', 'JV'),
#   ('(', 'O'),
#   ('wedok', 'JV'),
#   (')', 'O'),
#   ('curhat', 'ID'),
#   ('hubungane', 'MIX-ID-JV'),
#   ('dee', 'JV'),
#   (',', 'O'),
#   ('terus', 'JV'),
#   ('kon', 'JV'),
#   ('nak', 'ID'),
#   ('kunu', 'JV'),
#   ('gak', 'JV'),
#   ('iso', 'JV'),
#   ('nyambung', 'JV'),
#   ('mbe', 'JV'),
#   ('percakapane', 'MIX-ID-JV'),
#   ('mereka', 'ID'),
#   ('?', 'O'),
#   ('soale', 'MIX-ID-JV'),
#   ('ancen', 'JV'),
#   ('awdw', 'JV'),
#   ('gak', 'JV'),
#   ('ero', 'JV'),
#   ('ceritoe', 'JV'),
#   ('yaopo', 'JV')],
#  [('Bajigurrr', 'JV'),
#   ('percakapane', 'MIX-ID-JV'),
#   ('wong', 'JV'),
#   ('crazy', 'EN'),
#   ('rich', 'EN')],
#  [('Isine', 'JV'),
#   ('percakapane', 'MIX-ID-JV'),
#   ('sibal"an', 'JV'),
#   ('😭', 'O'),
#   ('😭', 'O'),
#   ('😭', 'O'),
#   ('😭', 'O')],
#  [('pora', 'JV'),
#   ('yok', 'JV'),
#   ('"', 'O'),
#   ('ngang', 'O'),
#   ('ngong', 'O'),
#   ('ngang', 'O'),
#   ('ngong', 'O'),
#   ('"', 'O'),
#   ('isi', 'JV'),
#   ('percakapane', 'MIX-ID-JV'),
#   ('👀', 'O')],
#  [('👩', 'O'),
#   ('\u200d', 'O'),
#   ('🦳', 'O'),
#   ('mbak', 'ID'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('jagung', 'ID'),
#   ('👩', 'O'),
#   ('becek', 'ID'),
#   (',', 'O'),
#   ('motorku', 'JV'),
#   ('lg', 'ID'),
#   ('bgt', 'ID'),
#   ('tak', 'ID'),
#   ('cuci', 'ID'),
#   ('👩', 'O'),
#   ('\u200d', 'O'),
#   ('🦳', 'O'),
#   ('yws', 'JV'),
#   ('bar', 'JV'),
#   ('cuci', 'ID'),
#   ('plastiki', 'JV'),
#   ('wae', 'JV'),
#   ('njuk', 'JV'),
#   ('balek', 'JV'),
#   ('e', 'JV'),
#   ('toko', 'JV'),
#   ('👩', 'O'),
#   ('gasss', 'JV'),
#   (':)', 'O')],
#  [('@WoengDheszo', 'O'),
#   ('@kin_kinasih1', 'O'),
#   ('Cucur', 'ID'),
#   ('wae', 'JV'),
#   ('klu', 'ID'),
#   ('msh', 'ID'),
#   ('kurang', 'ID'),
#   ('omong', 'ID'),
#   ('ya', 'ID'),
#   ('..', 'O'),
#   ('nanti', 'ID'),
#   ('tak', 'ID'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('di', 'ID'),
#   ('kebun', 'ID'),
#   ('msh', 'ID'),
#   ('byk', 'ID'),
#   ('😂', 'O'),
#   ('Peace', 'EN'),
#   ('njih', 'JV'),
#   ('mbakyu', 'JV'),
#   ('✌', 'O')],
#  [('@Andriaor_', 'O'),
#   ('Opo', 'JV'),
#   ('aku', 'JV'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('wae', 'JV'),
#   ('yo', 'JV'),
#   ('seneng', 'JV'),
#   ('ahahha', 'O')],
#  [('@indahindudd', 'O'),
#   ('Seru', 'ID'),
#   ('bgt', 'ID'),
#   ('nggarapi', 'JV'),
#   ('cilikan', 'JV'),
#   ('hahaha', 'O'),
#   ('Mau', 'JV'),
#   ('menek', 'JV'),
#   ('pagerku', 'JV'),
#   ('Tak', 'JV'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('wae', 'JV'),
#   ('Trus', 'ID'),
#   ('tak', 'ID'),
#   ('suruh', 'ID'),
#   ('pushup', 'EN'),
#   ('25x', 'O'),
#   ('Aku', 'JV'),
#   ('ra', 'JV'),
#   ('tego', 'JV'),
#   ('tak', 'JV'),
#   ('kon', 'JV'),
#   ('20', 'O'),
#   ('wae', 'JV'),
#   (',', 'O'),
#   ('trus', 'JV'),
#   ('kan', 'ID'),
#   ('kon', 'JV'),
#   ('suit', 'ID'),
#   ('Jadi', 'ID'),
#   ('pushupnya', 'MIX-ID-EN'),
#   ('sia', 'ID'),
#   ('sia', 'ID'),
#   ('HUAHAHAHAHAHAHA', 'O')],
#  [('@shintabrth', 'O'),
#   ('Tak', 'JV'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('wae', 'JV'),
#   ('.', 'O'),
#   ('Trus', 'ID'),
#   ('kamu', 'ID'),
#   ('ngebis', 'ID'),
#   ('ke', 'ID'),
#   ('klaten', 'O'),
#   ('wkwowkwowk', 'O')],
#  [('@Rezaraihann01', 'O'),
#   ('Tutup', 'ID'),
#   ('fren', 'EN'),
#   ('mbuh', 'JV'),
#   ('meh', 'JV'),
#   ('bukak', 'JV'),
#   ('kapan', 'JV'),
#   ('nek', 'JV'),
#   ('ndak', 'JV'),
#   ('bsk', 'ID'),
#   ('wae', 'JV'),
#   ('tak', 'JV'),
#   ('ambilke', 'MIX-ID-JV')],
#  [('🐙', 'O'),
#   ('Buk', 'ID'),
#   ('..', 'O'),
#   ('👸', 'O'),
#   ('*', 'O'),
#   ('rajang', 'JV'),
#   ('wortel', 'JV'),
#   ('*', 'O'),
#   ('hmm', 'O'),
#   ('?', 'O'),
#   ('🐙', 'O'),
#   ('Mau', 'ID'),
#   ('bukber', 'ID'),
#   ('..', 'O'),
#   ('👸', 'O'),
#   ('Gak', 'ID'),
#   ('usah', 'ID'),
#   ('🐙', 'O'),
#   ('Sm', 'ID'),
#   ('temen2', 'ID'),
#   ('Karawitan', 'ID'),
#   (',', 'O'),
#   ('ketemune', 'JV'),
#   ('cuman', 'ID'),
#   ('setaun', 'JV'),
#   ('sekali', 'ID'),
#   ('😣', 'O'),
#   ('👸', 'O'),
#   ('Gak', 'ID'),
#   ('usah', 'ID'),
#   (',', 'O'),
#   ('wes', 'JV'),
#   ('nek', 'JV'),
#   ('omah', 'JV'),
#   ('wae', 'JV'),
#   ('🐙', 'O'),
#   ('/', 'O'),
#   ('merajuk', 'ID'),
#   ('/', 'O'),
#   ('👸', 'O'),
#   ('/', 'O'),
#   ('abai', 'ID'),
#   ('/', 'O'),
#   ('Ambilke', 'MIX-ID-JV'),
#   ('telur', 'ID'),
#   ('mbak', 'ID'),
#   (',', 'O'),
#   ('trus', 'ID'),
#   ('ini', 'ID'),
#   ('bakwannya', 'ID'),
#   ('digoreng', 'ID'),
#   ('yuhuu', 'O'),
#   ('ternyata', 'ID'),
#   ('diem', 'ID'),
#   ('diem', 'ID'),
#   ('Ibukku', 'ID'),
#   ('kangen', 'ID'),
#   ('aku', 'ID'),
#   ('akhirnyaa', 'ID'),
#   ('hamdalah', 'ID')],
#  [('alhamdulillah', 'ID'),
#   ('dah', 'ID'),
#   ('mandi', 'ID'),
#   ('dah', 'ID'),
#   ('cantik', 'ID'),
#   ('walaupun', 'ID'),
#   ('masih', 'ID'),
#   ('bingung', 'ID'),
#   ('iki', 'JV'),
#   ('mau', 'JV'),
#   ('iseh', 'JV'),
#   ('rabu', 'ID'),
#   ('po', 'JV'),
#   ('wis', 'JV'),
#   ('kamis', 'ID'),
#   (',', 'O'),
#   ('dikon', 'JV'),
#   ('tumbas', 'JV'),
#   ('air', 'ID'),
#   ('wae', 'JV'),
#   ('malah', 'JV'),
#   ('tak', 'JV'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('nang', 'JV'),
#   ('gelas', 'JV'),
#   ('😣', 'O')],
#  [('@ShintaSumarsono', 'O'),
#   ('shin', 'O'),
#   ('nek', 'JV'),
#   ('seumpama', 'ID'),
#   ('sesok', 'JV'),
#   ('aku', 'JV'),
#   ('gak', 'JV'),
#   ('mangkat', 'JV'),
#   (',', 'O'),
#   ('fdku', 'MIX-JV-EN'),
#   ('sisan', 'JV'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('ya', 'JV'),
#   (',', 'O'),
#   ('terus', 'ID'),
#   ('tak', 'ID'),
#   ('ambil', 'ID'),
#   ('neng', 'JV'),
#   ('kamu', 'ID'),
#   ('wae', 'JV')],
#  [('Nanti', 'ID'),
#   ('sekalian', 'ID'),
#   ('tak', 'ID'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('mbak', 'ID'),
#   ('vi', 'O'),
#   ('@viceriiaputtd:', 'O'),
#   ('@bimbimasu', 'O'),
#   ('@ushianaa', 'O'),
#   ('sesok', 'JV'),
#   ('ja', 'ID'),
#   ('ding', 'ID'),
#   ('mbak', 'ID'),
#   ('nek', 'JV'),
#   ('meh', 'JV'),
#   ('tak', 'JV'),
#   ('jak', 'JV'),
#   ('dolan', 'JV'),
#   ('wae', 'JV'),
#   ('si', 'O'),
#   ('millo', 'O'),
#   ('ki', 'JV'),
#   ('ngko', 'JV'),
#   ('tak', 'JV')],
#  [('@nurulita_ita', 'O'),
#   ('yowes', 'JV'),
#   ('.', 'O'),
#   ('suk', 'JV'),
#   ('nek', 'JV'),
#   ('ultah', 'ID'),
#   ('ta', 'ID'),
#   ('kado', 'ID'),
#   ('cermin', 'ID'),
#   ('wae', 'JV'),
#   ('yaa', 'JV'),
#   ('.', 'O'),
#   ('ta', 'ID'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('di', 'ID'),
#   ('kampus', 'ID'),
#   (':D', 'O')],
#  [('@avissamna', 'O'),
#   ('hahaa', 'O'),
#   ('ah', 'JV'),
#   ('we', 'JV'),
#   ('ki', 'JV'),
#   (',', 'O'),
#   ('tak', 'JV'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('tisu', 'ID'),
#   ('wae', 'JV'),
#   ('buat', 'ID'),
#   ('mas', 'ID'),
#   ('mas', 'ID'),
#   ('suju', 'O'),
#   ('😍', 'O')],
#  [('@anissadewisma', 'O'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('wae', 'JV'),
#   ('to', 'JV'),
#   (',', 'O'),
#   ('aku', 'ID'),
#   ('gak', 'ID'),
#   ('tau', 'ID'),
#   ('hahaha', 'O')],
#  [('@putrie_wuland', 'O'),
#   ('nanti', 'ID'),
#   ('tak', 'ID'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('wae', 'JV')],
#  [('@aan_ravee', 'O'),
#   ('apa', 'ID'),
#   ('aku', 'ID'),
#   ('d', 'ID'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('wae', 'JV'),
#   ('un', 'O'),
#   ('?', 'O'),
#   ('*', 'O'),
#   ('ngarepp', 'ID')],
#  [('@MariaTheresia22', 'O'),
#   ('@Nana_Islanzadi', 'O'),
#   ('ya', 'JV'),
#   ('wes', 'JV'),
#   ('tak', 'JV'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('sisan', 'JV'),
#   ('wae', 'JV'),
#   ('yaa', 'JV'),
#   ('.', 'O'),
#   ('Bsok', 'ID'),
#   ('meh', 'JV'),
#   ('k', 'ID'),
#   ('grj', 'ID'),
#   ('gk', 'ID'),
#   ('??', 'O')],
#  [('@bima_sakti_s', 'O'),
#   ('@nikeenlarasati', 'O'),
#   ('halah', 'JV'),
#   ('kadar', 'ID'),
#   ('kuliah', 'ID'),
#   ('kamu', 'ID'),
#   ('guyon', 'ID'),
#   ('wae', 'JV'),
#   ('o', 'O'),
#   ('wuu', 'O'),
#   ('-,-', 'O'),
#   ('iyaaa', 'ID'),
#   ('besok', 'ID'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('yaaa', 'ID'),
#   (':p', 'O')],
#  [('Haha', 'O'),
#   (',', 'O'),
#   ('hla', 'JV'),
#   ('meh', 'JV'),
#   ('opo', 'JV'),
#   ('jal', 'JV'),
#   (':p', 'O'),
#   ('RT', 'EN'),
#   ('"@nroszyyana:', 'O'),
#   ('Ah', 'ID'),
#   ('pelit', 'ID'),
#   ('(˘̯˘)', 'O'),
#   ('/', 'O'),
#   ('"@hieronymusFT:', 'O'),
#   ('Wkk', 'O'),
#   ('..', 'O'),
#   ('Tak', 'ID'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('pasir', 'ID'),
#   ('vulkanik', 'ID'),
#   ('wae', 'JV'),
#   ('pye', 'JV'),
#   (':p', 'O'),
#   ('""', 'O')],
#  [('Ah', 'ID'),
#   ('pelit', 'ID'),
#   ('(˘̯˘)', 'O'),
#   ('/', 'O'),
#   ('"@hieronymusFT:', 'O'),
#   ('Wkk', 'O'),
#   ('..', 'O'),
#   ('Tak', 'ID'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('pasir', 'ID'),
#   ('vulkanik', 'ID'),
#   ('wae', 'JV'),
#   ('pye', 'JV'),
#   (':p', 'O'),
#   ('"', 'O')],
#  [('Wkk', 'O'),
#   ('..', 'O'),
#   ('Tak', 'ID'),
#   ('ambilke', 'MIX-ID-JV'),
#   ('pasir', 'ID'),
#   ('vulkanik', 'ID'),
#   ('wae', 'JV'),
#   ('pye', 'JV'),
#   (':p', 'O'),
#   ('RT', 'EN'),
#   ('"@nroszyyana:', 'O'),
#   ('Tp', 'JV'),
#   ('nek', 'JV'),
#   ('ng', 'JV'),
#   ('Bromo', 'O'),
#   ('ki', 'JV'),
#   ('opo', 'JV'),
#   ('oleh2', 'JV'),
#   ('sik', 'JV'),
#   ('apik', 'JV'),
#   ('?', 'O'),
#   (':/', 'O'),
#   ('"@hieronymusFT:', 'O'),
#   ('Yo', 'JV'),
#   ('aku', 'ID'),
#   ('minta', 'ID'),
#   ('uang', 'ID'),
#   ('.."', 'O')],
#  [('Kang', 'JV'),
#   (',', 'O'),
#   ('tulung', 'JV'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('mmt', 'O'),
#   ('nggih', 'JV'),
#   (',', 'O'),
#   ('kagem', 'JV'),
#   ('acara', 'JV'),
#   ('ngenjang', 'JV'),
#   ('jam', 'JV'),
#   ('12.', 'O'),
#   ('.......', 'O')],
#  [('@dorisak_', 'O'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('wae', 'JV'),
#   ('bang', 'ID'),
#   ('😅', 'O')],
#  [('@alipsaurus', 'O'),
#   ('Diprintke', 'MIX-JV-EN'),
#   ('mbok', 'JV'),
#   ('an', 'JV')],
#  [('@UNSfess_', 'O'),
#   ('Kan', 'ID'),
#   ('diprintke', 'MIX-JV-EN'),
#   (',', 'O'),
#   ('diwei', 'JV'),
#   ('kertase', 'JV')],
#  [('Iki', 'JV'),
#   ('to', 'JV'),
#   ('wonge', 'JV'),
#   (',', 'O'),
#   ('tulung', 'JV'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('ditemplekne', 'JV'),
#   ('baliho', 'ID'),
#   ('ne', 'JV'),
#   ('puan', 'O')],
#  [('@ucglyducking', 'O'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('logo', 'ID'),
#   ('PDIP', 'O'),
#   ('bro', 'EN')],
#  [('sekarang', 'ID'),
#   ('bikin', 'ID'),
#   ('aturan', 'ID'),
#   ('kayaknya', 'ID'),
#   ('gampang', 'ID'),
#   (',', 'O'),
#   ('gampang', 'ID'),
#   ('terbit', 'ID'),
#   (',', 'O'),
#   ('gampang', 'ID'),
#   ('dicabut', 'ID'),
#   ('.', 'O'),
#   ('koyo', 'JV'),
#   ('koncoku', 'JV'),
#   (',', 'O'),
#   ('wes', 'JV'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('antigen', 'ID'),
#   ('ilang', 'JV'),
#   (',', 'O'),
#   ('njaluk', 'JV'),
#   ('printke', 'MIX-JV-EN'),
#   ('meneh', 'JV'),
#   ('..', 'O'),
#   ('katanya', 'ID'),
#   ('kan', 'ID'),
#   ('gampang', 'ID'),
#   ('ngeprint', 'MIX-ID-EN'),
#   ('meneh', 'JV'),
#   ('..', 'O'),
#   ('ha', 'O'),
#   ('socane', 'JV'),
#   ('panjenenga', 'JV'),
#   ('puniko', 'JV'),
#   ('!!', 'O')],
#  [('🙇', 'O'),
#   ('\u200d', 'O'),
#   ('♂', 'O'),
#   ('️', 'O'),
#   ('Mbah', 'JV'),
#   ('Pamit', 'JV'),
#   (',', 'O'),
#   ('kulo', 'JV'),
#   ('ajeng', 'JV'),
#   ('mangkat', 'JV'),
#   ('teng', 'JV'),
#   ('jakarta', 'O'),
#   ('malih', 'JV'),
#   ('👩', 'O'),
#   ('\u200d', 'O'),
#   ('🦳', 'O'),
#   ('Aku', 'JV'),
#   ('mbok', 'JV'),
#   ('njaluk', 'JV'),
#   ('fotomu', 'JV'),
#   ('le', 'JV'),
#   ('🙇', 'O'),
#   ('\u200d', 'O'),
#   ('♂', 'O'),
#   ('️', 'O'),
#   ('Enggih', 'JV'),
#   (',', 'O'),
#   ('mengkih', 'JV'),
#   ('kersane', 'JV'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('mbak', 'JV'),
#   ('10', 'O'),
#   ('bulan', 'ID'),
#   ('kemudian', 'ID'),
#   ('sampe', 'ID'),
#   ('aku', 'ID'),
#   ('pulang', 'ID'),
#   ('lagi', 'ID'),
#   (',', 'O'),
#   ('belum', 'ID'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('juga', 'ID'),
#   ('🤣', 'O')],
#  [('@_rezanrf', 'O'),
#   ('bg', 'EN'),
#   ('biru', 'JV'),
#   ('ngne', 'JV'),
#   ('ki', 'JV'),
#   ('nek', 'JV'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('ngko', 'JV'),
#   ('ditakoni', 'JV'),
#   ('tukang', 'JV'),
#   ('fc', 'EN'),
#   ('ne', 'JV'),
#   ('"', 'O'),
#   ('mau', 'ID'),
#   ('nikah', 'ID'),
#   ('ya', 'ID'),
#   ('mbak', 'ID'),
#   ('?"', 'O'),
#   ('skslskwlek', 'O'),
#   ('pengalaman', 'ID'),
#   ('pribadiq', 'ID'),
#   ('🤪', 'O')],
#  [('@jogjamf', 'O'),
#   ('Kartu', 'ID'),
#   ('vaksin', 'ID'),
#   ('print', 'EN'),
#   ('dewe', 'JV'),
#   ('/', 'O'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('kan', 'ID'),
#   ('yo', 'JV'),
#   ('iso', 'JV')],
#  [('@rfq___', 'O'),
#   ('Mas', 'JV'),
#   ('nyuwun', 'JV'),
#   ('tulung', 'JV'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('sertifikat', 'ID'),
#   ('tanah', 'ID'),
#   ('gen', 'JV'),
#   ('jenengan', 'JV'),
#   ('mangkeh', 'JV'),
#   ('tak', 'JV'),
#   ('pendete', 'JV')],
#  [('@Marchettya', 'O'),
#   ('@samsat_sragen', 'O'),
#   ('@ganjarpranowo', 'O'),
#   ('Aku', 'ID'),
#   ('bacane', 'MIX-ID-JV'),
#   ('sak', 'JV'),
#   ('pol', 'JV'),
#   ('e', 'JV'),
#   ('.', 'O'),
#   ('Wkwk', 'O'),
#   ('.', 'O'),
#   ('Ish', 'JV'),
#   ('samsat', 'ID'),
#   ('sragen', 'O'),
#   ('ora', 'JV'),
#   ('maju2', 'JV'),
#   ('lha', 'JV'),
#   ('sing', 'JV'),
#   ('kerjo', 'JV'),
#   ('malesan', 'JV'),
#   ('og', 'JV'),
#   ('.', 'O'),
#   ('Di', 'ID'),
#   ('sini', 'ID'),
#   ('aku', 'ID'),
#   ('bayar', 'ID'),
#   ('pajek', 'ID'),
#   ('mobil', 'ID'),
#   ('motor', 'ID'),
#   ('online', 'EN'),
#   ('kabeh', 'JV'),
#   ('.', 'O'),
#   ('Diprintke', 'MIX-JV-EN'),
#   ('sisan', 'JV'),
#   ('.', 'O'),
#   ('Ga', 'ID'),
#   ('nunggu', 'ID'),
#   ('lamak', 'ID'),
#   ('.', 'O'),
#   ('Wes', 'JV'),
#   ('beres', 'JV'),
#   ('.', 'O'),
#   ('Jabar', 'O'),
#   ('emang', 'ID'),
#   ('keren', 'ID'),
#   ('wakakak', 'O'),
#   ('.', 'O'),
#   ('Di', 'ID'),
#   ('bandung', 'O'),
#   ('yo', 'JV'),
#   ('keren', 'ID'),
#   ('.', 'O'),
#   ('Di', 'ID'),
#   ('Bekasi', 'O'),
#   ('yo', 'JV'),
#   ('keren', 'ID'),
#   ('.', 'O'),
#   ('Wes', 'JV'),
#   ('enak', 'JV'),
#   ('tenan', 'JV'),
#   ('.', 'O')],
#  [('Harus', 'ID'),
#   ('ditanya', 'ID'),
#   ('beberapa', 'ID'),
#   ('kali', 'ID'),
#   ('dulu', 'ID'),
#   ('baru', 'ID'),
#   ('ngeh', 'ID'),
#   (',', 'O'),
#   ('padahal', 'ID'),
#   ('ya', 'ID'),
#   ('udah', 'ID'),
#   ('enak', 'ID'),
#   ('apa2', 'ID'),
#   ('diprintke', 'MIX-JV-EN'),
#   (',', 'O'),
#   ('digarapke', 'MIX-ID-JV'),
#   ('sik', 'JV'),
#   ('.', 'O')],
#  [('@Araghutama', 'O'),
#   ('Wingi', 'JV'),
#   ('muncul', 'ID'),
#   ('pak', 'JV'),
#   ('jarene', 'JV'),
#   ('soale', 'MIX-ID-JV'),
#   ('aku', 'ID'),
#   ('Ndak', 'ID'),
#   ('diliatkan', 'ID'),
#   ('karena', 'ID'),
#   ('biasanya', 'ID'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('dari', 'ID'),
#   ('cs', 'EN'),
#   ('dan', 'ID'),
#   ('infonya', 'ID'),
#   ('penarikannya', 'ID'),
#   ('di', 'ID'),
#   ('Bandung', 'O')],
#  [('@txtdarionlshop', 'O'),
#   ('Utek', 'JV'),
#   ('e', 'JV'),
#   ('wae', 'JV'),
#   ('tulung', 'JV'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('mas', 'JV')],
#  [('@ridhanug', 'O'),
#   ('@Puthutea', 'O'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('wae', 'JV')],
#  [('@ngalamfess', 'O'),
#   ('kowe', 'JV'),
#   ('ngirim', 'JV'),
#   ('pesenan', 'JV'),
#   ('kan', 'ID'),
#   ('?', 'O'),
#   ('bakal', 'JV'),
#   ('otomatis', 'ID'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('j*t', 'O'),
#   ('kok', 'JV'),
#   ('nder', 'EN'),
#   ('dadi', 'JV'),
#   ('langsung', 'JV'),
#   ('ditempelke', 'MIX-ID-JV'),
#   ('karo', 'JV'),
#   ('mereka', 'ID')],
#  [('@halipnuryanto', 'O'),
#   ('Tulung', 'JV'),
#   ('diprintke', 'MIX-JV-EN'),
#   ('tulisan', 'ID'),
#   ('"', 'O'),
#   ('baru', 'ID'),
#   ('belajar', 'ID'),
#   ('"', 'O')],
#  [('@lilyfrncn', 'O'),
#   ('Lha', 'JV'),
#   ('kok', 'JV'),
#   ('ra', 'JV'),
#   ('genose', 'O'),
#   ('po', 'JV'),
#   ('rapid', 'EN'),
#   ('ning', 'JV'),
#   ('stasiun', 'JV'),
#   ('wae', 'JV'),
#   ('e', 'JV'),
#   ('Lik', 'JV'),
#   ('?', 'O'),
#   ('Kan', 'ID'),
#   ('luwih', 'JV'),
#   ('murah', 'JV'),
#   ('tur', 'JV'),
#   ('wes', 'JV'),
#   ('diprintke', 'MIX-JV-EN')],
#  [('@sbyfess', 'O'),
#   ('Kapan', 'ID'),
#   ('pulang', 'ID'),
#   ('+', 'O'),
#   ('nitip', 'ID'),
#   ('ketikan', 'ID'),
#   ('sekalian', 'ID'),
#   ('diprintke', 'MIX-JV-EN')],
#  [('dicancel', 'MIX-ID-EN'),
#   ('karena', 'ID'),
#   ('terlalu', 'ID'),
#   ('galak', 'ID'),
#   ('bisa', 'ID'),
#   ('gakya', 'ID'),
#   ('.', 'O')],
#  [('ya', 'ID'),
#   ('Allah', 'ID'),
#   ('Alhamdulillah', 'ID'),
#   ('untung', 'ID'),
#   ('kelas', 'ID'),
#   ('sorenya', 'ID'),
#   ('dicancel', 'MIX-ID-EN'),
#   ('.', 'O'),
#   ('kalo', 'ID'),
#   ('gak', 'ID'),
#   (',', 'O'),
#   ('bisa', 'ID'),
#   ('ga', 'ID'),
#   ('waras', 'ID'),
#   ('gue', 'ID')],
#  ...]

# %%
def sent2features(sent):
    return [token2features(sent, i) for i in range(len(sent))]


def sent2labels(sent):
    return [label for token, label in sent]


def sent2tokens(sent):
    return [token for token, label in sent]

# %%
X = [sent2features(s) for s in token_tag_pair]
y = [sent2labels(s) for s in token_tag_pair]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=0)

# %%
X_train[20]
# Out:
# [{'token.tag': 'O',
#   'n_gram_0': '@sudjiwotedjo',
#   'token.lower': '@sudjiwotedjo',
#   'token.prefix_2': '@s',
#   'token.prefix_3': '@su',
#   'token.suffix_2': 'jo',
#   'token.suffix_3': 'djo',
#   'token.length': 13,
#   'token.is_alpha': False,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': True,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   'BOS': True,
#   '+1:token.lower': 'mbah',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': True,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': True,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'JV'},
#  {'token.tag': 'JV',
#   'n_gram_0': 'Mba',
#   'token.lower': 'mbah',
#   'token.prefix_2': 'Mb',
#   'token.prefix_3': 'Mba',
#   'token.suffix_2': 'ah',
#   'token.suffix_3': 'bah',
#   'token.length': 4,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': True,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': True,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': '@sudjiwotedjo',
#   '-1:token.is_alpha': False,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': True,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'O',
#   '+1:token.lower': ',',
#   '+1:token.is_alpha': False,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'O'},
#  {'token.tag': 'O',
#   'n_gram_0': ',',
#   'token.lower': ',',
#   'token.prefix_2': ',',
#   'token.prefix_3': ',',
#   'token.suffix_2': ',',
#   'token.suffix_3': ',',
#   'token.length': 1,
#   'token.is_alpha': False,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'mbah',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': True,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': True,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'JV',
#   '+1:token.lower': 'sampeyan',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'JV'},
#  {'token.tag': 'JV',
#   'n_gram_0': 'sam',
#   'token.lower': 'sampeyan',
#   'token.prefix_2': 'sa',
#   'token.prefix_3': 'sam',
#   'token.suffix_2': 'an',
#   'token.suffix_3': 'yan',
#   'token.length': 8,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': ',',
#   '-1:token.is_alpha': False,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'O',
#   '+1:token.lower': 'kuwi',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'JV',
#   'n_gram_1': 'amp',
#   'n_gram_2': 'mpe',
#   'n_gram_3': 'pey',
#   'n_gram_4': 'eya'},
#  {'token.tag': 'JV',
#   'n_gram_0': 'kuw',
#   'token.lower': 'kuwi',
#   'token.prefix_2': 'ku',
#   'token.prefix_3': 'kuw',
#   'token.suffix_2': 'wi',
#   'token.suffix_3': 'uwi',
#   'token.length': 4,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'sampeyan',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'JV',
#   '+1:token.lower': 'suwé²',
#   '+1:token.is_alpha': False,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'JV'},
#  {'token.tag': 'JV',
#   'n_gram_0': 'suw',
#   'token.lower': 'suwé²',
#   'token.prefix_2': 'su',
#   'token.prefix_3': 'suw',
#   'token.suffix_2': 'é²',
#   'token.suffix_3': 'wé²',
#   'token.length': 5,
#   'token.is_alpha': False,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'kuwi',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'JV',
#   '+1:token.lower': 'ora',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'JV',
#   'n_gram_1': 'uwé'},
#  {'token.tag': 'JV',
#   'n_gram_0': 'ora',
#   'token.lower': 'ora',
#   'token.prefix_2': 'or',
#   'token.prefix_3': 'ora',
#   'token.suffix_2': 'ra',
#   'token.suffix_3': 'ora',
#   'token.length': 3,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'suwé²',
#   '-1:token.is_alpha': False,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'JV',
#   '+1:token.lower': 'lucu',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'ID'},
#  {'token.tag': 'ID',
#   'n_gram_0': 'luc',
#   'token.lower': 'lucu',
#   'token.prefix_2': 'lu',
#   'token.prefix_3': 'luc',
#   'token.suffix_2': 'cu',
#   'token.suffix_3': 'ucu',
#   'token.length': 4,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'ora',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'JV',
#   '+1:token.lower': '.',
#   '+1:token.is_alpha': False,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'O'},
#  {'token.tag': 'O',
#   'n_gram_0': '.',
#   'token.lower': '.',
#   'token.prefix_2': '.',
#   'token.prefix_3': '.',
#   'token.suffix_2': '.',
#   'token.suffix_3': '.',
#   'token.length': 1,
#   'token.is_alpha': False,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'lucu',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'ID',
#   '+1:token.lower': 'postingané',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': True,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': True,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'MIX-ID-JV'},
#  {'token.tag': 'MIX-ID-JV',
#   'n_gram_0': 'Pos',
#   'token.lower': 'postingané',
#   'token.prefix_2': 'Po',
#   'token.prefix_3': 'Pos',
#   'token.suffix_2': 'né',
#   'token.suffix_3': 'ané',
#   'token.length': 10,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': True,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': True,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': '.',
#   '-1:token.is_alpha': False,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'O',
#   '+1:token.lower': 'rècèhan',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'JV',
#   'n_gram_1': 'ost',
#   'n_gram_2': 'sti',
#   'n_gram_3': 'tin',
#   'n_gram_4': 'ing',
#   'n_gram_5': 'nga',
#   'n_gram_6': 'gan'},
#  {'token.tag': 'JV',
#   'n_gram_0': 'rèc',
#   'token.lower': 'rècèhan',
#   'token.prefix_2': 'rè',
#   'token.prefix_3': 'rèc',
#   'token.suffix_2': 'an',
#   'token.suffix_3': 'han',
#   'token.length': 7,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'postingané',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': True,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': True,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'MIX-ID-JV',
#   '+1:token.lower': 'banget',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'JV',
#   'n_gram_1': 'ècè',
#   'n_gram_2': 'cèh',
#   'n_gram_3': 'èha'},
#  {'token.tag': 'JV',
#   'n_gram_0': 'ban',
#   'token.lower': 'banget',
#   'token.prefix_2': 'ba',
#   'token.prefix_3': 'ban',
#   'token.suffix_2': 'et',
#   'token.suffix_3': 'get',
#   'token.length': 6,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'rècèhan',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'JV',
#   '+1:token.lower': '.',
#   '+1:token.is_alpha': False,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'O',
#   'n_gram_1': 'ang',
#   'n_gram_2': 'nge'},
#  {'token.tag': 'O',
#   'n_gram_0': '.',
#   'token.lower': '.',
#   'token.prefix_2': '.',
#   'token.prefix_3': '.',
#   'token.suffix_2': '.',
#   'token.suffix_3': '.',
#   'token.length': 1,
#   'token.is_alpha': False,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'banget',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'JV',
#   '+1:token.lower': 'coba',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': True,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': True,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'ID'},
#  {'token.tag': 'ID',
#   'n_gram_0': 'Cob',
#   'token.lower': 'coba',
#   'token.prefix_2': 'Co',
#   'token.prefix_3': 'Cob',
#   'token.suffix_2': 'ba',
#   'token.suffix_3': 'oba',
#   'token.length': 4,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': True,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': True,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': '.',
#   '-1:token.is_alpha': False,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'O',
#   '+1:token.lower': 'piknik',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'ID'},
#  {'token.tag': 'ID',
#   'n_gram_0': 'pik',
#   'token.lower': 'piknik',
#   'token.prefix_2': 'pi',
#   'token.prefix_3': 'pik',
#   'token.suffix_2': 'ik',
#   'token.suffix_3': 'nik',
#   'token.length': 6,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'coba',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': True,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': True,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'ID',
#   '+1:token.lower': 'sing',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'JV',
#   'n_gram_1': 'ikn',
#   'n_gram_2': 'kni'},
#  {'token.tag': 'JV',
#   'n_gram_0': 'sin',
#   'token.lower': 'sing',
#   'token.prefix_2': 'si',
#   'token.prefix_3': 'sin',
#   'token.suffix_2': 'ng',
#   'token.suffix_3': 'ing',
#   'token.length': 4,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'piknik',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'ID',
#   '+1:token.lower': 'adoh',
#   '+1:token.is_alpha': True,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'JV'},
#  {'token.tag': 'JV',
#   'n_gram_0': 'ado',
#   'token.lower': 'adoh',
#   'token.prefix_2': 'ad',
#   'token.prefix_3': 'ado',
#   'token.suffix_2': 'oh',
#   'token.suffix_3': 'doh',
#   'token.length': 4,
#   'token.is_alpha': True,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'sing',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'JV',
#   '+1:token.lower': '.',
#   '+1:token.is_alpha': False,
#   '+1:token.is_numeric': False,
#   '+1:token.is_capital': False,
#   '+1:token.is_title': False,
#   '+1:token.startswith_symbols': False,
#   '+1:token.contains_numeric': False,
#   '+1:token.contains_capital': False,
#   '+1:token.contains_quotes': False,
#   '+1:token.contains_hyphen': False,
#   '+1:tag': 'O'},
#  {'token.tag': 'O',
#   'n_gram_0': '.',
#   'token.lower': '.',
#   'token.prefix_2': '.',
#   'token.prefix_3': '.',
#   'token.suffix_2': '.',
#   'token.suffix_3': '.',
#   'token.length': 1,
#   'token.is_alpha': False,
#   'token.is_numeric': False,
#   'token.is_capital': False,
#   'token.is_title': False,
#   'token.startswith_symbols': False,
#   'token.contains_numeric': False,
#   'token.contains_capital': False,
#   'token.contains_quotes': False,
#   'token.contains_hyphen': False,
#   '-1:token.lower': 'adoh',
#   '-1:token.is_alpha': True,
#   '-1:token.is_numeric': False,
#   '-1:token.is_capital': False,
#   '-1:token.is_title': False,
#   '-1:token.startswith_symbols': False,
#   '-1:token.contains_numeric': False,
#   '-1:token.contains_capital': False,
#   '-1:token.contains_quotes': False,
#   '-1:token.contains_hyphen': False,
#   '-1:tag': 'JV',
#   'EOS': True}]

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',  # for gradient descent for optimization and getting model parameters
    c1=0.1, # Coefficient for Lasso (L1) regularization
    c2=0.1, # Coefficient for Ridge (L2) regularization
    max_iterations=100, # The maximum number of iterations for optimization algorithms, iteration for the gradient descent optimization
    all_possible_transitions=True   # Specify whether CRFsuite generates transition features that do not even occur in the training data
)

# %%
# %%time
crf.fit(X_train, y_train)
# Out:
# CPU times: user 12.8 s, sys: 73.6 ms, total: 12.9 s
# Wall time: 12.9 s
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %%
labels = ['ID', 'JV', 'EN', 'O', 'MIX-ID-EN', 'MIX-ID-JV', 'MIX-JV-EN']

# %%
y_pred = crf.predict(X_test)

# %%
flat_y = [item for y_ in y_test for item in y_]
flat_y_pred = [item for y_pred_ in y_pred for item in y_pred_]
print(classification_report(flat_y, flat_y_pred, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#           ID       1.00      1.00      1.00     26887
#           JV       1.00      1.00      1.00      5865
#           EN       1.00      1.00      1.00      6185
#            O       1.00      1.00      1.00     12090
#    MIX-ID-EN       1.00      1.00      1.00      1173
#    MIX-ID-JV       1.00      1.00      1.00       354
#    MIX-JV-EN       1.00      1.00      1.00       330
#
#     accuracy                           1.00     52884
#    macro avg       1.00      1.00      1.00     52884
# weighted avg       1.00      1.00      1.00     52884

# %%
import eli5
eli5.show_weights(crf)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>EN</th>
#
#                 <th>ID</th>
#
#                 <th>JV</th>
#
#                 <th>MIX-ID-EN</th>
#
#                 <th>MIX-ID-JV</th>
#
#                 <th>MIX-JV-EN</th>
#
#                 <th>O</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>EN</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.00%)" title="EN &rArr; EN">
#                             0.663
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.69%)" title="EN &rArr; ID">
#                             0.002
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.17%)" title="EN &rArr; JV">
#                             -0.143
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="EN &rArr; MIX-ID-EN">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.53%)" title="EN &rArr; MIX-ID-JV">
#                             -0.132
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="EN &rArr; MIX-JV-EN">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.71%)" title="EN &rArr; O">
#                             0.189
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>ID</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 97.57%)" title="ID &rArr; EN">
#                             0.033
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 85.80%)" title="ID &rArr; ID">
#                             0.407
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 87.60%)" title="ID &rArr; JV">
#                             -0.335
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 90.45%)" title="ID &rArr; MIX-ID-EN">
#                             0.231
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.91%)" title="ID &rArr; MIX-ID-JV">
#                             -0.069
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.11%)" title="ID &rArr; MIX-JV-EN">
#                             -0.176
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 93.56%)" title="ID &rArr; O">
#                             0.132
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>JV</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.77%)" title="JV &rArr; EN">
#                             -0.125
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 88.90%)" title="JV &rArr; ID">
#                             -0.286
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.80%)" title="JV &rArr; JV">
#                             0.58
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 87.51%)" title="JV &rArr; MIX-ID-EN">
#                             -0.339
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 89.60%)" title="JV &rArr; MIX-ID-JV">
#                             0.261
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 84.32%)" title="JV &rArr; MIX-JV-EN">
#                             0.468
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 98.09%)" title="JV &rArr; O">
#                             0.023
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>MIX-ID-EN</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="MIX-ID-EN &rArr; EN">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 94.93%)" title="MIX-ID-EN &rArr; ID">
#                             0.093
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 88.02%)" title="MIX-ID-EN &rArr; JV">
#                             -0.319
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="MIX-ID-EN &rArr; MIX-ID-EN">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="MIX-ID-EN &rArr; MIX-ID-JV">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="MIX-ID-EN &rArr; MIX-JV-EN">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="MIX-ID-EN &rArr; O">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>MIX-ID-JV</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.86%)" title="MIX-ID-JV &rArr; EN">
#                             -0.047
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.78%)" title="MIX-ID-JV &rArr; ID">
#                             -0.012
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 88.31%)" title="MIX-ID-JV &rArr; JV">
#                             0.308
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="MIX-ID-JV &rArr; MIX-ID-EN">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="MIX-ID-JV &rArr; MIX-ID-JV">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="MIX-ID-JV &rArr; MIX-JV-EN">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.18%)" title="MIX-ID-JV &rArr; O">
#                             -0.062
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>MIX-JV-EN</th>
#
#                         <t
