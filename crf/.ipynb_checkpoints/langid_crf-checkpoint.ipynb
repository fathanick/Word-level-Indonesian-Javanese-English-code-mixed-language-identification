# %%
from helper.dataset_reader import read_tsv
from lang_id_crf import *
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %%
langid = LanguageIdentifier()

# %% [markdown]
# ## Scenario 1
# 1. Using different data for training and test data.
# 2. Include named entity

# %%
train_data = read_tsv('../raw dataset/all-tagged-280322-train.tsv')
test_data = read_tsv('../raw dataset/all-tagged-080422-test.tsv')

# %%
langid.train_test_result_(train_data=train_data, test_data=test_data, n_label=8, model_name='mod_080422.pkl')
# Out:
#  Evaluation on the test data
# Confusion Matrix
#               precision    recall  f1-score   support
#
#           ID       0.84      0.97      0.90     11123
#           JV       0.89      0.82      0.86      4906
#           EN       0.91      0.75      0.82      1746
#           NE       0.85      0.32      0.47       675
#            O       0.99      0.95      0.97      4817
#    MIX-ID-EN       0.85      0.60      0.71       578
#    MIX-ID-JV       0.96      0.37      0.54       204
#    MIX-JV-EN       0.98      0.36      0.53       258
#
#     accuracy                           0.88     24307
#    macro avg       0.91      0.64      0.72     24307
# weighted avg       0.89      0.88      0.88     24307
#  Evaluation on the training data
# Confusion Matrix
#               precision    recall  f1-score   support
#
#           ID       0.96      0.99      0.97     38006
#           JV       0.93      0.93      0.93      8918
#           EN       0.98      0.92      0.95      4877
#           NE       0.97      0.84      0.90      2611
#            O       1.00      0.98      0.99     14499
#    MIX-ID-EN       0.99      0.97      0.98      2107
#    MIX-ID-JV       0.99      0.93      0.96       626
#    MIX-JV-EN       0.97      0.93      0.95       525
#
#     accuracy                           0.97     72169
#    macro avg       0.97      0.94      0.95     72169
# weighted avg       0.97      0.97      0.97     72169
# Top likely transitions:
# O          -> O          4.81595
# EN         -> O          3.98267
# ID         -> O          3.97329
# JV         -> O          3.84826
# NE         -> O          3.71802
# MIX-ID-EN  -> O          3.46678
# MIX-JV-EN  -> O          3.04951
# MIX-ID-JV  -> O          2.89825
# NE         -> NE         1.98663
# JV         -> JV         1.40808
# EN         -> EN         1.38555
# JV         -> MIX-JV-EN  0.94212
# ID         -> NE         0.87029
# EN         -> NE         0.84370
# JV         -> NE         0.59025
# ID         -> ID         0.58070
# MIX-JV-EN  -> JV         0.45967
# JV         -> MIX-ID-JV  0.45892
# MIX-ID-JV  -> JV         0.45104
# O          -> JV         0.34956
#
# Top unlikely transitions:
# MIX-ID-JV  -> ID         -0.60614
# NE         -> EN         -0.69336
# EN         -> MIX-JV-EN  -0.72078
# MIX-JV-EN  -> MIX-ID-JV  -0.86566
# MIX-ID-JV  -> EN         -0.87502
# ID         -> JV         -0.94499
# NE         -> MIX-ID-JV  -0.99214
# JV         -> ID         -1.08450
# NE         -> MIX-ID-EN  -1.09770
# MIX-JV-EN  -> EN         -1.12329
# NE         -> MIX-JV-EN  -1.20734
# MIX-ID-EN  -> MIX-ID-JV  -1.32114
# EN         -> MIX-ID-JV  -1.41263
# ID         -> MIX-JV-EN  -1.50922
# MIX-ID-JV  -> MIX-ID-EN  -1.71935
# MIX-JV-EN  -> ID         -1.82605
# MIX-JV-EN  -> MIX-ID-EN  -1.96571
# MIX-ID-EN  -> JV         -2.10342
# JV         -> MIX-ID-EN  -2.34714
# MIX-ID-EN  -> MIX-JV-EN  -2.41664
#
# Top positive:
# 10.702675 O          startswith_symbols
# 8.036532 O          n_gram_0:wkwk
# 7.765216 NE         n_gram_0:tokped
# 7.464896 MIX-ID-JV  n_gram_0:beline
# 7.440885 MIX-ID-JV  n_gram_0:jadine
# 7.394798 MIX-ID-JV  n_gram_0:uange
# 7.392878 MIX-JV-EN  n_gram_0:nyepam
# 7.392549 MIX-ID-JV  n_gram_0:minume
# 7.385889 O          n_gram_0:wkwkwk
# 7.170845 MIX-ID-JV  n_gram_0:carine
# 6.986929 MIX-ID-JV  n_gram_0:hapuse
# 6.937411 MIX-ID-EN  n_gram_0:dikick
# 6.936539 MIX-ID-EN  n_gram_0:dicut
# 6.891177 MIX-JV-EN  n_gram_0:kesave
# 6.787708 MIX-ID-JV  n_gram_0:soale
# 6.775775 MIX-ID-JV  n_gram_0:bajune
# 6.772736 O          n_gram_0:wkwkw
# 6.605224 NE         n_gram_0:shopee
# 6.548288 MIX-JV-EN  n_gram_0:hpne
# 6.517948 MIX-ID-EN  n_gram_0:ngeadd
#
# Top negative:
# -1.068238 NE         startswith_symbols
# -1.074535 JV         is_punctuation
# -1.092609 MIX-ID-EN  contains_aphostrope
# -1.104573 O          is_alpha
# -1.165367 MIX-ID-JV  is_capital
# -1.182686 ID         n_gram_0:to
# -1.268732 NE         contains_aphostrope
# -1.320129 ID         n_gram_0:yo
# -1.347277 EN         startswith_symbols
# -1.445461 O          n_gram_0:11
# -1.479394 ID         n_gram_1:gelin
# -1.481367 JV         startswith_symbols
# -1.503628 O          n_gram_0:7
# -1.621898 O          startswith_uppercase
# -1.682827 ID         n_gram_0:au
# -1.896398 JV         is_numeric
# -2.075742 ID         startswith_symbols
# -2.292182 ID         contains_aphostrope
# -2.952566 ID         is_numeric
# -4.353324 O          contains_alpha
# <IPython.core.display.HTML object>

# %% [markdown]
# ## Scenario 2:
# 1. Using different data for training and test data.
# 2. Exclude named entity. Replace NE into O

# %%
train_data_ = read_tsv('../raw dataset/all-tagged-280322-train-no-ne.tsv')
test_data_ = read_tsv('../raw dataset/all-tagged-080422-test-no-ne.tsv')

# %%
langid.train_test_result_(train_data=train_data_, test_data=test_data_, n_label=7, model_name='mod_080422_no_ne.pkl')
# Out:
#  Evaluation on the test data
#               precision    recall  f1-score   support
#
#           ID       0.84      0.97      0.90     11123
#           JV       0.89      0.82      0.85      4906
#           EN       0.92      0.73      0.81      1746
#            O       0.98      0.87      0.92      5492
#    MIX-ID-EN       0.85      0.61      0.71       578
#    MIX-ID-JV       0.95      0.39      0.55       204
#    MIX-JV-EN       0.99      0.37      0.54       258
#
#     accuracy                           0.88     24307
#    macro avg       0.92      0.68      0.75     24307
# weighted avg       0.89      0.88      0.88     24307
#
# Confusion Matrix
#  Evaluation on the training data
#               precision    recall  f1-score   support
#
#           ID       0.96      0.99      0.98     38006
#           JV       0.93      0.93      0.93      8918
#           EN       0.98      0.92      0.95      4877
#            O       0.99      0.97      0.98     17110
#    MIX-ID-EN       0.99      0.96      0.98      2107
#    MIX-ID-JV       0.99      0.93      0.96       626
#    MIX-JV-EN       0.97      0.93      0.95       525
#
#     accuracy                           0.97     72169
#    macro avg       0.97      0.95      0.96     72169
# weighted avg       0.97      0.97      0.97     72169
#
# Confusion Matrix
# Top likely transitions:
# O          -> O          4.78699
# ID         -> O          4.25394
# EN         -> O          4.16742
# JV         -> O          4.01865
# MIX-ID-EN  -> O          3.72671
# MIX-JV-EN  -> O          3.48912
# MIX-ID-JV  -> O          3.01544
# EN         -> EN         1.89161
# JV         -> JV         1.87697
# MIX-JV-EN  -> JV         1.24571
# JV         -> MIX-JV-EN  1.18940
# ID         -> ID         1.09323
# JV         -> MIX-ID-JV  0.81930
# O          -> JV         0.80497
# MIX-ID-JV  -> JV         0.79161
# O          -> ID         0.76677
# O          -> EN         0.75961
# ID         -> MIX-ID-EN  0.73696
# ID         -> EN         0.69564
# EN         -> ID         0.37566
#
# Top unlikely transitions:
# MIX-ID-EN  -> MIX-ID-EN  -0.17803
# MIX-JV-EN  -> MIX-JV-EN  -0.18574
# MIX-JV-EN  -> EN         -0.22515
# MIX-JV-EN  -> MIX-ID-JV  -0.24452
# O          -> MIX-JV-EN  -0.26672
# MIX-ID-JV  -> MIX-JV-EN  -0.27640
# MIX-ID-JV  -> ID         -0.31244
# ID         -> JV         -0.42746
# MIX-ID-JV  -> EN         -0.50641
# EN         -> MIX-JV-EN  -0.63495
# JV         -> ID         -0.64828
# MIX-ID-EN  -> MIX-ID-JV  -1.02870
# MIX-JV-EN  -> ID         -1.07996
# EN         -> MIX-ID-JV  -1.09495
# ID         -> MIX-JV-EN  -1.21147
# MIX-JV-EN  -> MIX-ID-EN  -1.42102
# MIX-ID-JV  -> MIX-ID-EN  -1.61616
# MIX-ID-EN  -> JV         -1.63791
# JV         -> MIX-ID-EN  -1.93564
# MIX-ID-EN  -> MIX-JV-EN  -2.56263
#
# Top positive:
# 8.528614 O          startswith_symbols
# 7.591539 O          n_gram_0:tokped
# 7.584652 MIX-ID-JV  n_gram_0:jadine
# 7.564531 MIX-ID-JV  n_gram_0:beline
# 7.500218 MIX-ID-JV  n_gram_0:minume
# 7.496334 MIX-ID-JV  n_gram_0:uange
# 7.334119 MIX-JV-EN  n_gram_0:nyepam
# 7.185014 MIX-ID-JV  n_gram_0:carine
# 7.106267 MIX-ID-EN  n_gram_0:dikick
# 7.075687 MIX-ID-EN  n_gram_0:dicut
# 7.004957 MIX-JV-EN  n_gram_0:kesave
# 6.959242 MIX-ID-JV  n_gram_0:hapuse
# 6.842526 MIX-ID-JV  n_gram_0:bajune
# 6.752778 O          n_gram_0:shopee
# 6.640338 MIX-ID-EN  n_gram_0:accnya
# 6.635999 O          n_gram_0:wkwk
# 6.621059 MIX-ID-EN  n_gram_0:ngeadd
# 6.617299 MIX-JV-EN  n_gram_0:hpne
# 6.591145 MIX-ID-JV  n_gram_0:soale
# 6.476325 EN         n_gram_0:hp
#
# Top negative:
# -0.983517 ID         is_numeric
# -1.009980 MIX-JV-EN  is_alpha
# -1.104322 ID         n_gram_0:mbok
# -1.121115 ID         n_gram_1:witte
# -1.135082 ID         n_gram_0:to
# -1.163042 ID         n_gram_0:yo
# -1.177796 ID         n_gram_0:pending
# -1.261127 EN         is_punctuation
# -1.274828 O          is_alpha
# -1.320130 MIX-ID-EN  startswith_symbols
# -1.342650 JV         is_punctuation
# -1.401517 O          n_gram_2:itter
# -1.511668 MIX-ID-JV  is_capital
# -1.532207 ID         n_gram_1:gelin
# -1.536543 EN         startswith_symbols
# -1.667814 JV         startswith_symbols
# -1.977839 ID         n_gram_0:au
# -2.302955 O          contains_alpha
# -2.366542 ID         contains_aphostrope
# -3.267283 ID         startswith_symbols

# %% [markdown]
# ## Scenario 3:
# 1. Merge between training and test data
# 2. Include named entity

# %%
dataset = read_tsv('../raw dataset/all-tagged-090422-merged.tsv')
langid.train_test_result(data=dataset, test_size=0.33, n_label=8, model_name='mod_090422.pkl')
# Out:
#  Evaluation on the test data
#               precision    recall  f1-score   support
#
#           ID       0.89      0.97      0.93     16311
#           JV       0.85      0.85      0.85      4641
#           EN       0.92      0.68      0.79      2218
#           NE       0.84      0.39      0.53      1013
#            O       0.99      0.96      0.97      6508
#    MIX-ID-EN       0.98      0.86      0.92       852
#    MIX-ID-JV       0.97      0.82      0.89       286
#    MIX-JV-EN       0.96      0.82      0.89       250
#
#     accuracy                           0.91     32079
#    macro avg       0.93      0.79      0.84     32079
# weighted avg       0.91      0.91      0.90     32079
#
# Confusion Matrix
#  Evaluation on the training data
#               precision    recall  f1-score   support
#
#           ID       0.96      0.99      0.97     32818
#           JV       0.93      0.94      0.94      9183
#           EN       0.98      0.92      0.95      4405
#           NE       0.98      0.83      0.90      2273
#            O       1.00      0.98      0.99     12808
#    MIX-ID-EN       0.99      0.97      0.98      1833
#    MIX-ID-JV       1.00      0.90      0.95       544
#    MIX-JV-EN       0.97      0.93      0.95       533
#
#     accuracy                           0.97     64397
#    macro avg       0.98      0.93      0.95     64397
# weighted avg       0.97      0.97      0.97     64397
#
# Confusion Matrix
# Top likely transitions:
# O          -> O          5.17360
# EN         -> O          4.11583
# ID         -> O          4.06027
# JV         -> O          3.73404
# NE         -> O          3.72964
# MIX-ID-EN  -> O          3.46917
# MIX-JV-EN  -> O          3.33946
# MIX-ID-JV  -> O          3.07989
# NE         -> NE         1.95126
# EN         -> EN         1.72254
# JV         -> JV         1.25530
# EN         -> NE         1.00035
# ID         -> NE         0.90015
# ID         -> ID         0.79578
# O          -> ID         0.65266
# JV         -> MIX-JV-EN  0.61866
# O          -> EN         0.60931
# O          -> JV         0.56891
# JV         -> NE         0.49632
# O          -> NE         0.48452
#
# Top unlikely transitions:
# NE         -> EN         -0.54049
# MIX-ID-JV  -> ID         -0.60640
# MIX-JV-EN  -> EN         -0.69430
# ID         -> JV         -0.91559
# MIX-ID-JV  -> EN         -0.98399
# MIX-JV-EN  -> MIX-ID-JV  -1.06229
# EN         -> MIX-JV-EN  -1.06852
# NE         -> MIX-ID-JV  -1.09633
# JV         -> ID         -1.18233
# ID         -> MIX-JV-EN  -1.32770
# NE         -> MIX-ID-EN  -1.35465
# MIX-JV-EN  -> ID         -1.48872
# EN         -> MIX-ID-JV  -1.62539
# MIX-ID-EN  -> MIX-ID-JV  -1.70571
# MIX-ID-EN  -> JV         -2.06321
# NE         -> MIX-JV-EN  -2.17577
# MIX-ID-EN  -> MIX-JV-EN  -2.34902
# JV         -> MIX-ID-EN  -2.42521
# MIX-ID-JV  -> MIX-ID-EN  -2.96843
# MIX-JV-EN  -> MIX-ID-EN  -3.04482
#
# Top positive:
# 9.012095 O          startswith_symbols
# 8.106292 MIX-JV-EN  n_gram_0:hpne
# 7.971432 O          n_gram_0:wkwk
# 7.481387 O          n_gram_0:wkwkwk
# 7.422341 NE         n_gram_0:tokped
# 7.261590 MIX-ID-EN  n_gram_0:dicopy
# 7.259586 MIX-ID-JV  n_gram_0:jadine
# 7.148335 MIX-ID-JV  n_gram_0:beline
# 7.087358 MIX-JV-EN  n_gram_0:nyepam
# 6.936847 MIX-ID-JV  n_gram_0:minume
# 6.844520 MIX-ID-EN  n_gram_0:dikick
# 6.810354 MIX-JV-EN  n_gram_0:Hpne
# 6.772080 MIX-ID-JV  n_gram_0:soale
# 6.744865 O          n_gram_0:wkwkw
# 6.716514 MIX-JV-EN  n_gram_0:dicopy
# 6.692452 MIX-ID-EN  n_gram_0:dicut
# 6.692027 MIX-ID-JV  n_gram_0:uange
# 6.673149 MIX-ID-JV  n_gram_0:hapuse
# 6.663415 MIX-JV-EN  n_gram_0:kesave
# 6.587299 MIX-ID-JV  n_gram_0:carine
#
# Top negative:
# -0.959973 ID         n_gram_0:to
# -0.983039 ID         n_gram_1:witte
# -0.993800 ID         n_gram_0:ono
# -1.011636 EN         contains_numeric
# -1.012859 ID         n_gram_0:au
# -1.047570 O          n_gram_0:12
# -1.087385 MIX-ID-EN  startswith_symbols
# -1.088307 ID         n_gram_1:xplor
# -1.258221 NE         n_gram_2:itter
# -1.300748 JV         startswith_symbols
# -1.339853 MIX-ID-JV  contains_numeric
# -1.343859 ID         is_numeric
# -1.424675 NE         startswith_symbols
# -1.616001 EN         startswith_symbols
# -1.711735 ID         contains_aphostrope
# -1.724089 O          startswith_uppercase
# -1.728858 O          n_gram_0:11
# -1.828604 MIX-ID-EN  startswith_uppercase
# -2.148585 O          is_alpha
# -3.285809 O          contains_alpha

# %%
dataset_no_ne = read_tsv('../raw dataset/all-tagged-090422-merged-no-ne.tsv')
langid.train_test_result(data=dataset_no_ne, test_size=0.33, n_label=7, model_name='mod_090422_no_ne.pkl')
# Out:
#  Evaluation on the test data
#               precision    recall  f1-score   support
#
#           ID       0.89      0.97      0.93     16311
#           JV       0.85      0.85      0.85      4641
#           EN       0.93      0.68      0.78      2218
#            O       0.98      0.89      0.93      7521
#    MIX-ID-EN       0.98      0.86      0.92       852
#    MIX-ID-JV       0.97      0.81      0.89       286
#    MIX-JV-EN       0.96      0.82      0.89       250
#
#     accuracy                           0.91     32079
#    macro avg       0.94      0.84      0.88     32079
# weighted avg       0.91      0.91      0.90     32079
#
# Confusion Matrix
#  Evaluation on the training data
#               precision    recall  f1-score   support
#
#           ID       0.96      0.99      0.98     32818
#           JV       0.93      0.94      0.94      9183
#           EN       0.98      0.92      0.95      4405
#            O       1.00      0.97      0.98     15081
#    MIX-ID-EN       0.99      0.97      0.98      1833
#    MIX-ID-JV       1.00      0.90      0.94       544
#    MIX-JV-EN       0.97      0.93      0.95       533
#
#     accuracy                           0.97     64397
#    macro avg       0.98      0.94      0.96     64397
# weighted avg       0.97      0.97      0.97     64397
#
# Confusion Matrix
# Top likely transitions:
# O          -> O          4.18663
# EN         -> O          3.30131
# ID         -> O          3.29999
# JV         -> O          2.96704
# MIX-JV-EN  -> O          2.82039
# MIX-ID-EN  -> O          2.65659
# MIX-ID-JV  -> O          2.38312
# EN         -> EN         1.48068
# JV         -> JV         1.21672
# ID         -> ID         0.78881
# O          -> ID         0.67761
# O          -> JV         0.56077
# MIX-JV-EN  -> JV         0.55990
# O          -> EN         0.52242
# ID         -> MIX-ID-EN  0.47668
# JV         -> MIX-JV-EN  0.39257
# MIX-ID-JV  -> JV         0.33806
# ID         -> EN         0.14890
# EN         -> ID         0.05339
# JV         -> MIX-ID-JV  0.05109
#
# Top unlikely transitions:
# MIX-ID-EN  -> EN         -0.53400
# MIX-ID-JV  -> MIX-JV-EN  -0.54574
# JV         -> EN         -0.56282
# O          -> MIX-JV-EN  -0.60368
# MIX-JV-EN  -> EN         -0.62096
# MIX-ID-JV  -> ID         -0.65506
# MIX-JV-EN  -> MIX-ID-JV  -0.83670
# ID         -> JV         -0.97203
# JV         -> ID         -1.17493
# MIX-ID-JV  -> EN         -1.17505
# MIX-JV-EN  -> ID         -1.26333
# EN         -> MIX-JV-EN  -1.39969
# ID         -> MIX-JV-EN  -1.57173
# MIX-ID-EN  -> MIX-ID-JV  -1.67725
# EN         -> MIX-ID-JV  -1.71287
# MIX-ID-EN  -> JV         -2.20905
# MIX-ID-EN  -> MIX-JV-EN  -2.23020
# MIX-JV-EN  -> MIX-ID-EN  -2.31257
# JV         -> MIX-ID-EN  -2.33748
# MIX-ID-JV  -> MIX-ID-EN  -2.83509
#
# Top positive:
# 8.066396 MIX-JV-EN  n_gram_0:hpne
# 7.454984 O          startswith_symbols
# 7.267051 MIX-ID-JV  n_gram_0:jadine
# 7.266359 O          n_gram_0:tokped
# 7.166387 MIX-ID-EN  n_gram_0:dicopy
# 7.145809 MIX-ID-JV  n_gram_0:beline
# 7.064577 MIX-JV-EN  n_gram_0:nyepam
# 6.942931 MIX-JV-EN  n_gram_0:Hpne
# 6.925153 MIX-ID-EN  n_gram_0:dikick
# 6.906924 MIX-ID-JV  n_gram_0:minume
# 6.767229 O          n_gram_0:wkwk
# 6.724312 MIX-ID-JV  n_gram_0:soale
# 6.707531 MIX-ID-EN  n_gram_0:dicut
# 6.670393 MIX-ID-JV  n_gram_0:hapuse
# 6.670302 MIX-ID-JV  n_gram_0:uange
# 6.648225 MIX-JV-EN  n_gram_0:kesave
# 6.573595 MIX-JV-EN  n_gram_0:dicopy
# 6.542699 MIX-ID-JV  n_gram_0:carine
# 6.503103 JV         n_gram_0:e
# 6.484038 MIX-ID-JV  n_gram_0:bajune
#
# Top negative:
# -0.853468 O          n_gram_1:angga
# -0.863589 ID         n_gram_0:au
# -0.865314 ID         n_gram_0:ono
# -0.897051 EN         contains_numeric
# -0.959661 MIX-ID-EN  contains_aphostrope
# -1.060535 O          is_alpha
# -1.081145 ID         n_gram_1:witte
# -1.192151 ID         n_gram_1:xplor
# -1.242366 MIX-ID-JV  contains_numeric
# -1.274090 MIX-ID-EN  startswith_uppercase
# -1.357228 O          n_gram_2:itter
# -1.373419 MIX-JV-EN  startswith_symbols
# -1.387427 MIX-ID-JV  startswith_symbols
# -1.388074 ID         is_numeric
# -1.504150 O          contains_alpha
# -1.610272 ID         contains_aphostrope
# -1.630949 ID         n_gram_0:to
# -1.785856 MIX-ID-EN  startswith_symbols
# -2.055766 JV         startswith_symbols
# -2.359030 EN         startswith_symbols
