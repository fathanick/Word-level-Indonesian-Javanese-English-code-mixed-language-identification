# %%
import numpy as np
from deep_learning_models import *
from helper.dataset_reader import read_tsv
from helper.utils import *
import pandas as pd

# %%
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))

# %%
merged_data = read_tsv('../../dataset/comlid-data-140422-v1.tsv')

train_data = read_tsv('../../dataset/train.tsv')
val_data = read_tsv('../../dataset/val.tsv')
test_data = read_tsv('../../dataset/test.tsv')

# %%
X_train, y_train = input_converter(merged_data, train_data)
X_val, y_val = input_converter(merged_data, val_data)
X_test, y_test = input_converter(merged_data, test_data)

# %%
df = list_to_dataframe(merged_data)
words = get_unique_words(df)
tags = get_unique_tags(df)

num_words = len(words)
num_tags = len(tags)
max_len = 100

# %%
model = blstm_crf_model(num_words, num_tags, max_len)

# %%
from tensorflow.keras.callbacks import EarlyStopping
num_epoch = 50
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='max',
                                   baseline=None, restore_best_weights=False)
callbacks = [early_stopping]

history = model.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    epochs=num_epoch,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# 91/91 [==============================] - 20s 164ms/step - decode_sequence_acc: 0.6460 - loss: 15.3339 - val_decode_sequence_acc: 0.9708 - val_loss: 9.5709
# Epoch 2/50
# 91/91 [==============================] - 15s 165ms/step - decode_sequence_acc: 0.9876 - loss: 3.5180 - val_decode_sequence_acc: 0.9722 - val_loss: 9.2684
# Epoch 3/50
# 91/91 [==============================] - 15s 166ms/step - decode_sequence_acc: 0.9939 - loss: 1.6731 - val_decode_sequence_acc: 0.9732 - val_loss: 9.0266
# Epoch 4/50
# 91/91 [==============================] - 17s 186ms/step - decode_sequence_acc: 0.9958 - loss: 1.0905 - val_decode_sequence_acc: 0.9740 - val_loss: 9.9164
# Epoch 5/50
# 91/91 [==============================] - 14s 152ms/step - decode_sequence_acc: 0.9966 - loss: 0.8774 - val_decode_sequence_acc: 0.9731 - val_loss: 10.9243
# Epoch 6/50
# 91/91 [==============================] - 15s 161ms/step - decode_sequence_acc: 0.9971 - loss: 0.7304 - val_decode_sequence_acc: 0.9726 - val_loss: 11.4379
# Epoch 7/50
# 91/91 [==============================] - 14s 155ms/step - decode_sequence_acc: 0.9976 - loss: 0.6217 - val_decode_sequence_acc: 0.9728 - val_loss: 12.9196
# Epoch 8/50
# 91/91 [==============================] - 15s 165ms/step - decode_sequence_acc: 0.9978 - loss: 0.5699 - val_decode_sequence_acc: 0.9720 - val_loss: 11.3658
# Epoch 9/50
# 91/91 [==============================] - 18s 201ms/step - decode_sequence_acc: 0.9982 - loss: 0.4711 - val_decode_sequence_acc: 0.9717 - val_loss: 14.0516
# Epoch 10/50
# 91/91 [==============================] - 16s 180ms/step - decode_sequence_acc: 0.9984 - loss: 0.4236 - val_decode_sequence_acc: 0.9729 - val_loss: 13.2675
# Epoch 11/50
# 91/91 [==============================] - 15s 166ms/step - decode_sequence_acc: 0.9986 - loss: 0.3451 - val_decode_sequence_acc: 0.9718 - val_loss: 13.6989
# Epoch 12/50
# 91/91 [==============================] - 14s 159ms/step - decode_sequence_acc: 0.9986 - loss: 0.3321 - val_decode_sequence_acc: 0.9729 - val_loss: 14.7470
# Epoch 13/50
# 91/91 [==============================] - 15s 168ms/step - decode_sequence_acc: 0.9991 - loss: 0.2332 - val_decode_sequence_acc: 0.9732 - val_loss: 14.4768
# Epoch 14/50
# 91/91 [==============================] - 15s 162ms/step - decode_sequence_acc: 0.9989 - loss: 0.2663 - val_decode_sequence_acc: 0.9724 - val_loss: 15.7880
# Epoch 15/50
# 91/91 [==============================] - 15s 161ms/step - decode_sequence_acc: 0.9989 - loss: 0.2910 - val_decode_sequence_acc: 0.9716 - val_loss: 14.5933
# Epoch 16/50
# 91/91 [==============================] - 15s 162ms/step - decode_sequence_acc: 0.9990 - loss: 0.2454 - val_decode_sequence_acc: 0.9720 - val_loss: 14.5553
# Epoch 17/50
# 91/91 [==============================] - 16s 176ms/step - decode_sequence_acc: 0.9992 - loss: 0.1965 - val_decode_sequence_acc: 0.9705 - val_loss: 14.6037
# Epoch 18/50
# 91/91 [==============================] - 15s 164ms/step - decode_sequence_acc: 0.9991 - loss: 0.2052 - val_decode_sequence_acc: 0.9714 - val_loss: 15.8524
# Epoch 19/50
# 91/91 [==============================] - 14s 157ms/step - decode_sequence_acc: 0.9992 - loss: 0.1794 - val_decode_sequence_acc: 0.9722 - val_loss: 15.5491
# Epoch 20/50
# 91/91 [==============================] - 14s 158ms/step - decode_sequence_acc: 0.9993 - loss: 0.1738 - val_decode_sequence_acc: 0.9715 - val_loss: 17.2397
# Epoch 21/50
# 91/91 [==============================] - 14s 158ms/step - decode_sequence_acc: 0.9993 - loss: 0.1758 - val_decode_sequence_acc: 0.9727 - val_loss: 18.3773
# Epoch 22/50
# 91/91 [==============================] - 15s 162ms/step - decode_sequence_acc: 0.9994 - loss: 0.1601 - val_decode_sequence_acc: 0.9696 - val_loss: 15.4467
# Epoch 23/50
# 91/91 [==============================] - 15s 160ms/step - decode_sequence_acc: 0.9993 - loss: 0.1713 - val_decode_sequence_acc: 0.9722 - val_loss: 16.7838
# Epoch 24/50
# 91/91 [==============================] - 15s 160ms/step - decode_sequence_acc: 0.9993 - loss: 0.1818 - val_decode_sequence_acc: 0.9724 - val_loss: 14.9983
# Epoch 25/50
# 91/91 [==============================] - 14s 159ms/step - decode_sequence_acc: 0.9993 - loss: 0.1690 - val_decode_sequence_acc: 0.9726 - val_loss: 17.2161
# Epoch 26/50
# 91/91 [==============================] - 15s 166ms/step - decode_sequence_acc: 0.9993 - loss: 0.1684 - val_decode_sequence_acc: 0.9723 - val_loss: 16.3027

# %%
print(model.evaluate(X_test, y_test))
model.save('model/blstm_crf.h5')
# Out:
# 56/56 [==============================] - 2s 32ms/step - decode_sequence_acc: 0.9734 - loss: 11.1018
# [0.9733801484107971, 13.395139694213867]

# %%
# just check the oputput
a,b,c,d = model.predict(X_test)
print(b.shape)
y_pred = np.argmax(b, axis=-1)
y_pred
# Out:
# (1781, 100, 7)
# array([[1, 1, 3, ..., 6, 6, 6],
#        [6, 6, 3, ..., 6, 6, 6],
#        [1, 6, 1, ..., 6, 6, 6],
#        ...,
#        [1, 3, 6, ..., 6, 6, 6],
#        [6, 6, 1, ..., 6, 6, 6],
#        [1, 0, 1, ..., 6, 6, 6]])

# %%
i = np.random.randint(0, X_test.shape[0]) #659
decode_seq, potentials, seq_length, kernel = model.predict(np.array([X_test[i]]))
p = np.argmax(potentials, axis=-1)
y_true = y_test[i]
print("{:30}{:10}\t {}\n".format("Word", "True", "Pred"))
print("-" *60)

for w, true, pred in zip(X_test[i], y_true, p[0]):
    if words[w-1] != "ENDPAD":
        print("{:30}{:10}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# Word                          True      	 Pred
#
# ------------------------------------------------------------
# oyi                           JV        	JV
# rek                           JV        	JV
# penjual                       ID        	ID
# ayam                          ID        	ID
# potong                        ID        	ID
# di                            ID        	ID
# pasar                         ID        	ID
# itu                           ID        	ID
# mau                           ID        	ID
# apa                           ID        	ID
# engga                         ID        	ID
# ya                            ID        	ID
# kalo                          ID        	ID
# misal                         ID        	ID
# kita                          ID        	ID
# beline                        MIX-ID-JV 	MIX-ID-JV
# fillet                        EN        	ID
# ?                             O         	O
# spill                         EN        	EN
# dipasar                       ID        	EN
# mana                          ID        	ID
# dong                          ID        	ID
# 🙏                             O         	O
# 🏻                             O         	O

# %%
all_w_pair = []
all_true_pair = []
all_pred_pair = []

for i in range(len(X_test)):
    decode_seq, potentials, seq_length, kernel = model.predict(np.array([X_test[i]]))
    p = np.argmax(potentials, axis=-1)
    y_true = y_test[i]
    w_pair = []
    true_pair = []
    pred_pair = []
    for w, true, pred in zip(X_test[i], y_true, p[0]):
        if words[w-1] != "ENDPAD":
            print("{:30}{:10}\t{}".format(words[w-1], tags[true], tags[pred]))
            w_pair.append(words[w-1])
            true_pair.append(tags[true])
            pred_pair.append(tags[pred])
    all_w_pair.append(w_pair)
    all_true_pair.append(true_pair)
    all_pred_pair.append(pred_pair)
# Out:
# Cara                          ID        	ID
# menghilangkan                 ID        	ID
# ovt                           EN        	EN
# gimana                        ID        	ID
# :D                            O         	O
# ,                             O         	O
# walau                         ID        	ID
# udh                           ID        	ID
# mule                          ID        	ID
# teneg                         ID        	ID
# tapi                          ID        	ID
# ga                            ID        	ID
# teneg                         ID        	ID
# lagi                          ID        	ID
# jadinya                       ID        	ID
# (                             O         	O
# harusnya                      ID        	ID
# ke                            ID        	ID
# priv                          EN        	JV
# tapi                          ID        	ID
# males                         ID        	ID
# switch                        EN        	EN
# acc                           EN        	EN
# )                             O         	O
# eng                           O         	O
# !                             O         	O
# Last                          EN        	EN
# night                         EN        	EN
# i                             EN        	EN
# ...                           O         	O
# dinner                        EN        	EN
# with                          EN        	EN
# my                            EN        	EN
# friend                        EN        	EN
# when                          EN        	EN
# it                            EN        	EN
# rainded                       EN        	EN
# heavily                       EN        	EN
# So                            EN        	EN
# ,                             O         	O
# i                             EN        	EN
# cancelled                     EN        	EN
# it                            EN        	EN
# Kalau                         ID        	ID
# kayaa                         ID        	EN
# gitu                          ID        	ID
# jawabnya                      ID        	ID
# pake                          ID        	ID
# verb                          EN        	EN
# 2                             O         	O
# boleh                         ID        	ID
# nggak                         ID        	ID
# yaa                           ID        	ID
# ?                             O         	O
# (                             O         	O
# Wanted                        EN        	EN
# to                            EN        	EN
# had                           EN        	EN
# /                             O         	O
# want                          EN        	EN
# to                            EN        	EN
# have                          EN        	EN
# )                             O         	O
# ??                            O         	O
# Kira                          ID        	ID
# kira                          ID        	ID
# yang                          ID        	ID
# bener                         ID        	ID
# yang                          ID        	ID
# mana                          ID        	ID
# yaa                           ID        	ID
# ,                             O         	O
# thankyou                      EN        	EN
# kok                           ID        	ID
# twt                           O         	O
# aku                           ID        	ID
# skrng                         ID        	ID
# jd                            ID        	ID
# lemot                         ID        	ID
# ya                            ID        	ID
# ..                            O         	O
# buka                          ID        	ID
# gambar                        ID        	ID
# lama                          ID        	ID
# bngt                          ID        	ID
# trs                           ID        	ID
# pengen                        ID        	ID
# buka                          ID        	ID
# dm                            EN        	EN
# juga                          ID        	ID
# loadingnya                    MIX-ID-EN 	MIX-ID-EN
# lama                          ID        	ID
# bngt                          ID        	ID
# 😪                             O         	O
# @leadersheepy                 O         	O
# @tokopedia                    O         	O
# gilssss                       EN        	JV
# collab                        EN        	JV
# maneh                         JV        	JV
# ,                             O         	O
# duite                         JV        	JV
# akeh                          JV        	JV
# sekali                        ID        	ID
# 🤤                             O         	ID
# 🤤                             O         	ID
# 🤔                             O         	O
# yahhh                         ID        	ID
# sangane                       JV        	ID
# serum                         ID        	ID
# lebih                         ID        	ID
# penting                       ID        	ID
# ,                             O         	O
# dan                           ID        	ID
# ng                            JV        	JV
# toko                          JV        	JV
# iki                           JV        	JV
# gak                           JV        	JV
# diskon                        ID        	ID
# wkwkkw                        O         	O
# kowe                          JV        	JV
# wes                           JV        	JV
# entuk                         JV        	JV
# pc                            EN        	EN
# ne                            JV        	JV
# sopo                          JV        	JV
# ae                            JV        	JV
# ?                             O         	O
# ?                             O         	O
# Lagi                          ID        	ID
# nyetel                        ID        	EN
# be                            EN        	EN
# together                      EN        	EN
# trus                          ID        	ID
# iseng                         ID        	ID
# cek                           ID        	ID
# playlist                      EN        	EN
# video                         ID        	ID
# gyang                         O         	EN
# do                            EN        	EN
# it                            EN        	EN
# di                            ID        	ID
# akun                          ID        	ID
# official                      EN        	EN
# deg2an                        ID        	ID
# bgt                           ID        	ID
# scroll                        EN        	EN
# kebawah                       ID        	ID
# udah                          ID        	ID
# pikiran                       ID        	ID
# macem2                        ID        	ID
# dan                           ID        	ID
# hamdalah                      ID        	ID
# masih                         ID        	ID
# ada                           ID        	ID
# irun                          O         	ID
# disitu                        ID        	ID
# ngga                          ID        	ID
# diremove                      MIX-ID-EN 	MIX-ID-EN
# 😭                             O         	O
# Please                        EN        	EN
# anyone                        EN        	EN
# ,                             O         	O
# bantuin                       ID        	ID
# gue                           ID        	ID
# bikin                         ID        	ID
# tugas                         ID        	ID
# b                             O         	O
# ,                             O         	O
# indo                          O         	O
# tentang                       ID        	ID
# covid                         O         	O
# dong                          ID        	ID
# 😭                             O         	O
# dear                          EN        	EN
# sekonco                       JV        	ID
# babii                         ID        	EN
# kalo                          ID        	ID
# ada                           ID        	ID
# akun                          ID        	ID
# jelek                         ID        	ID
# langsung                      ID        	ID
# direport                      MIX-ID-EN 	MIX-ID-EN
# aja                           ID        	ID
# ya                            ID        	ID
# ,                             O         	O
# makasih                       ID        	ID
# 🫶                             O         	O
# 🏻                             O         	O
# Inti                          ID        	O
# kasus                         ID        	ID
# OF                            O         	ID
# ,                             O         	O
# karena                        ID        	ID
# dianggap                      ID        	ID
# melanggar                     ID        	ID
# UU                            ID        	ID
# ITE                           ID        	EN
# diproses                      ID        	JV
# semua                         ID        	ID
# .                             O         	O
# Terus                         ID        	ID
# ,                             O         	O
# kok                           ID        	ID
# speednya                      MIX-ID-EN 	MIX-ID-EN
# cepet                         ID        	ID
# banget                        ID        	ID
# ,                             O         	O
# dapet                         ID        	ID
# referral                      EN        	ID
# kali                          ID        	ID
# ya                            ID        	ID
# dari                          ID        	ID
# OF                            O         	EN
# kalo                          ID        	ID
# bisa                          ID        	ID
# resolve                       EN        	ID
# issue                         EN        	ID
# legalnya                      ID        	ID
# ?                             O         	O
# #yaudahlahya                  O         	ID
# kerja                         ID        	ID
# gih                           ID        	ID
# lu                            ID        	ID
# om                            ID        	ID
# ,                             O         	O
# masih                         ID        	ID
# miskin                        ID        	ID
# kan                           ID        	ID
# ,                             O         	O
# ingat                         ID        	ID
# baktimu                       ID        	ID
# berupa                        ID        	ID
# pajak                         ID        	O
# pada                          ID        	ID
# negara                        ID        	ID
# ..                            O         	O
# ingat                         ID        	ID
# karmamu                       ID        	ID
# uga                           ID        	ID
# ..                            O         	O
# @kimd0ki_                     O         	ID
# di                            ID        	ID
# bub                           EN        	EN
# aja                           ID        	ID
# ,                             O         	O
# block                         EN        	EN
# dulu                          ID        	ID
# akun                          ID        	ID
# yang                          ID        	ID
# ngefollow                     MIX-ID-EN 	MIX-ID-EN
# kamu                          ID        	ID
# ,                             O         	O
# habis                         ID        	ID
# diblock                       MIX-ID-EN 	MIX-ID-EN
# buka                          ID        	ID
# lagi                          ID        	ID
# blockan                       MIX-ID-EN 	ID
# nya                           ID        	ID
# nah                           ID        	ID
# itu                           ID        	ID
# otomatis                      ID        	ID
# dia                           ID        	ID
# udah                          ID        	ID
# ga                            ID        	ID
# follow                        EN        	EN
# kamu                          ID        	ID
# lagi                          ID        	ID
# gitu                          ID        	ID
# sih                           ID        	ID
# kalau                         ID        	ID
# gasalah                       ID        	O
# Iku                           JV        	O
# chanel                        EN        	EN
# apa                           ID        	ID
# ?                             O         	O
# Kbs                           O         	ID
# sbs                           O         	EN
# mbc                           O         	ID
# ?                             O         	O
# @henasdeliara:                O         	ID
# Downloadke                    MIX-JV-EN 	MIX-JV-EN
# Sung                          O         	JV
# drama                         ID        	EN
# 10EP                          ID        	O
# "                             O         	O
# Please                        EN        	EN
# Remember                      EN        	EN
# ,                             O         	O
# Princess                      EN        	ID
# "                             O         	O
# :)                            O         	O
# He'll                         EN        	EN
# be                            EN        	EN
# acting                        EN        	EN
# as                            EN        	EN
# 정기억                           O         	EN
# 4th                           EN        	EN
# Nov                           EN        	O
# 2013                          O         	O
# "                             O         	O
# mesti                         JV        	JV
# lek                           JV        	JV
# pas                           JV        	JV
# duwe                          JV        	JV
# gratis                        ID        	ID
# ongkir                        ID        	ID
# akeh                          JV        	JV
# tapi                          JV        	JV
# gak                           JV        	JV
# pingin                        JV        	JV
# check                         EN        	EN
# out                           EN        	EN
# ,                             O         	O
# sedeng                        JV        	EN
# gratis                        JV        	JV
# ongkire                       MIX-ID-JV 	MIX-ID-JV
# hangus                        ID        	ID
# kaet                          JV        	ID
# kepikiran                     JV        	ID
# check                         EN        	EN
# out                           EN        	EN
# .                             O         	O
# babi                          ID        	JV
# gak                           ID        	JV
# tuhh                          ID        	O
# @OngisnadeNet                 O         	O
# Padahal                       ID        	ID
# Robby                         O         	O
# penyelamatane                 MIX-ID-JV 	MIX-ID-JV
# akeh                          JV        	JV
# ,                             O         	O
# menutupi                      ID        	ID
# lubang                        ID        	ID
# Bagas                         O         	O
# &                             O         	O
# amp                           O         	O
# ;                             O         	O
# Rizky                         O         	O
# Dwi                           O         	O
# .                             O         	O
# @vickyvrgwn                   O         	O
# Tak                           JV        	JV
# hapuse                        MIX-ID-JV 	MIX-ID-JV
# .                             O         	O
# @literarybase                 O         	O
# Dan                           ID        	ID
# setelah                       ID        	ID
# semua                         ID        	ID
# perjuangan                    ID        	ID
# yang                          ID        	ID
# kamu                          ID        	ID
# lakukan                       ID        	ID
# ,                             O         	O
# semua                         ID        	ID
# sakit                         ID        	ID
# yang                          ID        	ID
# kamu                          ID        	ID
# lalui                         ID        	ID
# akhirnya                      ID        	ID
# yang                          ID        	ID
# diinginkan                    ID        	ID
# tercapai                      ID        	ID
# .                             O         	O
# Sekarang                      ID        	ID
# saatnya                       ID        	ID
# istirahat                     ID        	ID
# sejenak                       ID        	ID
# ,                             O         	O
# kamu                          ID        	ID
# telah                         ID        	ID
# berjuang                      ID        	ID
# dengan                        ID        	ID
# hebat                         ID        	ID
# @zhevyeah                     O         	O
# @Apriado8                     O         	O
# @idextratime                  O         	O
# @Corriere                     O         	ID
# Ya                            ID        	ID
# itu                           ID        	ID
# ,                             O         	O
# sebenarnya                    ID        	ID
# setelah                       ID        	ID
# kejadian                      ID        	ID
# kesekian                      ID        	EN
# kalinya                       ID        	ID
# kyak                          ID        	EN
# harusnya                      ID        	ID
# Ballon                        EN        	ID
# D'or                          EN        	ID
# dan                           ID        	ID
# FIFA                          O         	EN
# best                          EN        	EN
# player                        EN        	EN
# kesepannya                    ID        	EN
# harus                         ID        	ID
# dibuat                        ID        	ID
# standar                       ID        	ID
# pasti                         ID        	ID
# yg                            ID        	ID
# objektif                      ID        	ID
# dan                           ID        	ID
# baku                          ID        	EN
# .                             O         	O
# Percuma                       ID        	ID
# vote                          EN        	O
# terus                         ID        	ID
# ,                             O         	O
# percuma                       ID        	ID
# ada                           ID        	ID
# statistik                     ID        	ID
# hebat                         ID        	ID
# ,                             O         	O
# percuma                       ID        	ID
# dapet                         ID        	ID
# trofi                         ID        	ID
# banyak                        ID        	ID
# kalo                          ID        	ID
# ujung-ujungnya                ID        	EN
# kontroversi                   ID        	O
# Hallo                         EN        	O
# @myXL                         O         	ID
# masih                         ID        	ID
# error                         EN        	EN
# ini                           ID        	ID
# sampe                         ID        	ID
# skrg                          ID        	ID
# jaringan                      ID        	ID
# 😤                             O         	O
# kalo                          ID        	ID
# ga                            ID        	ID
# karna                         ID        	ID
# ngelink                       MIX-ID-EN 	MIX-ID-EN
# ama                           ID        	ID
# mbanking                      EN        	ID
# &                             O         	O
# amp                           O         	O
# ;                             O         	O
# udah                          ID        	ID
# dipake                        ID        	ID
# lama                          ID        	ID
# buat                          ID        	ID
# kerjaan                       ID        	ID
# pasti                         ID        	ID
# udah                          ID        	ID
# saya                          ID        	ID
# non                           ID        	ID
# aktifin                       ID        	ID
# ni                            ID        	ID
# nomor                         ID        	ID
# XL                            O         	O
# .                             O         	O
# @teatimewithrin               O         	O
# TAK                           JV        	ID
# KEKI                          JV        	ID
# GRATIS                        JV        	ID
# GELEM                         JV        	ID
# TA                            JV        	ID
# ?                             O         	O
# tapi                          JV        	ID
# mbayaro                       JV        	ID
# ongkire                       MIX-ID-JV 	MIX-ID-JV
# tok                           JV        	JV
# 🤩                             O         	O
# 👍🏻                            O         	O
# @aeribase                     O         	O
# 1                             O         	O
# kali                          ID        	ID
# print                         EN        	EN
# 1                             O         	O
# kali                          ID        	ID
# dapat                         ID        	ID
# foto                          ID        	ID
# bareng                        ID        	ID
# .                             O         	O
# Ngeprint                      MIX-ID-EN 	MIX-ID-EN
# banyak                        ID        	ID
# bisa                          ID        	ID
# bawa                          ID        	ID
# pulang                        ID        	ID
# orang                         ID        	ID
# nya                           ID        	ID
# 🤗                             O         	O
# 👍                             O         	O
# @NatawidjajaArie              O         	O
# wes                           JV        	JV
# mulai                         ID        	ID
# nih                           ID        	ID
# ko                            JV        	JV
# ..                            O         	O
# Iyooo                         JV        	JV
# wes                           JV        	JV
# taon                          JV        	JV
# dpn                           ID        	JV
# yo                            JV        	JV
# g                             JV        	JV
# kroso                         JV        	ID
# ..                            O         	O
# Medeniiii                     JV        	JV
# ..                            O         	O
# Iso                           JV        	JV
# ko                            JV        	JV
# ,                             O         	O
# diclick                       MIX-ID-EN 	MIX-JV-EN
# aja                           ID        	ID
# sg                            JV        	JV
# ad                            ID        	ID
# (                             O         	O
# cont                          O         	EN
# )                             O         	O
# http://t.co/1W7NBYC           O         	JV
# @starfess                     O         	O
# Paji                          O         	ID
# bisa                          ID        	ID
# dicopy                        MIX-ID-EN 	MIX-ID-EN
# paste                         EN        	EN
# ga                            ID        	ID
# sih                           ID        	ID
# ,                             O         	O
# ya                            ID        	ID
# Allah                         O         	O
# .                             O         	O
# '                             O         	O
# Aku                           ID        	ID
# pengen                        ID        	ID
# ke                            ID        	ID
# korea                         O         	O
# tp                            ID        	ID
# gaisa                         JV        	ID
# cuti                          ID        	ID
# ca                            O         	O
# ,                             O         	O
# enak                          ID        	ID
# km                            ID        	ID
# isa                           JV        	JV
# seenaknya                     ID        	ID
# berangkat                     ID        	ID
# ke                            ID        	ID
# korea                         O         	O
# '                             O         	O
# JANCOK                        JV        	JV
# KON                           JV        	JV
# GAK                           JV        	JV
# MIKIR                         JV        	ID
# AKU                           JV        	JV
# DUIT                          JV        	ID
# E                             JV        	JV
# TUTUK                         JV        	JV
# NDI                           JV        	JV
# ?                             O         	O
# MBOK                          JV        	JV
# KIRO                          JV        	ID
# NGURUS                        JV        	JV
# VISA                          ID        	O
# LEK                           JV        	JV
# GAK                           JV        	JV
# KERJO                         JV        	ID
# NDE                           JV        	ID
# KANTORAN                      JV        	JV
# ISOK                          JV        	JV
# TENANG                        ID        	JV
# GAMPANG                       JV        	ID
# DIAPPROVE                     MIX-ID-EN 	MIX-ID-EN
# ?                             O         	O
# ENAK                          JV        	ID
# LAMBEMU                       JV        	O
# SU                            JV        	O
# @OposisiCerdas                O         	O
# Yg                            ID        	ID
# happy                         EN        	EN
# Tito                          O         	ID
# doank                         ID        	ID
# ...                           O         	O
# jabatannya                    ID        	ID
# sambung                       ID        	ID
# menyambung                    ID        	ID
# soalnya                       ID        	ID
# 😎                             O         	O
# asuuu                         JV        	O
# Kabeh                         JV        	JV
# Dengaren                      JV        	O
# ngeprintke                    MIX-JV-EN 	MIX-JV-EN
# tugas                         JV        	JV
# karo                          JV        	JV
# tiket                         JV        	JV
# ndelok                        JV        	JV
# persis                        O         	O
# larang                        JV        	ID
# ngeprint                      MIX-JV-EN 	MIX-ID-EN
# ke                            JV        	ID
# tugas                         JV        	ID
# ,                             O         	O
# suog                          JV        	ID
# ~                             O         	O
# @rouletteess                  O         	O
# @manggit_garis                O         	O
# udah                          ID        	ID
# di                            ID        	ID
# dm                            EN        	EN
# yaa                           ID        	ID
# gasss                         ID        	JV
# wkwkwk                        O         	O
# sek                           JV        	JV
# tak                           JV        	JV
# carine                        MIX-ID-JV 	MIX-ID-JV
# lagi                          ID        	ID
# heheh                         O         	O
# gimana                        ID        	ID
# caranya                       ID        	ID
# ngepin                        MIX-ID-EN 	MIX-ID-EN
# tweet                         EN        	EN
# orang                         ID        	ID
# ?                             O         	O
# perasaan                      ID        	ID
# dulu                          ID        	ID
# aku                           ID        	ID
# bisa                          ID        	ID
# kok                           ID        	ID
# skrng                         ID        	ID
# gabisa                        ID        	ID
# lgi                           ID        	ID
# @euisbeling13                 O         	O
# Kalo                          ID        	ID
# nomor                         ID        	ID
# selain                        ID        	ID
# +62                           O         	ID
# bisa                          ID        	ID
# disearch                      MIX-ID-EN 	MIX-ID-EN
# di                            ID        	ID
# gercontact                    O         	ID
# gk                            ID        	ID
# sih                           ID        	ID
# ?                             O         	O
# Telpon                        ID        	O
# 14045                         O         	O
# yan                           O         	O
# RT@harryansyah:               O         	O
# Woi                           ID        	ID
# internet                      ID        	ID
# jgn                           ID        	ID
# ngelag                        MIX-ID-EN 	MIX-ID-EN
# please                        EN        	EN
# bentar                        ID        	ID
# lagi                          ID        	ID
# lv                            EN        	ID
# 43                            O         	O
# @sbyfess                      O         	O
# Iya                           ID        	ID
# soale                         JV        	JV
# packingane                    MIX-JV-EN 	MIX-JV-EN
# box                           EN        	EN
# Kena                          ID        	JV
# volume                        ID        	JV
# sepiro                        JV        	JV
# larang                        JV        	JV
# ,                             O         	O
# lawong                        JV        	JV
# perokok                       JV        	JV
# ki                            JV        	JV
# ono                           JV        	JV
# duit                          JV        	JV
# gae                           JV        	JV
# tuku                          JV        	JV
# rokok                         JV        	ID
# .                             O         	O
# tapi                          JV        	JV
# ora                           JV        	JV
# ono                           JV        	JV
# aturan                        JV        	ID
# ketat                         JV        	ID
# banget                        JV        	JV
# sing                          JV        	JV
# gae                           JV        	JV
# cah                           JV        	JV
# dibawah                       ID        	ID
# umur                          ID        	ID
# mandeg                        JV        	JV
# rokok                         JV        	ID
# .                             O         	O
# Hp                            EN        	ID
# disilent                      MIX-ID-EN 	MIX-ID-EN
# ,                             O         	O
# trus                          ID        	ID
# lgi                           ID        	ID
# di                            ID        	ID
# charger                       EN        	ID
# ,                             O         	O
# org2                          ID        	ID
# nge                           ID        	ID
# chat                          EN        	EN
# pada                          ID        	ID
# enggak                        ID        	ID
# tau                           ID        	ID
# .                             O         	O
# Trus                          ID        	ID
# lupa                          ID        	ID
# balasnya                      ID        	ID
# ,                             O         	O
# memang                        ID        	ID
# lah                           ID        	ID
# kebiasaan                     ID        	ID
# aku                           ID        	ID
# wkwkwk                        O         	O
# 😅                             O         	O
# gonaku                        JV        	JV
# diprintke                     MIX-JV-EN 	MIX-JV-EN
# sisan                         JV        	JV
# ya                            JV        	JV
# RT                            EN        	EN
# @CynthiaInkee:                O         	O
# Sakit                         ID        	ID
# kali                          ID        	ID
# ini                           ID        	ID
# disponsori                    ID        	EN
# oleh                          ID        	JV
# bayang-bayang                 O         	ID
# tugas                         ID        	ID
# yang                          ID        	ID
# nggak                         ID        	ID
# kelar-kelar                   ID        	ID
# ,                             O         	O
# padahal                       ID        	ID
# udah                          ID        	ID
# pengen                        ID        	ID
# t                             O         	ID
# Mbok                          JV        	JV
# ada                           ID        	ID
# yg                            ID        	ID
# kerumahku                     ID        	ID
# bawain                        ID        	ID
# flashdisk                     EN        	EN
# ,                             O         	O
# sekalian                      ID        	ID
# ngeprintke                    MIX-JV-EN 	MIX-JV-EN
# tugas                         ID        	ID
# TIK                           ID        	ID
# ku                            ID        	ID
# :'')                          EN        	O
# masi                          ID        	ID
# inget                         ID        	ID
# gue                           ID        	ID
# baca                          ID        	ID
# au                            EN        	EN
# ini                           ID        	ID
# grgr                          ID        	ID
# diprank                       MIX-ID-EN 	MIX-ID-EN
# temen                         ID        	ID
# gue                           ID        	ID
# katanya                       ID        	ID
# happy                         EN        	EN
# ending                        EN        	EN
# tapi                          ID        	ID
# ternyata                      ID        	ID
# 🥲                             O         	O
# but                           EN        	EN
# hats                          EN        	EN
# off                           EN        	EN
# to                            EN        	EN
# my                            EN        	EN
# favourite                     EN        	EN
# angst                         EN        	EN
# au                            EN        	EN
# ,                             O         	O
# every                         EN        	EN
# tears                         EN        	EN
# i                             EN        	EN
# spent                         EN        	EN
# on                            EN        	EN
# this                          EN        	EN
# masterpiece                   EN        	EN
# is                            EN        	EN
# worth                         EN        	EN
# it                            EN        	EN
# ❤                             O         	O
# ️                             O         	O
# @binhshxx53                   O         	O
# @febandryani                  O         	O
# Mencoba                       ID        	O
# cari                          ID        	ID
# pengalihan                    ID        	ID
# cis                           O         	JV
# ,                             O         	O
# drama                         ID        	ID
# opo                           JV        	JV
# wae                           JV        	JV
# tak                           JV        	JV
# delok                         JV        	JV
# ki                            JV        	JV
# ,                             O         	O
# wes                           JV        	JV
# tak                           JV        	JV
# donlod                        EN        	EN
# suwi                          JV        	JV
# ,                             O         	O
# mubazir                       ID        	JV
# gak                           JV        	ID
# di                            JV        	ID
# delok                         JV        	JV
# 😅                             O         	O
# 😓                             O         	O
# #.                            O         	O
# ini                           ID        	ID
# maafff                        ID        	EN
# bgt                           ID        	ID
# rl                            EN        	EN
# tp                            ID        	ID
# please                        EN        	EN
# anyone                        EN        	EN
# tolong                        ID        	ID
# dong                          ID        	ID
# rep                           EN        	EN
# topik                         ID        	ID
# apa                           ID        	ID
# yg                            ID        	ID
# kira                          ID        	ID
# "                             O         	O
# ada                           ID        	ID
# perspektif                    ID        	ID
# pro                           ID        	EN
# &                             O         	O
# amp                           O         	O
# ;                             O         	O
# kontra                        ID        	ID
# nya                           ID        	ID
# ?                             O         	O
# contohnya                     ID        	ID
# kyk                           ID        	ID
# hukuman                       ID        	ID
# m4ti                          ID        	ID
# kan                           ID        	ID
# ada                           ID        	ID
# yg                            ID        	ID
# pro                           ID        	EN
# &                             O         	O
# amp                           O         	O
# ;                             O         	O
# kontra                        ID        	ID
# gt                            ID        	ID
# gt                            ID        	ID
# pls                           EN        	EN
# bantuin                       ID        	ID
# :")                           O         	O
# Fan                           ID        	ID
# projectnya                    MIX-ID-EN 	MIX-ID-EN
# bener2                        ID        	ID
# bikin                         ID        	ID
# pgn                           ID        	ID
# nonton                        ID        	ID
# lagi                          ID        	ID
# 😭                             O         	O
# kalian                        ID        	ID
# hebat                         ID        	ID
# banget                        ID        	ID
# ,                             O         	O
# super                         ID        	ID
# profesional                   ID        	ID
# huaaaa                        O         	ID
# T_T                           O         	O
# nangis                        ID        	ID
# banget                        ID        	ID
# liat                          ID        	ID
# perjuangan                    ID        	ID
# mreka                         ID        	ID
# yang                          ID        	ID
# bener                         ID        	ID
# "                             O         	O
# berlika-liku                  ID        	ID
# .                             O         	O
# and                           EN        	EN
# if                            EN        	EN
# he                            EN        	EN
# suddenly                      EN        	EN
# silent                        EN        	EN
# in                            EN        	EN
# the                           EN        	EN
# call                          EN        	EN
# ,                             O         	O
# he's                          EN        	EN
# just                          EN        	EN
# overcome                      EN        	EN
# it                            EN        	EN
# with                          EN        	EN
# SLEEP                         EN        	EN
# like                          EN        	EN
# how                           EN        	EN
# could                         EN        	EN
# u                             EN        	EN
# do                            EN        	EN
# that                          EN        	EN
# ?                             O         	O
# i                             EN        	EN
# mean                          EN        	EN
# ok                            EN        	EN
# tdr                           ID        	ID
# bisa                          ID        	ID
# jadi                          ID        	ID
# escape                        EN        	EN
# from                          EN        	EN
# life's                        EN        	EN
# stormy                        EN        	EN
# part                          EN        	EN
# TP                            ID        	ID
# JUJURLY                       MIX-ID-EN 	EN
# GUE                           ID        	ID
# GABISA                        ID        	ID
# .                             O         	O
# Gue                           ID        	ID
# malah                         ID        	ID
# ovt                           EN        	EN
# sampe                         ID        	ID
# ga                            ID        	ID
# bisa                          ID        	ID
# tdr                           ID        	EN
# .                             O         	O
# I                             EN        	EN
# just                          EN        	EN
# don't                         EN        	EN
# understand                    EN        	EN
# w/                            EN        	O
# him                           EN        	EN
# masalah                       JV        	JV
# e                             JV        	JV
# So                            O         	JV
# mbek                          JV        	JV
# Sa                            O         	JV
# angel                         JV        	JV
# diseleseke                    MIX-ID-JV 	MIX-ID-JV
# nek                           JV        	JV
# ego                           ID        	JV
# ne                            JV        	JV
# gede2                         JV        	JV
# ..                            O         	O
# segede                        JV        	JV
# gajah                         JV        	JV
# :(                            O         	O
# Ning                          O         	JV
# :                             O         	O
# "                             O         	O
# ma                            ID        	ID
# ,                             O         	O
# ning                          O         	JV
# mau                           ID        	ID
# jualan                        ID        	ID
# jilbab                        ID        	ID
# malolo                        O         	ID
# d                             ID        	ID
# kendari                       O         	ID
# ,                             O         	O
# menurut                       ID        	ID
# mama                          ID        	ID
# gimana                        ID        	ID
# ?"                            O         	O
# Ma                            ID        	ID
# :                             O         	O
# "                             O         	O
# Insya                         ID        	ID
# Allah                         O         	O
# bisa                          ID        	ID
# nak                           ID        	ID
# ,                             O         	O
# yang                          ID        	ID
# penting                       ID        	ID
# mau                           ID        	ID
# ikhtiar                       ID        	ID
# dan                           ID        	ID
# berdoa                        ID        	ID
# "                             O         	O
# Penyemangat                   ID        	ID
# pagi                          ID        	ID
# ku                            ID        	ID
# ..                            O         	O
# My                            EN        	EN
# angel                         EN        	EN
# ,                             O         	O
# mama                          ID        	ID
# tersayang                     ID        	EN
# ♥                             O         	O
# ️                             O         	O
# @natanattda                   O         	O
# Ibuku                         JV        	JV
# ,                             O         	O
# "                             O         	O
# ya                            JV        	JV
# Allah                         O         	O
# iki                           JV        	JV
# panganan                      JV        	JV
# opo                           JV        	JV
# ?                             O         	O
# Larang                        JV        	JV
# banget                        JV        	JV
# tp                            JV        	JV
# siithik                       JV        	ID
# e                             JV        	JV
# pol                           JV        	JV
# .                             O         	O
# Mending                       JV        	JV
# nggo                          JV        	JV
# tuku                          JV        	JV
# omah                          JV        	JV
# timbang                       JV        	JV
# nggo                          JV        	JV
# tuku                          JV        	JV
# panganan                      JV        	JV
# sak                           JV        	JV
# upil                          JV        	ID
# ngene                         JV        	JV
# ki                            JV        	JV
# "                             O         	O
# @collegemenfess               O         	O
# diem2                         ID        	ID
# aja                           ID        	ID
# aku                           ID        	ID
# jg                            ID        	ID
# magang                        ID        	ID
# di                            ID        	ID
# pt                            ID        	ID
# punya                         ID        	ID
# sodara                        ID        	ID
# tp                            ID        	ID
# emg                           ID        	ID
# pt                            ID        	ID
# nya                           ID        	ID
# ada                           ID        	ID
# dilist                        MIX-ID-EN 	MIX-ID-EN
# magang                        ID        	ID
# wajib                         ID        	ID
# kampus                        ID        	ID
# sih                           ID        	ID
# ,                             O         	O
# kek                           ID        	ID
# kampus                        ID        	ID
# ku                            ID        	ID
# ngeluarin                     ID        	ID
# list                          EN        	ID
# perusahaan                    ID        	ID
# a                             O         	O
# b                             O         	O
# c                             O         	O
# ini                           ID        	ID
# boleh                         ID        	ID
# magang                        ID        	O
# gt                            ID        	ID
# dan                           ID        	ID
# kebetulan                     ID        	ID
# ada                           ID        	ID
# @cgharger                     O         	O
# Gue                           ID        	ID
# ngebales                      ID        	ID
# replyan                       MIX-ID-EN 	ID
# doang                         ID        	ID
# ...                           O         	O
# dia                           ID        	ID
# yg                            ID        	ID
# tiba2                         ID        	ID
# nge                           ID        	ID
# jb                            EN        	MIX-ID-EN
# jb                            EN        	MIX-ID-EN
# ,                             O         	O
# dibales                       ID        	ID
# malah                         ID        	ID
# diblock                       MIX-ID-EN 	MIX-ID-EN
# ..                            O         	O
# ya                            ID        	ID
# gapapa                        ID        	ID
# juga                          ID        	ID
# siih                          ID        	ID
# NGELAG                        MIX-ID-EN 	MIX-ID-EN
# ALWAYS                        EN        	EN
# LAGGING                       EN        	O
# !!                            O         	O
# ERRRRRRRRRRRR                 O         	EN
# !!!                           O         	O
# PLEASE                        EN        	EN
# BE                            EN        	EN
# NICE                          EN        	ID
# INTERNET                      EN        	ID
# NO                            EN        	EN
# LAG                           EN        	ID
# -________-                    O         	O
# @pacarbighit                  O         	O
# ya                            ID        	ID
# aman2                         ID        	ID
# ajaa                          ID        	ID
# .                             O         	O
# aku                           ID        	ID
# selalu                        ID        	ID
# order                         ID        	ID
# namanya                       ID        	ID
# pc                            O         	EN
# bts                           O         	O
# ya                            ID        	ID
# ...
# kaya                          ID        	ID
# giniii                        ID        	ID
# 😭                             O         	O
# 😭                             O         	O
# https://t.co/B29xCVBTqF       O         	O
# Pdhl                          ID        	ID
# berharap                      ID        	ID
# bgt                           ID        	ID
# merch                         EN        	ID
# tote                          EN        	ID
# bag                           EN        	ID
# nya                           ID        	ID
# diapprove                     MIX-ID-EN 	MIX-ID-EN
# 🥲                             O         	O
# @sibasrotttt                  O         	O
# @mengkoceng                   O         	O
# Rasah                         JV        	O
# gowo2                         JV        	JV
# tutup                         JV        	ID
# cuk                           JV        	JV
# ,                             O         	O
# koe                           JV        	JV
# dikick                        MIX-JV-EN 	MIX-JV-EN
# Seko                          JV        	JV
# grup                          JV        	JV
# mung                          JV        	JV
# masalah                       JV        	JV
# tutup                         JV        	ID
# 🤣                             O         	O
# 🤣                             O         	O
# @lailia_mami                  O         	O
# @afif_james                   O         	O
# @arwindiputri                 O         	O
# semangatt                     ID        	O
# mam                           ID        	JV
# ,                             O         	O
# sok                           JV        	JV
# nek                           JV        	JV
# berkas2                       ID        	JV
# wes                           JV        	JV
# clear                         EN        	JV
# kabeh                         JV        	JV
# garek                         JV        	JV
# sukuran                       ID        	JV
# nraktir                       ID        	JV
# konco2                        JV        	JV
# sing                          JV        	JV
# diclearke                     MIX-JV-EN 	MIX-JV-EN
# .                             O         	O
# Oke                           ID        	ID
# !                             O         	O
# @Iniakunku458                 O         	O
# @mx00711                      O         	O
# Manusia                       ID        	O
# emg                           ID        	ID
# ga                            ID        	ID
# bisa                          ID        	ID
# milih                         ID        	ID
# lahir                         ID        	ID
# dari                          ID        	ID
# ras                           ID        	ID
# apa                           ID        	ID
# .                             O         	O
# Tp                            ID        	ID
# manusia                       ID        	ID
# bisa                          ID        	ID
# milih                         ID        	ID
# agama                         ID        	ID
# apapun                        ID        	ID
# .                             O         	O
# Manusia                       ID        	ID
# bisa                          ID        	ID
# milih                         ID        	ID
# kewarganegaraan               ID        	ID
# manapun                       ID        	ID
# (                             O         	O
# cuma                          ID        	ID
# milih                         ID        	ID
# ,                             O         	O
# urusan                        ID        	ID
# diapprove                     MIX-ID-EN 	MIX-ID-EN
# /                             O         	O
# ga                            ID        	ID
# ya                            ID        	ID
# beda                          ID        	ID
# lg                            ID        	ID
# 😂                             O         	O
# )                             O         	O
# @sweethoney765                O         	O
# Ngeload                       MIX-ID-EN 	MIX-ID-EN
# di                            ID        	ID
# website                       EN        	EN
# nya                           ID        	ID
# aja                           ID        	ID
# lama                          ID        	ID
# banget                        ID        	ID
# sampe                         ID        	ID
# error                         EN        	EN
# beberapa                      ID        	ID
# kali                          ID        	ID
# @ohmybeautybank               O         	O
# buset                         ID        	ID
# hape                          EN        	EN
# canggih                       ID        	ID
# tapi                          ID        	ID
# kenapa                        ID        	ID
# gak                           ID        	ID
# sekalian                      ID        	ID
# pengetahuannya                ID        	ID
# diupgrade                     MIX-ID-EN 	MIX-ID-EN
# ,                             O         	O
# banyak                        ID        	ID
# plusnya                       ID        	ID
# make                          ID        	EN
# menstrual                     EN        	ID
# cup                           EN        	EN
# tapi                          ID        	ID
# ya                            ID        	ID
# emang                         ID        	ID
# berisiko                      ID        	ID
# juga                          ID        	ID
# tapi                          ID        	ID
# kan                           ID        	ID
# woman’s                       EN        	ID
# choice                        EN        	EN
# .                             O         	O
# lagian                        ID        	ID
# kenapa                        ID        	ID
# sih                           ID        	ID
# masih                         ID        	ID
# mikirin                       ID        	ID
# gitu                          ID        	ID
# yatuhaaan                     ID        	O
# @hyp3r_bunny                  O         	O
# @Askrlfess                    O         	O
# Aku                           ID        	ID
# pernah                        ID        	ID
# denger                        ID        	ID
# nder                          EN        	EN
# ,                             O         	O
# katanya                       ID        	ID
# kalau                         ID        	ID
# ketika                        ID        	ID
# kita                          ID        	ID
# baligh                        ID        	ID
# dimana                        ID        	ID
# kita                          ID        	ID
# udah                          ID        	ID
# tau                           ID        	ID
# mana                          ID        	ID
# yang                          ID        	ID
# bener                         ID        	ID
# dan                           ID        	ID
# mana                          ID        	ID
# yang                          ID        	ID
# salah                         ID        	ID
# ,                             O         	O
# maka                          ID        	ID
# seharusnya                    ID        	ID
# kita                          ID        	ID
# mulai                         ID        	ID
# mempertanyakan                ID        	ID
# apakah                        ID        	ID
# selama                        ID        	ID
# ini                           ID        	ID
# agama                         ID        	ID
# yang                          ID        	ID
# kita                          ID        	ID
# jalani                        JV        	ID
# benar                         ID        	ID
# atau                          ID        	ID
# tidak                         ID        	ID
# .                             O         	O
# Jadine                        MIX-ID-JV 	MIX-ID-JV
# meskipun                      ID        	ID
# dilahirkan                    ID        	ID
# dalam                         ID        	ID
# agama                         ID        	ID
# apapun                        ID        	ID
# ,                             O         	O
# ketika                        ID        	ID
# baligh                        ID        	ID
# ...                           O         	O
# Dee                           JV        	O
# Ki                            JV        	O
# mung                          JV        	JV
# guyon                         JV        	JV
# ,                             O         	O
# haruse                        MIX-ID-JV 	MIX-ID-JV
# koe                           JV        	JV
# ngguyu                        JV        	JV
# ora                           JV        	JV
# malah                         JV        	JV
# kejeron                       JV        	JV
# :(                            O         	O
# @histaemin                    O         	O
# @tsundereculture              O         	ID
# @lobisevad                    O         	ID
# kemaren                       ID        	ID
# aja                           ID        	ID
# disensor                      ID        	ID
# ???                           O         	O
# yuta                          O         	ID
# baru                          ID        	ID
# deketin                       ID        	EN
# giginya                       ID        	ID
# rika                          O         	ID
# udah                          ID        	ID
# dicut                         MIX-ID-EN 	MIX-ID-EN
# ke                            ID        	ID
# geto                          ID        	EN
# tim                           ID        	ID
# sensornya                     ID        	EN
# ternyata                      ID        	ID
# sasha                         O         	O
# @northerncsl                  O         	O
# Model2                        JV        	O
# ngene                         JV        	JV
# kalah                         JV        	JV
# ngolek                        JV        	JV
# salah                         JV        	ID
# e                             JV        	JV
# siji                          JV        	JV
# loro                          JV        	JV
# pemain                        ID        	ID
# .                             O         	O
# Menang                        JV        	JV
# horeee                        ID        	JV
# ...                           O         	O
# Pemain                        ID        	ID
# arep                          JV        	JV
# main                          JV        	ID
# neng                          JV        	JV
# sleman                        O         	JV
# wegah                         JV        	ID
# di                            JV        	ID
# paido                         JV        	JV
# wae                           JV        	JV
# ...                           O         	O
# dari                          ID        	ID
# video                         ID        	ID
# lawan                         ID        	JV
# persiraja                     O         	ID
# kelihatan                     ID        	ID
# aliran                        ID        	EN
# bola                          ID        	ID
# lambat                        ID        	ID
# lawan                         ID        	JV
# .                             O         	O
# presing                       EN        	EN
# ketat                         ID        	JV
# mesti                         ID        	JV
# kedodoran                     ID        	JV
# wong                          JV        	JV
# belum                         ID        	ID
# nyetel                        ID        	ID
# Ket                           JV        	JV
# mau                           JV        	JV
# moco                          JV        	JV
# storyne                       MIX-JV-EN 	MIX-JV-EN
# wong²                         O         	JV
# bab                           JV        	JV
# iki                           JV        	JV
# kok                           JV        	JV
# aku                           JV        	JV
# rung                          JV        	JV
# paham                         JV        	JV
# konteks'e                     JV        	JV
# to                            JV        	JV
# ???                           O         	O
# Beli                          ID        	ID
# tulang                        ID        	EN
# sumsum                        ID        	O
# via                           ID        	ID
# Tokped                        O         	O
# .                             O         	O
# Ga                            ID        	ID
# mahal                         ID        	ID
# sih                           ID        	ID
# .                             O         	O
# Tp                            ID        	ID
# kok                           ID        	JV
# ora                           JV        	JV
# ono                           JV        	JV
# sumsume                       JV        	ID
# yo                            JV        	JV
# .                             O         	O
# Hihihi                        ID        	O
# https://t.co/1mb0ktwhUv       O         	O
# @diajengemy_                  O         	O
# @satriaxbrandal               O         	O
# @agama_nusantara              O         	ID
# @DiposuroP                    O         	O
# @SeruniPuspaAlam              O         	O
# Trus                          JV        	ID
# ?                             O         	O
# Ra                            JV        	JV
# oleh                          JV        	JV
# tuwo                          JV        	ID
# ?                             O         	O
# Ra                            JV        	JV
# oleh                          JV        	JV
# pikun                         JV        	ID
# ?                             O         	O
# Bar                           JV        	JV
# ngomong                       JV        	JV
# trus                          JV        	JV
# pringusan                     JV        	ID
# ...                           O         	O
# lali                          JV        	JV
# opo                           JV        	JV
# sing                          JV        	JV
# diomongke                     JV        	JV
# ...                           O         	O
# Salahe                        JV        	JV
# sopo                          JV        	JV
# milih                         JV        	JV
# wong                          JV        	JV
# sing                          JV        	JV
# berdiri                       ID        	JV
# setengah                      ID        	JV
# jam                           ID        	JV
# ae                            JV        	JV
# ngompol                       JV        	JV
# ?                             O         	O
# Tapi                          JV        	JV
# piye                          JV        	JV
# neh                           JV        	JV
# ...                           O         	O
# Une                           O         	JV
# stratègie                     O         	ID
# politique                     O         	ID
# ...                           O         	O
# Baru                          ID        	ID
# screentimenya                 MIX-ID-EN 	MIX-ID-EN
# dikit                         ID        	ID
# pas                           ID        	ID
# bts                           O         	O
# eps                           ID        	ID
# 13                            O         	O
# aja                           ID        	ID
# protes                        ID        	ID
# si                            O         	ID
# tika                          O         	O
# .                             O         	O
# Pas                           ID        	ID
# sbps                          O         	EN
# marah                         ID        	ID
# scene                         EN        	EN
# win                           EN        	EN
# dicut                         MIX-ID-EN 	MIX-ID-EN
# secara                        ID        	ID
# kasar                         ID        	EN
# aja                           ID        	ID
# dibilang                      ID        	ID
# lebay                         ID        	ID
# wkwkwkwk                      O         	O
# ya                            ID        	ID
# allah                         O         	O
# karma                         ID        	ID
# 😂                             O         	O
# 😂                             O         	O
# 😂                             O         	O

# %%
true_flat = [item for sublist in all_true_pair for item in sublist]
pred_flat = [item for sublist in all_pred_pair for item in sublist]

# %%
performance_report(true_flat, pred_flat)
# Out:
#               precision    recall  f1-score   support
#
#           ID       0.90      0.94      0.92     22314
#           JV       0.85      0.84      0.85      4912
#           EN       0.81      0.85      0.83      5017
#    MIX-ID-EN       0.97      0.83      0.90       973
#    MIX-ID-JV       0.98      0.83      0.90       280
#    MIX-JV-EN       0.97      0.82      0.89       277
#            O       0.93      0.84      0.88     10151
#
#     accuracy                           0.89     43924
#    macro avg       0.92      0.85      0.88     43924
# weighted avg       0.89      0.89      0.89     43924
