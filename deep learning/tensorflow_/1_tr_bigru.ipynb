# %%
from deep_learning_models import *
from helper.dataset_reader import read_tsv
from helper.utils import *
import pandas as pd

# %%
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# Tensorflow version: 2.8.0
# GPU detected: []

# %%
merged_data = read_tsv('../../dataset/comlid-data-140422-v1.tsv')

train_data = read_tsv('../../dataset/train.tsv')
val_data = read_tsv('../../dataset/val.tsv')
test_data = read_tsv('../../dataset/test.tsv')

# %%
X_train, y_train = input_converter(merged_data, train_data)
X_val, y_val = input_converter(merged_data, val_data)
X_test, y_test = input_converter(merged_data, test_data)

# %%
df = list_to_dataframe(merged_data)

# %%
words = get_unique_words(df)
tags = get_unique_tags(df)

# %%
num_words = len(words)
num_tags = len(tags)
max_len = 100
model = bigru_model(num_words, num_tags, max_len)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  embedding (Embedding)       (None, 100, 50)           1344500
#
#  spatial_dropout1d (SpatialD  (None, 100, 50)          0
#  ropout1D)
#
#  bidirectional (Bidirectiona  (None, 100, 200)         91200
#  l)
#
#  time_distributed (TimeDistr  (None, 100, 7)           1407
#  ibuted)
#
# =================================================================
# Total params: 1,437,107
# Trainable params: 1,437,107
# Non-trainable params: 0
# _________________________________________________________________

# %%
root_path = 'model/'
model_name = 'gru_model.h5'
num_epoch = 50
callbacks = get_callbacks(root_path, model_name)

history = model.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    epochs=num_epoch,
    callbacks=callbacks,
    verbose=1
)

print(model.evaluate(X_test, y_test))
# Out:
# accuracy
# 	training         	 (min:    0.802, max:    0.993, cur:    0.993)
# 	validation       	 (min:    0.890, max:    0.897, cur:    0.890)
# Loss
# 	training         	 (min:    0.005, max:    0.141, cur:    0.005)
# 	validation       	 (min:    0.075, max:    0.103, cur:    0.103)
#
# Epoch 8: val_loss did not improve from 0.07485
# 91/91 [==============================] - 12s 128ms/step - loss: 0.0052 - accuracy: 0.9932 - val_loss: 0.1030 - val_accuracy: 0.8900
# 56/56 [==============================] - 1s 24ms/step - loss: 0.1005 - accuracy: 0.8891
# [0.10051123052835464, 0.889103889465332]

# %%
from keras.models import load_model

mdl = load_model('model/gru_model.h5')

# %%
all_w_pair = []
all_true_pair = []
all_pred_pair = []

for i in range(len(X_test)):
    p = mdl.predict(np.array([X_test[i]]))
    p = np.argmax(p, axis=-1)
    y_true = y_test[i]
    w_pair = []
    true_pair = []
    pred_pair = []
    for w, true, pred in zip(X_test[i], y_true, p[0]):
        if words[w-1] != "ENDPAD":
            # print("{:30}{:10}\t{}".format(words[w-1], tags[true], tags[pred]))
            w_pair.append(words[w-1])
            true_pair.append(tags[true])
            pred_pair.append(tags[pred])
    all_w_pair.append(w_pair)
    all_true_pair.append(true_pair)
    all_pred_pair.append(pred_pair)

# %%
true_flat = [item for sublist in all_true_pair for item in sublist]
pred_flat = [item for sublist in all_pred_pair for item in sublist]

# %%
performance_report(true_flat, pred_flat)
# Out:
#               precision    recall  f1-score   support
#
#           ID     0.9107    0.9434    0.9268     22309
#           JV     0.8242    0.8567    0.8402      4914
#           EN     0.9024    0.8237    0.8613      5020
#    MIX-ID-EN     0.9623    0.7873    0.8660       973
#    MIX-ID-JV     0.9050    0.7821    0.8391       280
#    MIX-JV-EN     0.9474    0.7148    0.8148       277
#            O     0.8836    0.8596    0.8714     10151
#
#     accuracy                         0.8948     43924
#    macro avg     0.9051    0.8240    0.8599     43924
# weighted avg     0.8951    0.8948    0.8942     43924

# %%
df_ = pd.DataFrame({
    'word': all_w_pair,
    'true': all_true_pair,
    'pred': all_pred_pair
})

# %%
token_true_pred = []
for index, row in df_.iterrows():
    pair = list(zip(row['word'], row['true'], row['pred']))
    token_true_pred.append(pair)

# %%
true_pred_file = 'tagging_result/compare_results_gru.tsv'
with open(true_pred_file, "a", encoding='utf-8') as f:
    f.write("Word" + "\t" + "True" + "\t" + "Predict" + "\n")

    for index, row in df_.iterrows():
        for tkn, t_true, t_pred in (zip(row['word'], row['true'], row['pred'])):
            f.write(tkn + '\t' + t_true + '\t' + t_pred + '\n')
        f.write('\n')

f.close()

# %%
i = np.random.randint(0, X_test.shape[0]) #659
p = mdl.predict(np.array([X_test[i]]))
p = np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:30}{:10}\t {}\n".format("Word", "True", "Pred"))
print("-" *60)

for w, true, pred in zip(X_test[i], y_true, p[0]):
    if words[w-1] != "ENDPAD":
        print("{:30}{:10}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# Word                          True      	 Pred
#
# ------------------------------------------------------------
# oyi                           JV        	JV
# rek                           JV        	JV
# penjual                       ID        	ID
# ayam                          ID        	ID
# potong                        ID        	ID
# di                            ID        	ID
# pasar                         ID        	ID
# itu                           ID        	ID
# mau                           ID        	ID
# apa                           ID        	ID
# engga                         ID        	ID
# ya                            ID        	ID
# kalo                          ID        	ID
# misal                         ID        	ID
# kita                          ID        	ID
# beline                        MIX-ID-JV 	MIX-ID-JV
# fillet                        EN        	O
# ?                             O         	O
# spill                         EN        	EN
# dipasar                       ID        	EN
# mana                          ID        	ID
# dong                          ID        	ID
# 🙏                             O         	O
# 🏻                             O         	O

# %%
from keras.utils.vis_utils import plot_model
plot_model(mdl, to_file='model_plot/tr_bigru.png', show_shapes=True, show_layer_names=False)
