# %% [markdown]
# ## Next Tasks
#
# 1. The next job is to create a csv or excel or text or conll format file containing tokens.
# 2. The file has the following header: ID, word, tag. This structure is based on https://towardsdatascience.com/pos-tagging-using-crfs-ea430c5fb78b
# 3. Do automatic tagging using several dictionaries (Indonesian, Javanese, English)
# 4. Propose the following tags"
#     - ID --> Indonesian
#     - EN --> English
#     - JV --> Javanese
#     - ID-EN --> mix Indonesian English
#     - NE --> name entity
#     - O --> Others (punctuations, hastags, URLs, etc.)
#     - OOV-ID --> OOV of Indonesian words
#     - OOV-EN --> OOV of English words
#     - OOV-JV --> OOV of Javanese words
#
# 5. To automatically label the tokens, we need the following dictionaries: (Update 31 Desember 2021)
#     - Indonesian dictionary
#         opsi --> https://pypi.org/project/kbbi/
#         FIX DIPAKAI: https://github.com/damzaky/kumpulan-kata-bahasa-indonesia-KBBI (updated 311221)
#     - English dictionary --> solved 250921: using english_words library
#     - Javanese dictionary --> unresolved 311221, options:
#         - create a list of tokens from Javanese tweets
#         - find a valid repository
#         - modify https://1000mostcommonwords.com/1000-most-common-javanese-words/
#
#
# 080122
#     Found latin languages, with keyword angel
#
#
# (010222):
# We do manual tagging to.
# Plan:
#     - Train manual tagging to create semi supervised training dataset
#
# Run in Kaggle?
#
#     To do next:
#     - Name entity dictionary
#     - Punctuations and symbols dictionary
#     - Regex to determine URLs and hashtags
#     - Indonesian OOV dictionary --> find Indonesian slang dictionary
#     - English OOV dictionary --> find English slang dictionary
#     - Javanese OOV dictionary --> ??
#
#     120122 --> line 15778  tagged data.txt
#
#     Labelling:
#     create dictionary from labelled data. (tagged-data.txt)
#
#     120122
#     To do:
#     - Remove duplicates --> solved (100122)
#     - Remove language other than Indonesian, English, Javanese
#     - Solve tagging problems: nn/mm , xxx...yyy --> solved (120122)
#     - solve tagging problems: tt.rr ; rr,ii
#
#     120122:
#     - Create dictionaries using correct tagged data
#     - Tokenize then tag the tokens --> recommended tokenizer: from nltk.tokenize import TweetTokenizer
#
#     310122
#     Line 104 tagged-text.txt
#
#     070222
#     Issue: *{ALL SOLVED: 200222}*
#     @100.000 tokenized into '@100' '.' '000'
#     bener² --> this should be one token: line 19310
#     '1.tinggi' is not tokenized perfectly
#     X% should not be tokenized --> '99%' instead of '99' '%'
#     bener" should not be tokenized
#     named entity tagging, using BIO format?
#     Bhs Sunda line 20138, 21533
#     Handle character emoticon ':))'
#     Handle -__-  and -_-
#     Handle mari..."
#
#     020222:
#     83317
#
#     070222
#     line 1727
#
#     080222:
#     Automatic labelling for 'O' label

# %% [markdown]
# ### 21022022
#
# #found issues: not tokenized properly in tokenize.ipynb
#
# luck:)
#
# iki..haha
#
# main'e,terburu-buru
#
# tok..hahaha
#
# 2014..
#
# gulung-gulung,
#
# "Pernahnya
#
# "Lo
#
# isuk-_-RT

# %% [markdown]
# Line 8392 : 23022022
#
# From file: (CSV file data-filtered-280122.xlsx)
#
# ### 230222
# Delete line 286: Malay
# @asrulmm hntu botol kicap?haha..hantu susu adalah konco dia..x mmbina lgsung filem cmni..baik tgk cite tamil rajnikanth lg best :D
#
# ### 240222
# Delete line 2031 : Malay
# Ini bukan tawaran shopee 10.10 tapi tawaran daripada saya Uwais Qorny, guru Quran anda.  10.10 pagi bermula. Daftar selaju dan seramai mungkin.  Harga istimewa dan video khas 29 pantang larang sebut huruf Quran untuk 100 yang terawal.  Link pendaftaran ⬇️   https://t.co/5qGEdl5MwE  https://t.co/zPRoUZeV7F
#
# Delete line 878: Sundanese language
# @v_frontline_pc Nyinyir wae pron dado uruskeun ceunah paling kritis ah kumaha ieu mah 🤭
#
# Delete line 97: Sundanese language
# @death_by_luck naha nya di indo, mun aya nu kasar kieu. masih keneh protes ka wasit naha pelanggaran....
#
# ### 270222
# 1. Delete line 452: Malay
# Sila pkai *Topeng muka n95* apabila kluar rumah.  Pencemaran udara telah tersebar di pasir gudang. Ramai diantara org yg duduk di seri alam n plentong masok hospital , angin bertiup kencang mnyebabkan toxic dekat dgn kita... Please pray for Pasir Gudang😢 Stay safe✨
#
# 2. Delete line 475: Malay
# Dah 3 hari angin kencang+hujan lebat dkt sini. Dah la duk tingkat 9. Bunyi mcm2, syiling nak terbang la, sampah terbang la. Pray for kuantan. Pray for my final
#
# 3. Delete line 478: Malay
# Harini mcm2 khabar angin bertiup kencang kt office ni. K just pray for the best.
#
# 4. Delete line 2014: Malay
# My mum kan mau beli kasut di shopee sebab murah dan cantik tapi aku larang, mostly kasut shopee murah tapi nda tahan. Kesian jugak sebab mama macam mau betul bah.
#
# 5. Delete line 486: Malay
# Pray 4 pantai Timur...  Angin kencang &amp; laut bergelora, air melimpahi tebing
#
# 6. Delete line 487: Malay
# A little truth, i'm a bit sad because angin kencang didn't won last night. But it's okay. Pray for his success. Aminnn   🌾🌾🌾🌾🌾🌾🌾🌾🌾🌾🌾🌾
#
# 7. Delete line 488: Malay
# Pray the best for Noh Salleh - Angin Kencang #AJL30
#
# 8. Delete line 505: Malay
# Weh tak tahu kenapa. Aku rasa nak amik master. Tarikh tutup sebelum 12/2 ni 🥲 Ya Allah berbelah nya hati.
#
# 9. Delete line 762: Sundanese
# karek kapikiran naha unggal aing nntn bola pasti eleh wae anj,ai teu nonton kalah sok menang😭
#
# 10. Delete line 764: Sundanese
# Kumaha teu rudet ajig udah mah nonton bola kalah ditambah push rank kalah wae 💩
#
# 11. Delete line 769: Sundanese
# @persib Ari pemain NU di latih naon ungkul Beett? Eta we ngoper ge ka Batur wae  yepak bola kalah kaluar wae...
#
# 12. Delete line 771: Sundanese
# Deden Natsir ceuk aing mah ek cicing wae jadi manekin puguh eta mah, lain bola ditjofng musuh kalah lalajo wungkul blog caw anying ka pskc we sia
#
# 13. Delete line 774: Sundanese
# @MJamal33 @persib Heeh bener aduh aingah weh greget2 na acan,, eta strekeur boyotna menta ampun, kalah loba daeping w hayang bola ngeunah wae
#
# 14. Delete line 778: Sundanese
# @akmaleee Eta teh bola suku tapi naha kalah ku sirah di heden sok kabiasaan wae
#
# 15. Delete line 779: Sundanese
# @Tyows Asli maguire bapuk bola set piece kalah wae, teu cara jiga di PES 🥲
#
# 16. Delete line 900: Sundanese
# @v_frontline_pc Nyinyir wae maneh teh siah, laina mere support atau input nu alus 👋🏻
#
# 17. 901 @bdngfess Nyinyir wae
#
# 18. 902 @bdaipastbrlnjt @ridwankamil @AndreasMarbun_ Nyinyir wae sia kehed mul mil mal mil jiga saumuran wae sia
#
# 19. 880 Naha nya ari psi nyinyir wae koplok 🤣😂
#
# 20. 886 Asa ateul nempo wae partai ieu nyinyir...yeuh bero nya dibejaan ku uing, cik maneh tibatan nyiyir wae ka gubernur, maneh nyinyir oge atuh kamana eta harun masiku??? Piraku newak teroris gancang ari koruptor lila...saran weh uing mah ngingetan meh objektif.
#
# 21. 894 Oh suka nyinyir juga ya. Atau protes? Apanan fansib mah sarantun sok nerimakeun wae nya
#
# 22. 895. @SantorinisSun Listrik bayar woy nyinyir wae silaingmah
#
# 23. 896 @Uki23 Enggeus lah ki, lebar otak dipake nyinyir wae, teu manfaat tah otak teh
#
# 24. 908 @panglima_z Oh Kitu,Muhun atuh,TOS Pendem wae nya,sugan CEBI nyinyir Ari TOS di terangken Kitu mah malalikir ,siapa sih masyarakat,tokoh agama,dsb yg mau daerahnya di jadikan tempat tempat maksiat,logikanya kan gitu ya
#
# 25. 656 Banjar language
#     Liliiiiiiii congrats lah sudah 10k haja ni, semangat tarus lah streaming nya mudahan makin rami haja nyaman hibak isi chat jua kaina hahaha @LilianCh10  https://t.co/NqXzPQLGSo
#
# 26. 920: Sundanese
#     @gendatmike Umak nyinyir wae euy 🤭
#
# 27. 927: Sundanese
#     Serius org jaman skrg mh nyinyir doang di gedein,mslh nyali nya kitu tea akakaka ttp semangat,tong di dangu nu ngmng kamana wae,sarangheo
#
# 28. 932: Sundanese
#     Meski bukan sebuah kewajiban mendukung timnas Garuda di final AFF 2020, tapi da ari ku karesep mah der weh. Keun wae nu nyinyir mah. Menang gak menang tetap berjuang. 💪
#
# 29. Croatian
#      @RumenoLice Stavljam i ono sto sam radio na crno, uvijek prilagođavam ovisno o tome na kakav se tip posla prijavljujem, imam par templatea pa samo provjerim jel updatean ili ne prije nego pošaljem.  Disclaimer: na temelju životopisa sam bio zaposlen jednom, poslao sam ga baš puno puta.
#
# 30. German
#      @Nell781 Tik Tak die Zeit läuft ⏳ ohne Luftfilter und Masken zu Hause…
#
# 31. Malay
#      I sedih bila tgk something tu dicopy paste sebijik and dijual dengan harga yg lebih murah. Dengan tag sama, dengan jenama sama siap buat ads lagi.
#
# 32. Malay
#         Aduh bs Eva beria suruh apply kerja tempat kerja lama dia dulu ada vacancy tp Shipping Dept. Sahhh direject awal lagi kalau apply punnnn takda kena mengena
#
# To identify Malay language:
# - look at the username/account
# - look at some words that are not commonly used by Indonesian

# %% [markdown]
# ### Abreviation or Acronym
# GA = giveaway
#
# fs = for sale
#
# NT = nice try
#
# Tl = time line
#
# FG = fresh graduate
#
# SG = snapgram
#
# PC = photocard
#
# rekber = rekening bersama
#
# ootd = outfit of the day
#
# fw garnier = face wash garnier
#
# cc = credit card
#
# va = virtual account
#
# co = check out
#
# minbel = minimal belanja
#
# nder = sender
#
# WH = ware house
#
# RT = Retweet
#
# rekber = rekening bersama
#
# FUP = fair usage policy
#
# WM = wall message
#
# OS = official store
#
# CB = cashback
#
# selca = selfie camera
#
# latsol = latihan soal
#
# rl = real life
#
# rp = role player
#
# verval = verifikasi dan validasi
#
# tnc = term and condition
#
# kip = kartu indonesia pintar
#
# dmg = damage bonus
#
# mci = master chef indonesia
#
# pt = pressure test
#
# sjw = social justice warriors
#
# sabi = bisa
#
# fwb = friends with benefits
#
# Menfess” or “Mention and confess
#
# qr = quick response
#
# anw = anyway
#
# salkun = salah akun
#
# sb = subscribe
#
# lrp = left role player
#
# fomo = fear of missing out
#
# ar = adventure rank
#
# jb = join bareng
#
# mentab = mention tab
#
# mv = music videos
#
# mfs = middle finger salute
#
# RE = retained earning
#
# mjb = maaf join bareng
#
# au = alternate universe
#
# fl = friend list
#
# sb = subscribe
#
# joktug = joki tugas
#
# wta = want to ask
#
# bbw = bubble wrap
#
# video fs = video full shot
#
# wtb = want to buy
#
# STFU =  shut the fuck up
#
# tbl =takut banget loh
#
# gdm = group direct message

# %% [markdown]
# Words with dash always identified as O
#
# 9544 --> 060422: 23:05

# %%
# Tweet with mix Indonesian-Sundanese line: 2429 in tagged-text.txt
